# %% [markdown]
# # **Default Setting**
#
# * Python: 3.6.9
# * ML Framework: tensorflow-gpu 2.4.0 / tensorflow-addons 0.12.0
# * CPU: AMD Ryzen 5 5600X 6-Core Processor
# * GPU: GeForce RTX 3070 (8G) (CUDA 11.1)
# * RAM: 32G
# * Platform: Linux Ubuntu 20.04 LTS (desktop)
#
# Install below APIs using anaconda as belows.
#
# ```
# conda create -n py36 python=3.6.9
# conda acitvate py36
# pip3 install tensorflow-gpu=2.4.0 tensorflow-addons=0.12.0
# conda install pandas, matplotlib, pydot, jupyterlab, cudatoolkit
# ```
#
# And now, you can run jupyter lab (or jupyter notebook).
#
# ```
# jupyter lab
# ```

# %%
# %env NOTEBOOKNAME try163
# %env LOCAL_DATA_PATH data
# %env CHECKPOINT_PATH ckpt
# %env SUBMISSION_PATH submission
# Out:
# env: NOTEBOOKNAME=try163
# env: LOCAL_DATA_PATH=data
# env: CHECKPOINT_PATH=ckpt
# env: SUBMISSION_PATH=submission

# %%
import tensorflow as tf
import tensorflow_addons as tfa

import datetime
import glob
import os

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

print(f"tf.__version__: {tf.__version__}")
print(f"tfa.__version__: {tfa.__version__}")
# Out:
# tf.__version__: 2.4.0
# tfa.__version__: 0.12.0

# %%
# If you wanna avoid below error, you need to run below codes when you start kernel.

# UnknownError: Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, 
# so try looking to see if a warning log message was printed above. [Op:Conv2D]

# Ref: https://blog.naver.com/vft1500/221793591386

gpus = tf.config.list_physical_devices("GPU")
if gpus:
    try:
    # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices("GPU")
        print(f"{len(gpus)} Physical GPUs, {len(logical_gpus)} Logical GPUs.")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs.

# %%
# !python -V

# %%
# !cat /proc/cpuinfo

# %%
# !nvidia-smi
# Out:
# Sun Jan 10 07:17:20 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.32.00    Driver Version: 455.32.00    CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Graphics Device     On   | 00000000:0A:00.0  On |                  N/A |
# |  0%   38C    P2    33W / 220W |    671MiB /  7979MiB |     14%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A       914      G   /usr/lib/xorg/Xorg                 35MiB |
# |    0   N/A  N/A      1404      G   /usr/lib/xorg/Xorg                 91MiB |
# |    0   N/A  N/A      1532      G   /usr/bin/gnome-shell               32MiB |
# |    0   N/A  N/A      2163      G   ...AAAAAAAA== --shared-files      193MiB |
# |    0   N/A  N/A     34846      C   ...nda3/envs/py36/bin/python      303MiB |
# +-----------------------------------------------------------------------------+

# %%
# !df -h

# %%
# !free -h
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:           31Gi        17Gi        12Gi       107Mi       1.8Gi        13Gi
# Swap:         2.0Gi       845Mi       1.2Gi

# %%
# Load the TensorBoard notebook extension.
# %load_ext tensorboard

# %% [markdown]
# # **Define Arguments**

# %%
class HParams(object):
    def __init__(self):
        # Basic
        self.seed = 42
        self.test_size = 0.2
        self.epoch = 50
        self.lr = 1e-3
        
        # Dataframe
        self.feature_dict = {}
        self.num_test_csv = 81
        self.day = 48
        self.real_day = 24
        
        # Dataset Pipeline
        self.w_inp = 7
        self.w_tar = 2
        self.w_shift = 1
        self.w_stride = 1
        self.w_dr = True
        
        self.shuffle_buffer_sz = 100_000

        self.auto = tf.data.experimental.AUTOTUNE

        self.global_batch_size = 128
        
        # model
        self.num_features = 8
        self.num_quantile = 9
        
        self.input_shape = [self.w_inp, self.real_day, self.num_features]
        self.input_dtype = tf.float32
        self.units = 64
        self.out_steps = self.w_tar
        self.dropout_rate = 0.4
        
        # Remove checkpoints.
        self.max_to_keep = 3
                
HPARAMS = HParams()

# %% [markdown]
# # **Load Datasets**

# %% [markdown]
# ## **Define Preprocessing Funciton**

# %%
def preprocessing(
    df: pd.DataFrame, 
    is_training: bool = True
) -> pd.DataFrame:
    """Preprocess dataframes without any normalize."""
    
    # Timestamp to signals.
    time = 2 * np.int64(df["Hour"]) + (np.int64(df["Minute"]) // 30)
    df.insert(loc = 0, column = "Time", value = time)
    
    day_sin = np.sin(df["Time"] * (2 * np.pi / HPARAMS.day))
    day_cos = np.cos(df["Time"] * (2 * np.pi / HPARAMS.day))
        
    df.insert(loc = 0, column = "DAY_SIN", value = day_sin)
    df.insert(loc = 1, column = "DAY_COS", value = day_cos)
    
    df = df.drop(["Day", "Hour", "Minute", "Time"], axis = 1)
    
#     for column in df.columns:
#         if is_training:
#             HPARAMS.feature_dict[f"{column}_MEAN"] = np.float32(df[column].mean())
#             HPARAMS.feature_dict[f"{column}_STD"] = np.float32(df[column].std())
        
#         df[column] = (df[column] - HPARAMS.feature_dict[f"{column}_MEAN"]) \
#             / HPARAMS.feature_dict[f"{column}_STD"]
    
    return df

# %% [markdown]
# ## **Train & Validation Dataframes**

# %%
df = pd.read_csv(os.path.join(os.environ["LOCAL_DATA_PATH"], "train", "train.csv"))
df.head(n = 10)
# Out:
#    Day  Hour  Minute  DHI  DNI   WS     RH   T  TARGET
# 0    0     0       0    0    0  1.5  69.08 -12     0.0
# 1    0     0      30    0    0  1.5  69.06 -12     0.0
# 2    0     1       0    0    0  1.6  71.78 -12     0.0
# 3    0     1      30    0    0  1.6  71.75 -12     0.0
# 4    0     2       0    0    0  1.6  75.20 -12     0.0
# 5    0     2      30    0    0  1.5  69.29 -11     0.0
# 6    0     3       0    0    0  1.5  72.56 -11     0.0
# 7    0     3      30    0    0  1.4  72.55 -11     0.0
# 8    0     4       0    0    0  1.3  74.62 -11     0.0
# 9    0     4      30    0    0  1.3  74.61 -11     0.0

# %%
# Forces the length of train and test data to be a multiple of the day.
HPARAMS.split_len = int(df.shape[0] * (1. - HPARAMS.test_size))
HPARAMS.split_len = HPARAMS.split_len - (HPARAMS.split_len % HPARAMS.day)

tr_df = df[:HPARAMS.split_len]
vl_df = df[HPARAMS.split_len:]

HPARAMS.epsilon = np.float32(tr_df["TARGET"][tr_df["TARGET"] > 0].min() * 0.9)

tr_df = preprocessing(tr_df)
vl_df = preprocessing(vl_df, is_training = False)

print(f"tr_df.shape: {tr_df.shape}, columns: {','.join(tr_df.columns)}")
print(f"vl_df.shape: {vl_df.shape}, columns: {','.join(vl_df.columns)}")
# Out:
# tr_df.shape: (42048, 8), columns: DAY_SIN,DAY_COS,DHI,DNI,WS,RH,T,TARGET
# vl_df.shape: (10512, 8), columns: DAY_SIN,DAY_COS,DHI,DNI,WS,RH,T,TARGET

# %% [markdown]
# ## **Test Dataframe**

# %%
ts_filenames = [os.path.join(os.environ["LOCAL_DATA_PATH"], "test", f"{i}.csv") for i in range(HPARAMS.num_test_csv)]
ts_dfs = [preprocessing(pd.read_csv(ts_filename), is_training = False) for ts_filename in ts_filenames]
ts_df = pd.concat(ts_dfs)

print(f"ts_df.shape: {ts_df.shape}, columns: {','.join(ts_df.columns)}")
# Out:
# ts_df.shape: (27216, 8), columns: DAY_SIN,DAY_COS,DHI,DNI,WS,RH,T,TARGET

# %% [markdown]
# # **Make Dataset Pipelines**
#
# The first batch is to bundle the tensors as input into units of a day. The operation below can guarantee that the number of sequences of tr_tensor and vl_tensor is a multiple of a day (i.e. 48), so `drop_remainder = True` is actually meaningless. However, it was added to specify the shape of the input data during the window division process (`.window(...)`)
#
# ```
# args["SPLIT_LEN"] = int(df.shape[0] * (1. - args["TEST_SIZE"]))
# args["SPLIT_LEN"] = args["SPLIT_LEN"] - np.mod(args["SPLIT_LEN"], args["DAY"]) # this process
#
# tr_df = df[:args["SPLIT_LEN"]]
# vl_df = df[args["SPLIT_LEN"]:]
# ```
#
# It is recommended to cache the dataset after the map transformation except if this transformation makes the data too big to fit in memory. A trade-off can be achieved if your mapped function can be split in two parts: a time consuming one and a memory consuming part. In this case, you can chain your transformations like below:
#
# ```
# dataset.map(time_consuming_mapping).cache().map(memory_consuming_mapping)
# ```
#
# If the cache is executed after partioning the window, the amount of data loaded in the memory increases by about 9 times (=`(W_INP + W_TAR) / W_STRIDE)`. Obviously, the mapping process comsumes a lot of time, but since we have to train a model like this 9 times, it would be desirable to load it into the cache mory before the window split.
#
# Also `cache` produce exactly the same elements during each iteration through the dataset. If you wish to randomize the iteration order, make sure to call `shuffle` after calling `cache`.
#
# Immediately after the window is splited, the mapping function `_split_window` is called after stacking with `GLOBAL_BATCH_SIZE`. This time, the vectorized mapping function is called once and applies to a batch of sample. While the function could takes more time to execute, the overhead appear only once, improving the overall time performance.
#
# *References*
#    * *https://www.tensorflow.org/guide/data_performance*
#    * *https://www.tensorflow.org/api_docs/python/tf/data/Dataset*

# %%
@tf.function
def _flat_fn_tr(x):
    return x.batch(HPARAMS.w_inp + HPARAMS.w_tar)


@tf.function
def _flat_fn_ts(x):
    return x.batch(HPARAMS.w_inp)


@tf.function
def tmp_fn(features):
    return tf.stack([features[:, :, 0::2, :], features[:, :, 1::2, :]], axis = 0)


@tf.function
def _split_window_tr(features):
    """
        input:  (batch, 9, 48, 8)
        output: (batch, 7, 48, 8), (batch, 2, 48, 1)
    """
    inp, tar = tf.split(features, [HPARAMS.w_inp, HPARAMS.w_tar], axis = 1)
    _, tar = tf.split(tar, [-1, 1], axis = -1)
    
    return inp, tar

# %%
# Dataframe to tensor. (TARGET column located on axis = -1)
tr_tensor = tf.constant(tr_df, dtype = tf.float32)
vl_tensor = tf.constant(vl_df, dtype = tf.float32)
ts_tensor = tf.constant(ts_df, dtype = tf.float32)

# Tensor to dataset.
tr_dataset = tf.data.Dataset.from_tensor_slices(tr_tensor
                    ).batch(HPARAMS.day, drop_remainder = True
                    ).cache(
                    ).window(HPARAMS.w_inp + HPARAMS.w_tar, HPARAMS.w_shift, HPARAMS.w_stride, HPARAMS.w_dr).flat_map(_flat_fn_tr
                    ).shuffle(HPARAMS.shuffle_buffer_sz, reshuffle_each_iteration = False
                    ).batch(HPARAMS.global_batch_size
                    ).map(tmp_fn, num_parallel_calls = HPARAMS.auto).unbatch(
                    ).map(_split_window_tr, num_parallel_calls = HPARAMS.auto
                    ).prefetch(HPARAMS.auto)
                                                
vl_dataset = tf.data.Dataset.from_tensor_slices(vl_tensor
                    ).batch(HPARAMS.day, drop_remainder = True
                    ).cache(
                    ).window(HPARAMS.w_inp + HPARAMS.w_tar, HPARAMS.w_shift, HPARAMS.w_stride, HPARAMS.w_dr).flat_map(_flat_fn_tr
#                     ).shuffle(HPARAMS.shuffle_buffer_sz, reshuffle_each_iteration = False
                    ).batch(HPARAMS.global_batch_size
                    ).map(tmp_fn, num_parallel_calls = HPARAMS.auto).unbatch(
                    ).map(_split_window_tr, num_parallel_calls = HPARAMS.auto
                    ).prefetch(HPARAMS.auto)

ts_dataset = tf.data.Dataset.from_tensor_slices(ts_tensor
                    ).batch(HPARAMS.day, drop_remainder = True
#                     ).cache(
                    ).window(HPARAMS.w_inp, HPARAMS.w_inp, HPARAMS.w_stride, HPARAMS.w_dr).flat_map(_flat_fn_ts
#                     ).shuffle(HPARAMS.shuffle_buffer_sz, reshuffle_each_iteration = True
                    ).batch(HPARAMS.num_test_csv # not HPARAMS.global_batch_size
#                     ).map(_split_window_ts, num_parallel_calls = HPARAMS.auto
                    ).prefetch(HPARAMS.auto)

# Print the shapes.
print("tr_dataset:")
print(f"\tinp: {tr_dataset.element_spec[0]}")
print(f"\ttar: {tr_dataset.element_spec[1]}")

print("vl_dataset:")
print(f"\tinp: {vl_dataset.element_spec[0]}")
print(f"\ttar: {vl_dataset.element_spec[1]}")

print("ts_dataset:")
print(f"\tinp: {ts_dataset.element_spec}")
# Out:
# tr_dataset:
# 	inp: TensorSpec(shape=(None, 7, 24, 8), dtype=tf.float32, name=None)
# 	tar: TensorSpec(shape=(None, 2, 24, 1), dtype=tf.float32, name=None)
# vl_dataset:
# 	inp: TensorSpec(shape=(None, 7, 24, 8), dtype=tf.float32, name=None)
# 	tar: TensorSpec(shape=(None, 2, 24, 1), dtype=tf.float32, name=None)
# ts_dataset:
# 	inp: TensorSpec(shape=(None, None, 48, 8), dtype=tf.float32, name=None)

# %% [markdown]
# ## **Take Samples**

# %%
# for element in tr_dataset.take(1):
#     foo, (bar, qux) = element
#     print(foo.shape, bar.shape, qux.shape)

# %%
# for element in vl_dataset.take(1):
#     foo, (bar, qux) = element
#     print(foo.shape, bar.shape, qux.shape)

# %%
# for element in ts_dataset.take(1):
#     foo = element
#     print(foo.shape)

# %% [markdown]
# # **Define Loss Function**

# %% [markdown]
# Dacon defines the loss as shown below.
#
# $$ L_\tau = maximum(\zeta\tau, \zeta(\tau-1)) $$
#
# However, [the pinball loss of tensorflow-addons](https://www.tensorflow.org/addons/api_docs/python/tfa/losses/pinball_loss) is implemented as follows.
#
# $$ L_\tau = \begin{cases} \zeta\tau & \text{ if } \zeta \geq 0 \\ -\zeta(1-\tau)=\zeta(\tau-1) & \text{ if } \zeta < 0 \end{cases}$$
#
# The description of the symbols used in is as follows.
#
# * $\zeta$ : y_true - y_pred
# * $\tau$ : Quantile values in \[0.1, 0.2, ..., 0.9\]
# * $L_\tau$ : Pinball loss function with $\tau$
#
# The two formulas seem intuitively different, but if you actually divide the interval, you can see that they are the same. However, in experience, it seems to force an underforecast when the evaluation expression of dacon is $\tau=0.1, 0.2$. In fact, for $\tau=0.1, 0.2$, the prediction (blue lines) in the target models mostly overlaps the label (yellow lines) or lies below the graph.

# %% [markdown]
# # **Create Network**

# %% [markdown]
# ## **Autoregressive-ConvLSTM2D Model**

# %%
def create_AR_ConvLSTM2D(
    model_name: str, 
    units: int = 32, 
    out_steps: int = 2,
    dropout_rate: float = 0.4,
) -> tf.keras.Model:
    """Create an Autoregressive-ConvLSTM2D model."""
    
    convlstm2d = tf.keras.layers.ConvLSTM2D(
        units, 3, padding = "same", dropout = dropout_rate, return_state = True)
    reshape = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis = 1), name = "expand_timestamp_dim")
    predict_delta = tf.keras.layers.TimeDistributed(tf.keras.Sequential([
        tf.keras.layers.SpatialDropout1D(dropout_rate),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(HPARAMS.num_features * units, activation = "relu"),
        tf.keras.layers.Dense(1, kernel_initializer = tf.keras.initializers.Zeros())], name = "predict_delta"))
    add = tf.keras.layers.Add(name = "residual_delta_add")
    outputs = []
    
    # Entry flow.
    model_input = tf.keras.layers.Input(shape = HPARAMS.input_shape, dtype = HPARAMS.input_dtype)
    
    x = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis = -1), name = "expand_channel_dim")(model_input)
    x = tf.keras.layers.TimeDistributed(tf.keras.Sequential([
        tf.keras.layers.Conv2D(units, 3, padding = "same", activation = "relu"),
        tf.keras.layers.BatchNormalization()], name = "stem"))(x)
    
    # Warm up.
    residual_seed = tf.keras.layers.Lambda(lambda x: x[:, -1, :, -1:], name = "residual_seed")(model_input)
    
    x, *state = convlstm2d(x)
    outputs.append(add([residual_seed, predict_delta(x)]))
    
    # Middle flow.
    for _ in range(1, out_steps):
        x = reshape(x)
        x, *state = convlstm2d(x, initial_state = state, training = False)
        outputs.append(add([outputs[-1], predict_delta(x)]))
        
    # Exit flow.
    model_output = tf.keras.layers.Lambda(lambda x: tf.stack(x, axis = 1), name = "stack_outputs")(outputs)
    
    return tf.keras.Model(
        inputs = model_input,
        outputs = model_output,
        name = model_name)

# %%
tmp = create_AR_ConvLSTM2D(
    "tmp", 
    units = HPARAMS.units, 
    out_steps = HPARAMS.out_steps,
    dropout_rate = HPARAMS.dropout_rate)

tmp.summary()
# Out:
# Model: "tmp"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_92 (InputLayer)           [(None, 7, 24, 8)]   0
# __________________________________________________________________________________________________
# expand_channel_dim (Lambda)     (None, 7, 24, 8, 1)  0           input_92[0][0]
# __________________________________________________________________________________________________
# time_distributed_183 (TimeDistr (None, 7, 24, 8, 64) 896         expand_channel_dim[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_91 (ConvLSTM2D)    [(None, 24, 8, 64),  295168      time_distributed_183[0][0]
#                                                                  expand_timestamp_dim[0][0]
#                                                                  conv_lst_m2d_91[0][1]
#                                                                  conv_lst_m2d_91[0][2]
# __________________________________________________________________________________________________
# expand_timestamp_dim (Lambda)   (None, 1, 24, 8, 64) 0           conv_lst_m2d_91[0][0]
# __________________________________________________________________________________________________
# residual_seed (Lambda)          (None, 24, 1)        0           input_92[0][0]
# __________________________________________________________________________________________________
# time_distributed_182 (TimeDistr (None, 24, 1)        263169      conv_lst_m2d_91[0][0]
#                                                                  conv_lst_m2d_91[1][0]
# __________________________________________________________________________________________________
# residual_delta_add (Add)        (None, 24, 1)        0           residual_seed[0][0]
#                                                                  time_distributed_182[0][0]
#                                                                  residual_delta_add[0][0]
#                                                                  time_distributed_182[1][0]
# __________________________________________________________________________________________________
# stack_outputs (Lambda)          (None, 2, 24, 1)     0           residual_delta_add[0][0]
#                                                                  residual_delta_add[1][0]
# ==================================================================================================
# Total params: 559,233
# Trainable params: 559,105
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(tmp, show_layer_names = True, show_shapes = False)

# %%
tf.keras.utils.plot_model(tmp, show_shapes = True)

# %%
del tmp

# %% [markdown]
# # **Compile and Fit**

# %%
def get_callbacks(
    model_name: str,
) -> list:
    """Get checkpoint and tensorboard callbacks."""
    
    # Checkpoint callback.
    ckpt_path = os.path.join(
        os.environ["CHECKPOINT_PATH"], os.environ["NOTEBOOKNAME"], 
        model_name, "cp-{epoch:03d}-{val_loss:.4f}.ckpt")
    ckpt_dir = os.path.dirname(ckpt_path)
    os.makedirs(ckpt_dir, exist_ok = True)
    
    cp_callback = tf.keras.callbacks.ModelCheckpoint(
        ckpt_path, verbose = 0, monitor = "val_loss", save_weights_only = True, save_best_only = True)
    
    # TensorBoard callback.
    log_dir = os.path.join(
        "logs", "fit", os.environ["NOTEBOOKNAME"], datetime.datetime.now().strftime(f"{model_name}-%Y%m%d-%H%M%S"))
    tb_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1, update_freq = "batch")
    
    return [cp_callback, tb_callback]
    

def compile_and_fit(
    model: tf.keras.Model, 
    tau: float, 
    tr_dataset: tf.data.Dataset, 
    vl_dataset: tf.data.Dataset, 
    epochs: int,
    lr: float,
    verbose: int = 0, 
) -> dict:
    """Compile and fit the model."""
    
    model.compile(
        loss = tfa.losses.PinballLoss(tau = tau),
        optimizer = tf.keras.optimizers.Adam(lr))
    
    print(f"Model {model.name}...")

    history = model.fit(
        tr_dataset,
        validation_data = vl_dataset,
        epochs = epochs,
        verbose = verbose,
        callbacks = get_callbacks(model.name))

    return history

# %%
# %%time

for tau in np.arange(0.1, 1, 0.1):
    model = create_AR_ConvLSTM2D(
        model_name = f"P{tau:.1f}", 
        units = HPARAMS.units,
        out_steps = HPARAMS.out_steps,
        dropout_rate = HPARAMS.dropout_rate)
    
    _ = compile_and_fit(
        model, 
        tau, 
        tr_dataset, 
        vl_dataset, 
        HPARAMS.epoch,
        HPARAMS.lr,
        verbose = 2)
    
    del model # for save memories
# Out:
# Model P0.1...
# Epoch 1/50
# 14/14 - 5s - loss: 2.6610 - val_loss: 2.2715
# Epoch 2/50
# 14/14 - 1s - loss: 1.7180 - val_loss: 2.1029
# Epoch 3/50
# 14/14 - 1s - loss: 1.5530 - val_loss: 1.7944
# Epoch 4/50
# 14/14 - 1s - loss: 1.5018 - val_loss: 1.6971
# Epoch 5/50
# 14/14 - 1s - loss: 1.4698 - val_loss: 1.5603
# Epoch 6/50
# 14/14 - 1s - loss: 1.4608 - val_loss: 1.5285
# Epoch 7/50
# 14/14 - 1s - loss: 1.4473 - val_loss: 1.4828
# Epoch 8/50
# 14/14 - 1s - loss: 1.4396 - val_loss: 1.4603
# Epoch 9/50
# 14/14 - 1s - loss: 1.4320 - val_loss: 1.4550
# Epoch 10/50
# 14/14 - 2s - loss: 1.4315 - val_loss: 1.4574
# Epoch 11/50
# 14/14 - 1s - loss: 1.4308 - val_loss: 1.4566
# Epoch 12/50
# 14/14 - 1s - loss: 1.4227 - val_loss: 1.4598
# Epoch 13/50
# 14/14 - 1s - loss: 1.4132 - val_loss: 1.4580
# Epoch 14/50
# 14/14 - 1s - loss: 1.4085 - val_loss: 1.4741
# Epoch 15/50
# 14/14 - 1s - loss: 1.4058 - val_loss: 1.4659
# Epoch 16/50
# 14/14 - 1s - loss: 1.4081 - val_loss: 1.4708
# Epoch 17/50
# 14/14 - 1s - loss: 1.3956 - val_loss: 1.4760
# Epoch 18/50
# 14/14 - 1s - loss: 1.3903 - val_loss: 1.5004
# Epoch 19/50
# 14/14 - 1s - loss: 1.3842 - val_loss: 1.4861
# Epoch 20/50
# 14/14 - 1s - loss: 1.3736 - val_loss: 1.4816
# Epoch 21/50
# 14/14 - 1s - loss: 1.3752 - val_loss: 1.4993
# Epoch 22/50
# 14/14 - 1s - loss: 1.3770 - val_loss: 1.4978
# Epoch 23/50
# 14/14 - 1s - loss: 1.3750 - val_loss: 1.4934
# Epoch 24/50
# 14/14 - 1s - loss: 1.3669 - val_loss: 1.4769
# Epoch 25/50
# 14/14 - 1s - loss: 1.3621 - val_loss: 1.4629
# Epoch 26/50
# 14/14 - 1s - loss: 1.3519 - val_loss: 1.4686
# Epoch 27/50
# 14/14 - 1s - loss: 1.3369 - val_loss: 1.4746
# Epoch 28/50
# 14/14 - 1s - loss: 1.3352 - val_loss: 1.4993
# Epoch 29/50
# 14/14 - 1s - loss: 1.3241 - val_loss: 1.4891
# Epoch 30/50
# 14/14 - 1s - loss: 1.3161 - val_loss: 1.4958
# Epoch 31/50
# 14/14 - 1s - loss: 1.3099 - val_loss: 1.5276
# Epoch 32/50
# 14/14 - 1s - loss: 1.3069 - val_loss: 1.5013
# Epoch 33/50
# 14/14 - 1s - loss: 1.2963 - val_loss: 1.5437
# Epoch 34/50
# 14/14 - 1s - loss: 1.2930 - val_loss: 1.4934
# Epoch 35/50
# 14/14 - 1s - loss: 1.2897 - val_loss: 1.5475
# Epoch 36/50
# 14/14 - 1s - loss: 1.2784 - val_loss: 1.5457
# Epoch 37/50
# 14/14 - 1s - loss: 1.2741 - val_loss: 1.5561
# Epoch 38/50
# 14/14 - 1s - loss: 1.2639 - val_loss: 1.5564
# Epoch 39/50
# 14/14 - 1s - loss: 1.2523 - val_loss: 1.5765
# Epoch 40/50
# 14/14 - 1s - loss: 1.2510 - val_loss: 1.6115
# Epoch 41/50
# 14/14 - 1s - loss: 1.2602 - val_loss: 1.6347
# Epoch 42/50
# 14/14 - 1s - loss: 1.2757 - val_loss: 1.6195
# Epoch 43/50
# 14/14 - 1s - loss: 1.3021 - val_loss: 1.4934
# Epoch 44/50
# 14/14 - 1s - loss: 1.2534 - val_loss: 1.4899
# Epoch 45/50
# 14/14 - 1s - loss: 1.2199 - val_loss: 1.5069
# Epoch 46/50
# 14/14 - 1s - loss: 1.2083 - val_loss: 1.5419
# Epoch 47/50
# 14/14 - 1s - loss: 1.1990 - val_loss: 1.5728
# Epoch 48/50
# 14/14 - 1s - loss: 1.2067 - val_loss: 1.5837
# Epoch 49/50
# 14/14 - 1s - loss: 1.2175 - val_loss: 1.5117
# Epoch 50/50
# 14/14 - 1s - loss: 1.2210 - val_loss: 1.5062
# Model P0.2...
# Epoch 1/50
# 14/14 - 5s - loss: 3.0006 - val_loss: 2.9809
# Epoch 2/50
# 14/14 - 1s - loss: 2.5262 - val_loss: 2.8958
# Epoch 3/50
# 14/14 - 1s - loss: 2.4043 - val_loss: 2.6495
# Epoch 4/50
# 14/14 - 1s - loss: 2.3565 - val_loss: 2.5333
# Epoch 5/50
# 14/14 - 1s - loss: 2.3285 - val_loss: 2.4099
# Epoch 6/50
# 14/14 - 1s - loss: 2.3151 - val_loss: 2.3823
# Epoch 7/50
# 14/14 - 1s - loss: 2.3073 - val_loss: 2.3643
# Epoch 8/50
# 14/14 - 1s - loss: 2.2974 - val_loss: 2.3437
# Epoch 9/50
# 14/14 - 1s - loss: 2.2842 - val_loss: 2.3400
# Epoch 10/50
# 14/14 - 1s - loss: 2.2722 - val_loss: 2.3364
# Epoch 11/50
# 14/14 - 1s - loss: 2.2519 - val_loss: 2.3386
# Epoch 12/50
# 14/14 - 1s - loss: 2.2384 - val_loss: 2.3443
# Epoch 13/50
# 14/14 - 1s - loss: 2.2268 - val_loss: 2.3317
# Epoch 14/50
# 14/14 - 1s - loss: 2.2066 - val_loss: 2.3275
# Epoch 15/50
# 14/14 - 1s - loss: 2.1817 - val_loss: 2.3526
# Epoch 16/50
# 14/14 - 1s - loss: 2.1752 - val_loss: 2.3509
# Epoch 17/50
# 14/14 - 1s - loss: 2.1546 - val_loss: 2.3319
# Epoch 18/50
# 14/14 - 1s - loss: 2.1416 - val_loss: 2.3669
# Epoch 19/50
# 14/14 - 1s - loss: 2.1169 - val_loss: 2.3616
# Epoch 20/50
# 14/14 - 1s - loss: 2.0891 - val_loss: 2.4093
# Epoch 21/50
# 14/14 - 1s - loss: 2.0845 - val_loss: 2.3663
# Epoch 22/50
# 14/14 - 1s - loss: 2.0582 - val_loss: 2.3603
# Epoch 23/50
# 14/14 - 1s - loss: 2.0589 - val_loss: 2.3874
# Epoch 24/50
# 14/14 - 1s - loss: 2.0122 - val_loss: 2.4200
# Epoch 25/50
# 14/14 - 1s - loss: 2.0209 - val_loss: 2.3954
# Epoch 26/50
# 14/14 - 1s - loss: 1.9863 - val_loss: 2.4143
# Epoch 27/50
# 14/14 - 1s - loss: 1.9743 - val_loss: 2.4065
# Epoch 28/50
# 14/14 - 1s - loss: 1.9791 - val_loss: 2.4259
# Epoch 29/50
# 14/14 - 1s - loss: 1.9830 - val_loss: 2.4102
# Epoch 30/50
# 14/14 - 1s - loss: 1.9296 - val_loss: 2.4824
# Epoch 31/50
# 14/14 - 1s - loss: 1.9240 - val_loss: 2.4361
# Epoch 32/50
# 14/14 - 1s - loss: 1.8791 - val_loss: 2.5040
# Epoch 33/50
# 14/14 - 1s - loss: 1.8865 - val_loss: 2.4639
# Epoch 34/50
# 14/14 - 1s - loss: 1.8746 - val_loss: 2.5032
# Epoch 35/50
# 14/14 - 1s - loss: 1.8481 - val_loss: 2.5107
# Epoch 36/50
# 14/14 - 1s - loss: 1.8364 - val_loss: 2.5733
# Epoch 37/50
# 14/14 - 1s - loss: 1.8325 - val_loss: 2.5626
# Epoch 38/50
# 14/14 - 1s - loss: 1.8265 - val_loss: 2.6100
# Epoch 39/50
# 14/14 - 1s - loss: 1.8505 - val_loss: 2.5365
# Epoch 40/50
# 14/14 - 1s - loss: 1.9320 - val_loss: 2.4278
# Epoch 41/50
# 14/14 - 1s - loss: 1.8627 - val_loss: 2.4700
# Epoch 42/50
# 14/14 - 1s - loss: 1.7804 - val_loss: 2.4787
# Epoch 43/50
# 14/14 - 1s - loss: 1.8100 - val_loss: 2.4399
# Epoch 44/50
# 14/14 - 1s - loss: 1.7964 - val_loss: 2.4668
# Epoch 45/50
# 14/14 - 1s - loss: 1.7363 - val_loss: 2.5290
# Epoch 46/50
# 14/14 - 1s - loss: 1.7287 - val_loss: 2.5252
# Epoch 47/50
# 14/14 - 1s - loss: 1.7506 - val_loss: 2.4757
# Epoch 48/50
# 14/14 - 1s - loss: 1.7327 - val_loss: 2.4374
# Epoch 49/50
# 14/14 - 1s - loss: 1.7051 - val_loss: 2.4773
# Epoch 50/50
# 14/14 - 1s - loss: 1.6816 - val_loss: 2.5330
# Model P0.3...
# Epoch 1/50
# 14/14 - 5s - loss: 3.1858 - val_loss: 3.1913
# Epoch 2/50
# 14/14 - 1s - loss: 2.9711 - val_loss: 3.1361
# Epoch 3/50
# 14/14 - 1s - loss: 2.8821 - val_loss: 3.0225
# Epoch 4/50
# 14/14 - 1s - loss: 2.8429 - val_loss: 2.9088
# Epoch 5/50
# 14/14 - 1s - loss: 2.8343 - val_loss: 2.9027
# Epoch 6/50
# 14/14 - 1s - loss: 2.7961 - val_loss: 2.8467
# Epoch 7/50
# 14/14 - 1s - loss: 2.7573 - val_loss: 2.7530
# Epoch 8/50
# 14/14 - 1s - loss: 2.7287 - val_loss: 2.7365
# Epoch 9/50
# 14/14 - 1s - loss: 2.7123 - val_loss: 2.7927
# Epoch 10/50
# 14/14 - 1s - loss: 2.6787 - val_loss: 2.7415
# Epoch 11/50
# 14/14 - 1s - loss: 2.6569 - val_loss: 2.7355
# Epoch 12/50
# 14/14 - 1s - loss: 2.6488 - val_loss: 2.7482
# Epoch 13/50
# 14/14 - 1s - loss: 2.6293 - val_loss: 2.7363
# Epoch 14/50
# 14/14 - 1s - loss: 2.6073 - val_loss: 2.7495
# Epoch 15/50
# 14/14 - 1s - loss: 2.5824 - val_loss: 2.7603
# Epoch 16/50
# 14/14 - 1s - loss: 2.5685 - val_loss: 2.7731
# Epoch 17/50
# 14/14 - 1s - loss: 2.5527 - val_loss: 2.7665
# Epoch 18/50
# 14/14 - 1s - loss: 2.5301 - val_loss: 2.7635
# Epoch 19/50
# 14/14 - 1s - loss: 2.4988 - val_loss: 2.7815
# Epoch 20/50
# 14/14 - 1s - loss: 2.4866 - val_loss: 2.7899
# Epoch 21/50
# 14/14 - 1s - loss: 2.4591 - val_loss: 2.7991
# Epoch 22/50
# 14/14 - 1s - loss: 2.4163 - val_loss: 2.8390
# Epoch 23/50
# 14/14 - 1s - loss: 2.4065 - val_loss: 2.8108
# Epoch 24/50
# 14/14 - 1s - loss: 2.3759 - val_loss: 2.8820
# Epoch 25/50
# 14/14 - 1s - loss: 2.3648 - val_loss: 2.8573
# Epoch 26/50
# 14/14 - 1s - loss: 2.3389 - val_loss: 2.8623
# Epoch 27/50
# 14/14 - 1s - loss: 2.3176 - val_loss: 2.8548
# Epoch 28/50
# 14/14 - 1s - loss: 2.2873 - val_loss: 2.8547
# Epoch 29/50
# 14/14 - 1s - loss: 2.2630 - val_loss: 2.8923
# Epoch 30/50
# 14/14 - 1s - loss: 2.2508 - val_loss: 2.9330
# Epoch 31/50
# 14/14 - 1s - loss: 2.2324 - val_loss: 2.8922
# Epoch 32/50
# 14/14 - 1s - loss: 2.2312 - val_loss: 2.8829
# Epoch 33/50
# 14/14 - 1s - loss: 2.2321 - val_loss: 2.8593
# Epoch 34/50
# 14/14 - 1s - loss: 2.1998 - val_loss: 2.9055
# Epoch 35/50
# 14/14 - 1s - loss: 2.1703 - val_loss: 2.9283
# Epoch 36/50
# 14/14 - 1s - loss: 2.1613 - val_loss: 2.8812
# Epoch 37/50
# 14/14 - 1s - loss: 2.1383 - val_loss: 2.9084
# Epoch 38/50
# 14/14 - 1s - loss: 2.1271 - val_loss: 2.9751
# Epoch 39/50
# 14/14 - 1s - loss: 2.1161 - val_loss: 2.8997
# Epoch 40/50
# 14/14 - 1s - loss: 2.0758 - val_loss: 2.9611
# Epoch 41/50
# 14/14 - 1s - loss: 2.0594 - val_loss: 2.9493
# Epoch 42/50
# 14/14 - 1s - loss: 2.0594 - val_loss: 2.9446
# Epoch 43/50
# 14/14 - 1s - loss: 2.0414 - val_loss: 2.9912
# Epoch 44/50
# 14/14 - 1s - loss: 2.0760 - val_loss: 2.9291
# Epoch 45/50
# 14/14 - 1s - loss: 2.0800 - val_loss: 2.9259
# Epoch 46/50
# 14/14 - 1s - loss: 2.1944 - val_loss: 2.7995
# Epoch 47/50
# 14/14 - 1s - loss: 2.1314 - val_loss: 2.7652
# Epoch 48/50
# 14/14 - 1s - loss: 2.0347 - val_loss: 2.8417
# Epoch 49/50
# 14/14 - 1s - loss: 2.0486 - val_loss: 2.8379
# Epoch 50/50
# 14/14 - 1s - loss: 2.0368 - val_loss: 2.8146
# Model P0.4...
# Epoch 1/50
# 14/14 - 5s - loss: 3.2808 - val_loss: 3.2847
# Epoch 2/50
# 14/14 - 1s - loss: 3.1926 - val_loss: 3.2120
# Epoch 3/50
# 14/14 - 1s - loss: 3.1319 - val_loss: 3.0962
# Epoch 4/50
# 14/14 - 1s - loss: 3.0534 - val_loss: 2.9898
# Epoch 5/50
# 14/14 - 1s - loss: 2.9326 - val_loss: 2.9273
# Epoch 6/50
# 14/14 - 1s - loss: 2.8828 - val_loss: 2.9183
# Epoch 7/50
# 14/14 - 1s - loss: 2.8463 - val_loss: 2.8535
# Epoch 8/50
# 14/14 - 1s - loss: 2.8156 - val_loss: 2.8621
# Epoch 9/50
# 14/14 - 1s - loss: 2.7986 - val_loss: 2.8449
# Epoch 10/50
# 14/14 - 2s - loss: 2.7747 - val_loss: 2.8354
# Epoch 11/50
# 14/14 - 1s - loss: 2.7504 - val_loss: 2.8326
# Epoch 12/50
# 14/14 - 1s - loss: 2.7393 - val_loss: 2.8330
# Epoch 13/50
# 14/14 - 1s - loss: 2.7282 - val_loss: 2.8340
# Epoch 14/50
# 14/14 - 1s - loss: 2.7008 - val_loss: 2.8430
# Epoch 15/50
# 14/14 - 1s - loss: 2.6744 - val_loss: 2.8529
# Epoch 16/50
# 14/14 - 1s - loss: 2.6614 - val_loss: 2.8610
# Epoch 17/50
# 14/14 - 1s - loss: 2.6337 - val_loss: 2.8825
# Epoch 18/50
# 14/14 - 1s - loss: 2.6093 - val_loss: 2.9057
# Epoch 19/50
# 14/14 - 1s - loss: 2.5800 - val_loss: 2.9100
# Epoch 20/50
# 14/14 - 1s - loss: 2.5921 - val_loss: 2.8722
# Epoch 21/50
# 14/14 - 1s - loss: 2.5404 - val_loss: 2.9121
# Epoch 22/50
# 14/14 - 1s - loss: 2.5264 - val_loss: 2.9161
# Epoch 23/50
# 14/14 - 1s - loss: 2.5009 - val_loss: 2.9018
# Epoch 24/50
# 14/14 - 1s - loss: 2.4877 - val_loss: 2.9002
# Epoch 25/50
# 14/14 - 1s - loss: 2.4653 - val_loss: 2.9435
# Epoch 26/50
# 14/14 - 1s - loss: 2.4378 - val_loss: 2.9524
# Epoch 27/50
# 14/14 - 1s - loss: 2.4233 - val_loss: 2.9072
# Epoch 28/50
# 14/14 - 1s - loss: 2.4132 - val_loss: 2.9254
# Epoch 29/50
# 14/14 - 1s - loss: 2.3837 - val_loss: 2.9531
# Epoch 30/50
# 14/14 - 1s - loss: 2.3622 - val_loss: 2.9349
# Epoch 31/50
# 14/14 - 1s - loss: 2.3414 - val_loss: 2.9779
# Epoch 32/50
# 14/14 - 1s - loss: 2.3232 - val_loss: 2.9531
# Epoch 33/50
# 14/14 - 2s - loss: 2.3185 - val_loss: 2.9727
# Epoch 34/50
# 14/14 - 1s - loss: 2.3153 - val_loss: 2.9413
# Epoch 35/50
# 14/14 - 1s - loss: 2.3265 - val_loss: 2.9319
# Epoch 36/50
# 14/14 - 1s - loss: 2.3177 - val_loss: 2.9437
# Epoch 37/50
# 14/14 - 1s - loss: 2.3028 - val_loss: 2.8874
# Epoch 38/50
# 14/14 - 1s - loss: 2.2710 - val_loss: 2.9116
# Epoch 39/50
# 14/14 - 1s - loss: 2.2334 - val_loss: 2.9333
# Epoch 40/50
# 14/14 - 1s - loss: 2.2028 - val_loss: 2.9629
# Epoch 41/50
# 14/14 - 2s - loss: 2.2084 - val_loss: 2.9511
# Epoch 42/50
# 14/14 - 1s - loss: 2.1755 - val_loss: 2.9969
# Epoch 43/50
# 14/14 - 1s - loss: 2.1757 - val_loss: 2.9906
# Epoch 44/50
# 14/14 - 1s - loss: 2.1970 - val_loss: 2.9724
# Epoch 45/50
# 14/14 - 1s - loss: 2.1549 - val_loss: 2.9439
# Epoch 46/50
# 14/14 - 1s - loss: 2.1921 - val_loss: 2.9728
# Epoch 47/50
# 14/14 - 1s - loss: 2.3458 - val_loss: 2.9526
# Epoch 48/50
# 14/14 - 1s - loss: 2.2232 - val_loss: 2.9496
# Epoch 49/50
# 14/14 - 1s - loss: 2.2168 - val_loss: 2.9303
# Epoch 50/50
# 14/14 - 1s - loss: 2.1804 - val_loss: 2.9204
# Model P0.5...
# Epoch 1/50
# 14/14 - 5s - loss: 3.3137 - val_loss: 3.3096
# Epoch 2/50
# 14/14 - 1s - loss: 3.2548 - val_loss: 3.1520
# Epoch 3/50
# 14/14 - 1s - loss: 2.9961 - val_loss: 2.8904
# Epoch 4/50
# 14/14 - 1s - loss: 2.8075 - val_loss: 2.8067
# Epoch 5/50
# 14/14 - 2s - loss: 2.7507 - val_loss: 2.7623
# Epoch 6/50
# 14/14 - 1s - loss: 2.7137 - val_loss: 2.7562
# Epoch 7/50
# 14/14 - 1s - loss: 2.6894 - val_loss: 2.7314
# Epoch 8/50
# 14/14 - 1s - loss: 2.6737 - val_loss: 2.7314
# Epoch 9/50
# 14/14 - 1s - loss: 2.6622 - val_loss: 2.7110
# Epoch 10/50
# 14/14 - 1s - loss: 2.6427 - val_loss: 2.7239
# Epoch 11/50
# 14/14 - 1s - loss: 2.6316 - val_loss: 2.7491
# Epoch 12/50
# 14/14 - 1s - loss: 2.6292 - val_loss: 2.7450
# Epoch 13/50
# 14/14 - 1s - loss: 2.6212 - val_loss: 2.7531
# Epoch 14/50
# 14/14 - 1s - loss: 2.6157 - val_loss: 2.7306
# Epoch 15/50
# 14/14 - 1s - loss: 2.5894 - val_loss: 2.7130
# Epoch 16/50
# 14/14 - 1s - loss: 2.5733 - val_loss: 2.7103
# Epoch 17/50
# 14/14 - 1s - loss: 2.5491 - val_loss: 2.7273
# Epoch 18/50
# 14/14 - 1s - loss: 2.5367 - val_loss: 2.7253
# Epoch 19/50
# 14/14 - 1s - loss: 2.5139 - val_loss: 2.7564
# Epoch 20/50
# 14/14 - 1s - loss: 2.4989 - val_loss: 2.7396
# Epoch 21/50
# 14/14 - 1s - loss: 2.4870 - val_loss: 2.7724
# Epoch 22/50
# 14/14 - 1s - loss: 2.4731 - val_loss: 2.7550
# Epoch 23/50
# 14/14 - 1s - loss: 2.4474 - val_loss: 2.7579
# Epoch 24/50
# 14/14 - 1s - loss: 2.4489 - val_loss: 2.7838
# Epoch 25/50
# 14/14 - 1s - loss: 2.4325 - val_loss: 2.8386
# Epoch 26/50
# 14/14 - 1s - loss: 2.3984 - val_loss: 2.8259
# Epoch 27/50
# 14/14 - 1s - loss: 2.3939 - val_loss: 2.8313
# Epoch 28/50
# 14/14 - 1s - loss: 2.3976 - val_loss: 2.7401
# Epoch 29/50
# 14/14 - 2s - loss: 2.3990 - val_loss: 2.7767
# Epoch 30/50
# 14/14 - 1s - loss: 2.3610 - val_loss: 2.8249
# Epoch 31/50
# 14/14 - 2s - loss: 2.3547 - val_loss: 2.7718
# Epoch 32/50
# 14/14 - 1s - loss: 2.3467 - val_loss: 2.7495
# Epoch 33/50
# 14/14 - 1s - loss: 2.3276 - val_loss: 2.8076
# Epoch 34/50
# 14/14 - 2s - loss: 2.2885 - val_loss: 2.8210
# Epoch 35/50
# 14/14 - 2s - loss: 2.2695 - val_loss: 2.7928
# Epoch 36/50
# 14/14 - 1s - loss: 2.2619 - val_loss: 2.8095
# Epoch 37/50
# 14/14 - 1s - loss: 2.2427 - val_loss: 2.8145
# Epoch 38/50
# 14/14 - 1s - loss: 2.2403 - val_loss: 2.8309
# Epoch 39/50
# 14/14 - 1s - loss: 2.2196 - val_loss: 2.8347
# Epoch 40/50
# 14/14 - 1s - loss: 2.2247 - val_loss: 2.8314
# Epoch 41/50
# 14/14 - 1s - loss: 2.2154 - val_loss: 2.8139
# Epoch 42/50
# 14/14 - 1s - loss: 2.2276 - val_loss: 2.8328
# Epoch 43/50
# 14/14 - 1s - loss: 2.2581 - val_loss: 2.7916
# Epoch 44/50
# 14/14 - 1s - loss: 2.1939 - val_loss: 2.8294
# Epoch 45/50
# 14/14 - 1s - loss: 2.1810 - val_loss: 2.8286
# Epoch 46/50
# 14/14 - 1s - loss: 2.1805 - val_loss: 2.7948
# Epoch 47/50
# 14/14 - 1s - loss: 2.1773 - val_loss: 2.8760
# Epoch 48/50
# 14/14 - 1s - loss: 2.1842 - val_loss: 2.8118
# Epoch 49/50
# 14/14 - 1s - loss: 2.2435 - val_loss: 2.8961
# Epoch 50/50
# 14/14 - 1s - loss: 2.2559 - val_loss: 2.8168
# Model P0.6...
# Epoch 1/50
# 14/14 - 5s - loss: 3.2808 - val_loss: 3.2440
# Epoch 2/50
# 14/14 - 1s - loss: 2.8348 - val_loss: 2.6266
# Epoch 3/50
# 14/14 - 1s - loss: 2.4986 - val_loss: 2.4717
# Epoch 4/50
# 14/14 - 2s - loss: 2.4175 - val_loss: 2.4344
# Epoch 5/50
# 14/14 - 1s - loss: 2.3909 - val_loss: 2.3994
# Epoch 6/50
# 14/14 - 1s - loss: 2.3698 - val_loss: 2.3840
# Epoch 7/50
# 14/14 - 1s - loss: 2.3562 - val_loss: 2.3831
# Epoch 8/50
# 14/14 - 1s - loss: 2.3416 - val_loss: 2.3963
# Epoch 9/50
# 14/14 - 1s - loss: 2.3279 - val_loss: 2.3860
# Epoch 10/50
# 14/14 - 1s - loss: 2.3187 - val_loss: 2.3772
# Epoch 11/50
# 14/14 - 1s - loss: 2.3080 - val_loss: 2.3832
# Epoch 12/50
# 14/14 - 1s - loss: 2.2954 - val_loss: 2.3839
# Epoch 13/50
# 14/14 - 1s - loss: 2.2993 - val_loss: 2.4004
# Epoch 14/50
# 14/14 - 1s - loss: 2.2856 - val_loss: 2.3962
# Epoch 15/50
# 14/14 - 1s - loss: 2.2852 - val_loss: 2.3796
# Epoch 16/50
# 14/14 - 1s - loss: 2.2595 - val_loss: 2.3903
# Epoch 17/50
# 14/14 - 1s - loss: 2.2566 - val_loss: 2.3823
# Epoch 18/50
# 14/14 - 1s - loss: 2.2435 - val_loss: 2.3888
# Epoch 19/50
# 14/14 - 1s - loss: 2.2389 - val_loss: 2.3852
# Epoch 20/50
# 14/14 - 1s - loss: 2.2209 - val_loss: 2.4039
# Epoch 21/50
# 14/14 - 1s - loss: 2.2302 - val_loss: 2.4155
# Epoch 22/50
# 14/14 - 1s - loss: 2.2199 - val_loss: 2.4012
# Epoch 23/50
# 14/14 - 1s - loss: 2.2120 - val_loss: 2.4055
# Epoch 24/50
# 14/14 - 1s - loss: 2.2088 - val_loss: 2.3700
# Epoch 25/50
# 14/14 - 1s - loss: 2.2206 - val_loss: 2.3874
# Epoch 26/50
# 14/14 - 1s - loss: 2.2268 - val_loss: 2.4041
# Epoch 27/50
# 14/14 - 1s - loss: 2.1804 - val_loss: 2.4376
# Epoch 28/50
# 14/14 - 1s - loss: 2.1536 - val_loss: 2.4321
# Epoch 29/50
# 14/14 - 1s - loss: 2.1665 - val_loss: 2.4054
# Epoch 30/50
# 14/14 - 1s - loss: 2.1497 - val_loss: 2.3934
# Epoch 31/50
# 14/14 - 1s - loss: 2.1285 - val_loss: 2.4069
# Epoch 32/50
# 14/14 - 1s - loss: 2.1269 - val_loss: 2.4053
# Epoch 33/50
# 14/14 - 1s - loss: 2.1123 - val_loss: 2.4016
# Epoch 34/50
# 14/14 - 1s - loss: 2.1129 - val_loss: 2.4054
# Epoch 35/50
# 14/14 - 1s - loss: 2.1080 - val_loss: 2.4487
# Epoch 36/50
# 14/14 - 1s - loss: 2.0922 - val_loss: 2.4709
# Epoch 37/50
# 14/14 - 1s - loss: 2.0844 - val_loss: 2.4250
# Epoch 38/50
# 14/14 - 1s - loss: 2.0714 - val_loss: 2.3883
# Epoch 39/50
# 14/14 - 1s - loss: 2.0754 - val_loss: 2.3806
# Epoch 40/50
# 14/14 - 1s - loss: 2.0511 - val_loss: 2.4620
# Epoch 41/50
# 14/14 - 1s - loss: 2.0377 - val_loss: 2.4056
# Epoch 42/50
# 14/14 - 1s - loss: 2.0077 - val_loss: 2.4408
# Epoch 43/50
# 14/14 - 1s - loss: 2.0101 - val_loss: 2.4142
# Epoch 44/50
# 14/14 - 1s - loss: 2.0090 - val_loss: 2.4457
# Epoch 45/50
# 14/14 - 2s - loss: 1.9977 - val_loss: 2.4238
# Epoch 46/50
# 14/14 - 1s - loss: 1.9854 - val_loss: 2.4355
# Epoch 47/50
# 14/14 - 1s - loss: 1.9771 - val_loss: 2.4457
# Epoch 48/50
# 14/14 - 1s - loss: 1.9771 - val_loss: 2.4546
# Epoch 49/50
# 14/14 - 1s - loss: 1.9672 - val_loss: 2.4469
# Epoch 50/50
# 14/14 - 1s - loss: 1.9636 - val_loss: 2.4561
# Model P0.7...
# Epoch 1/50
# 14/14 - 5s - loss: 3.2005 - val_loss: 3.0844
# Epoch 2/50
# 14/14 - 2s - loss: 2.5259 - val_loss: 2.3288
# Epoch 3/50
# 14/14 - 1s - loss: 2.1135 - val_loss: 2.0617
# Epoch 4/50
# 14/14 - 2s - loss: 2.0052 - val_loss: 1.9911
# Epoch 5/50
# 14/14 - 1s - loss: 1.9673 - val_loss: 1.9450
# Epoch 6/50
# 14/14 - 1s - loss: 1.9467 - val_loss: 1.9129
# Epoch 7/50
# 14/14 - 1s - loss: 1.9348 - val_loss: 1.9057
# Epoch 8/50
# 14/14 - 1s - loss: 1.9197 - val_loss: 1.8993
# Epoch 9/50
# 14/14 - 1s - loss: 1.9176 - val_loss: 1.8947
# Epoch 10/50
# 14/14 - 1s - loss: 1.9092 - val_loss: 1.8985
# Epoch 11/50
# 14/14 - 1s - loss: 1.9118 - val_loss: 1.9187
# Epoch 12/50
# 14/14 - 1s - loss: 1.8945 - val_loss: 1.9018
# Epoch 13/50
# 14/14 - 1s - loss: 1.8881 - val_loss: 1.8950
# Epoch 14/50
# 14/14 - 1s - loss: 1.8818 - val_loss: 1.8871
# Epoch 15/50
# 14/14 - 1s - loss: 1.8766 - val_loss: 1.9035
# Epoch 16/50
# 14/14 - 1s - loss: 1.8701 - val_loss: 1.8883
# Epoch 17/50
# 14/14 - 1s - loss: 1.8738 - val_loss: 1.8960
# Epoch 18/50
# 14/14 - 1s - loss: 1.8653 - val_loss: 1.8966
# Epoch 19/50
# 14/14 - 1s - loss: 1.8814 - val_loss: 1.9007
# Epoch 20/50
# 14/14 - 1s - loss: 1.8859 - val_loss: 1.8913
# Epoch 21/50
# 14/14 - 1s - loss: 1.8751 - val_loss: 1.9145
# Epoch 22/50
# 14/14 - 1s - loss: 1.8594 - val_loss: 1.9173
# Epoch 23/50
# 14/14 - 1s - loss: 1.8586 - val_loss: 1.9354
# Epoch 24/50
# 14/14 - 1s - loss: 1.8368 - val_loss: 1.9119
# Epoch 25/50
# 14/14 - 2s - loss: 1.8344 - val_loss: 1.9021
# Epoch 26/50
# 14/14 - 1s - loss: 1.8278 - val_loss: 1.8990
# Epoch 27/50
# 14/14 - 1s - loss: 1.8242 - val_loss: 1.8973
# Epoch 28/50
# 14/14 - 1s - loss: 1.8324 - val_loss: 1.8959
# Epoch 29/50
# 14/14 - 1s - loss: 1.8247 - val_loss: 1.9093
# Epoch 30/50
# 14/14 - 1s - loss: 1.8305 - val_loss: 1.8965
# Epoch 31/50
# 14/14 - 1s - loss: 1.8342 - val_loss: 1.9189
# Epoch 32/50
# 14/14 - 1s - loss: 1.8253 - val_loss: 1.9571
# Epoch 33/50
# 14/14 - 1s - loss: 1.8091 - val_loss: 1.9431
# Epoch 34/50
# 14/14 - 1s - loss: 1.8009 - val_loss: 1.9285
# Epoch 35/50
# 14/14 - 1s - loss: 1.7984 - val_loss: 1.9146
# Epoch 36/50
# 14/14 - 1s - loss: 1.7863 - val_loss: 1.9064
# Epoch 37/50
# 14/14 - 1s - loss: 1.7908 - val_loss: 1.9094
# Epoch 38/50
# 14/14 - 1s - loss: 1.7789 - val_loss: 1.9096
# Epoch 39/50
# 14/14 - 1s - loss: 1.7673 - val_loss: 1.9123
# Epoch 40/50
# 14/14 - 1s - loss: 1.7648 - val_loss: 1.9150
# Epoch 41/50
# 14/14 - 1s - loss: 1.7621 - val_loss: 1.9262
# Epoch 42/50
# 14/14 - 1s - loss: 1.7605 - val_loss: 1.9174
# Epoch 43/50
# 14/14 - 2s - loss: 1.7540 - val_loss: 1.9312
# Epoch 44/50
# 14/14 - 2s - loss: 1.7519 - val_loss: 1.9258
# Epoch 45/50
# 14/14 - 1s - loss: 1.7454 - val_loss: 1.9449
# Epoch 46/50
# 14/14 - 2s - loss: 1.7408 - val_loss: 1.9325
# Epoch 47/50
# 14/14 - 1s - loss: 1.7438 - val_loss: 1.9439
# Epoch 48/50
# 14/14 - 1s - loss: 1.7395 - val_loss: 1.9411
# Epoch 49/50
# 14/14 - 1s - loss: 1.7219 - val_loss: 1.9556
# Epoch 50/50
# 14/14 - 1s - loss: 1.7248 - val_loss: 1.9545
# Model P0.8...
# Epoch 1/50
# 14/14 - 5s - loss: 3.0315 - val_loss: 2.6723
# Epoch 2/50
# 14/14 - 1s - loss: 2.1390 - val_loss: 1.8358
# Epoch 3/50
# 14/14 - 1s - loss: 1.6330 - val_loss: 1.5369
# Epoch 4/50
# 14/14 - 1s - loss: 1.5016 - val_loss: 1.4568
# Epoch 5/50
# 14/14 - 1s - loss: 1.4569 - val_loss: 1.4414
# Epoch 6/50
# 14/14 - 1s - loss: 1.4240 - val_loss: 1.3944
# Epoch 7/50
# 14/14 - 1s - loss: 1.4065 - val_loss: 1.3563
# Epoch 8/50
# 14/14 - 1s - loss: 1.3897 - val_loss: 1.3526
# Epoch 9/50
# 14/14 - 1s - loss: 1.3762 - val_loss: 1.3509
# Epoch 10/50
# 14/14 - 1s - loss: 1.3792 - val_loss: 1.3429
# Epoch 11/50
# 14/14 - 1s - loss: 1.3662 - val_loss: 1.3366
# Epoch 12/50
# 14/14 - 1s - loss: 1.3638 - val_loss: 1.3522
# Epoch 13/50
# 14/14 - 1s - loss: 1.3655 - val_loss: 1.3317
# Epoch 14/50
# 14/14 - 1s - loss: 1.3608 - val_loss: 1.3329
# Epoch 15/50
# 14/14 - 1s - loss: 1.3516 - val_loss: 1.3330
# Epoch 16/50
# 14/14 - 1s - loss: 1.3547 - val_loss: 1.3325
# Epoch 17/50
# 14/14 - 1s - loss: 1.3496 - val_loss: 1.3353
# Epoch 18/50
# 14/14 - 1s - loss: 1.3470 - val_loss: 1.3330
# Epoch 19/50
# 14/14 - 1s - loss: 1.3436 - val_loss: 1.3320
# Epoch 20/50
# 14/14 - 2s - loss: 1.3480 - val_loss: 1.3317
# Epoch 21/50
# 14/14 - 1s - loss: 1.3495 - val_loss: 1.3454
# Epoch 22/50
# 14/14 - 1s - loss: 1.3579 - val_loss: 1.3739
# Epoch 23/50
# 14/14 - 1s - loss: 1.3744 - val_loss: 1.3405
# Epoch 24/50
# 14/14 - 2s - loss: 1.3527 - val_loss: 1.3471
# Epoch 25/50
# 14/14 - 1s - loss: 1.3455 - val_loss: 1.3356
# Epoch 26/50
# 14/14 - 1s - loss: 1.3359 - val_loss: 1.3328
# Epoch 27/50
# 14/14 - 1s - loss: 1.3350 - val_loss: 1.3338
# Epoch 28/50
# 14/14 - 1s - loss: 1.3413 - val_loss: 1.3357
# Epoch 29/50
# 14/14 - 1s - loss: 1.3376 - val_loss: 1.3351
# Epoch 30/50
# 14/14 - 1s - loss: 1.3372 - val_loss: 1.3582
# Epoch 31/50
# 14/14 - 1s - loss: 1.3320 - val_loss: 1.3783
# Epoch 32/50
# 14/14 - 1s - loss: 1.3200 - val_loss: 1.3510
# Epoch 33/50
# 14/14 - 1s - loss: 1.3155 - val_loss: 1.3480
# Epoch 34/50
# 14/14 - 1s - loss: 1.3132 - val_loss: 1.3409
# Epoch 35/50
# 14/14 - 1s - loss: 1.3172 - val_loss: 1.3400
# Epoch 36/50
# 14/14 - 1s - loss: 1.3241 - val_loss: 1.3444
# Epoch 37/50
# 14/14 - 1s - loss: 1.3174 - val_loss: 1.3365
# Epoch 38/50
# 14/14 - 1s - loss: 1.3109 - val_loss: 1.3400
# Epoch 39/50
# 14/14 - 1s - loss: 1.3053 - val_loss: 1.3372
# Epoch 40/50
# 14/14 - 1s - loss: 1.2991 - val_loss: 1.3424
# Epoch 41/50
# 14/14 - 1s - loss: 1.2987 - val_loss: 1.3368
# Epoch 42/50
# 14/14 - 1s - loss: 1.2963 - val_loss: 1.3397
# Epoch 43/50
# 14/14 - 1s - loss: 1.2948 - val_loss: 1.3551
# Epoch 44/50
# 14/14 - 1s - loss: 1.2964 - val_loss: 1.3436
# Epoch 45/50
# 14/14 - 1s - loss: 1.2958 - val_loss: 1.3521
# Epoch 46/50
# 14/14 - 1s - loss: 1.2819 - val_loss: 1.3445
# Epoch 47/50
# 14/14 - 1s - loss: 1.2853 - val_loss: 1.3480
# Epoch 48/50
# 14/14 - 1s - loss: 1.2795 - val_loss: 1.3474
# Epoch 49/50
# 14/14 - 1s - loss: 1.2803 - val_loss: 1.3486
# Epoch 50/50
# 14/14 - 1s - loss: 1.2811 - val_loss: 1.3460
# Model P0.9...
# Epoch 1/50
# 14/14 - 5s - loss: 2.7540 - val_loss: 2.0913
# Epoch 2/50
# 14/14 - 1s - loss: 1.6396 - val_loss: 1.3903
# Epoch 3/50
# 14/14 - 1s - loss: 1.1087 - val_loss: 1.0164
# Epoch 4/50
# 14/14 - 1s - loss: 0.9011 - val_loss: 0.8370
# Epoch 5/50
# 14/14 - 1s - loss: 0.8353 - val_loss: 0.7746
# Epoch 6/50
# 14/14 - 1s - loss: 0.8034 - val_loss: 0.7530
# Epoch 7/50
# 14/14 - 1s - loss: 0.7899 - val_loss: 0.7306
# Epoch 8/50
# 14/14 - 1s - loss: 0.7857 - val_loss: 0.7370
# Epoch 9/50
# 14/14 - 1s - loss: 0.7662 - val_loss: 0.7221
# Epoch 10/50
# 14/14 - 1s - loss: 0.7672 - val_loss: 0.7226
# Epoch 11/50
# 14/14 - 1s - loss: 0.7681 - val_loss: 0.7211
# Epoch 12/50
# 14/14 - 1s - loss: 0.7609 - val_loss: 0.7164
# Epoch 13/50
# 14/14 - 1s - loss: 0.7578 - val_loss: 0.7202
# Epoch 14/50
# 14/14 - 1s - loss: 0.7551 - val_loss: 0.7126
# Epoch 15/50
# 14/14 - 1s - loss: 0.7615 - val_loss: 0.7245
# Epoch 16/50
# 14/14 - 1s - loss: 0.7627 - val_loss: 0.7289
# Epoch 17/50
# 14/14 - 1s - loss: 0.7618 - val_loss: 0.7237
# Epoch 18/50
# 14/14 - 2s - loss: 0.7557 - val_loss: 0.7180
# Epoch 19/50
# 14/14 - 1s - loss: 0.7538 - val_loss: 0.7265
# Epoch 20/50
# 14/14 - 1s - loss: 0.7423 - val_loss: 0.7230
# Epoch 21/50
# 14/14 - 1s - loss: 0.7422 - val_loss: 0.7114
# Epoch 22/50
# 14/14 - 1s - loss: 0.7439 - val_loss: 0.7109
# Epoch 23/50
# 14/14 - 1s - loss: 0.7445 - val_loss: 0.7134
# Epoch 24/50
# 14/14 - 1s - loss: 0.7439 - val_loss: 0.7194
# Epoch 25/50
# 14/14 - 1s - loss: 0.7387 - val_loss: 0.7148
# Epoch 26/50
# 14/14 - 1s - loss: 0.7417 - val_loss: 0.7118
# Epoch 27/50
# 14/14 - 1s - loss: 0.7339 - val_loss: 0.7098
# Epoch 28/50
# 14/14 - 1s - loss: 0.7342 - val_loss: 0.7078
# Epoch 29/50
# 14/14 - 1s - loss: 0.7376 - val_loss: 0.7155
# Epoch 30/50
# 14/14 - 1s - loss: 0.7345 - val_loss: 0.7153
# Epoch 31/50
# 14/14 - 1s - loss: 0.7368 - val_loss: 0.7203
# Epoch 32/50
# 14/14 - 1s - loss: 0.7338 - val_loss: 0.7166
# Epoch 33/50
# 14/14 - 1s - loss: 0.7327 - val_loss: 0.7205
# Epoch 34/50
# 14/14 - 1s - loss: 0.7365 - val_loss: 0.7246
# Epoch 35/50
# 14/14 - 1s - loss: 0.7290 - val_loss: 0.7252
# Epoch 36/50
# 14/14 - 1s - loss: 0.7349 - val_loss: 0.7259
# Epoch 37/50
# 14/14 - 1s - loss: 0.7350 - val_loss: 0.7316
# Epoch 38/50
# 14/14 - 1s - loss: 0.7329 - val_loss: 0.7259
# Epoch 39/50
# 14/14 - 1s - loss: 0.7309 - val_loss: 0.7372
# Epoch 40/50
# 14/14 - 1s - loss: 0.7211 - val_loss: 0.7452
# Epoch 41/50
# 14/14 - 2s - loss: 0.7252 - val_loss: 0.7415
# Epoch 42/50
# 14/14 - 1s - loss: 0.7208 - val_loss: 0.7345
# Epoch 43/50
# 14/14 - 1s - loss: 0.7185 - val_loss: 0.7253
# Epoch 44/50
# 14/14 - 1s - loss: 0.7136 - val_loss: 0.7217
# Epoch 45/50
# 14/14 - 1s - loss: 0.7138 - val_loss: 0.7162
# Epoch 46/50
# 14/14 - 1s - loss: 0.7135 - val_loss: 0.7212
# Epoch 47/50
# 14/14 - 1s - loss: 0.7207 - val_loss: 0.7227
# Epoch 48/50
# 14/14 - 1s - loss: 0.7153 - val_loss: 0.7114
# Epoch 49/50
# 14/14 - 1s - loss: 0.7159 - val_loss: 0.7079
# Epoch 50/50
# 14/14 - 1s - loss: 0.7164 - val_loss: 0.7075
# CPU times: user 14min 13s, sys: 36.4 s, total: 14min 50s
# Wall time: 11min 29s

# %%
# %tensorboard --logdir logs/fit --host jupyter-server --port 6007

# %% [markdown]
# ## **Make Clean Checkpoints**

# %%
# %%time

ckpt_folders = sorted(glob.glob(os.path.join(os.environ["CHECKPOINT_PATH"], os.environ["NOTEBOOKNAME"], "P*")))

num_rm_files = 0
rm_files_sz = 0 # bytes

for f in ckpt_folders:
    # At least 7 files must be located in ckpt_folders. (latest 3 (ckpt-index, ckpt-data) pairs and checkpoint file)
    assert len(os.listdir(f)) >= (1 + HPARAMS.max_to_keep * 2), f"Checkpoints in {f} is less then 3 (max_to_keep)."
    
    rm_files = [os.path.join(f, i) for i in sorted(os.listdir(f))[1:-2*HPARAMS.max_to_keep]] # [1:-6]
    num_rm_files += len(rm_files)
    rm_files_sz += sum([os.path.getsize(rm_file) for rm_file in rm_files])
    
    _ = [os.remove(rm_file) for rm_file in rm_files]
    
print(f"{num_rm_files} files removed.")
print(f"{rm_files_sz / 2**20:.2f}MB saved.")
# Out:
# 138 files removed.
# 442.13MB saved.
# CPU times: user 0 ns, sys: 31.4 ms, total: 31.4 ms
# Wall time: 30.7 ms

# %% [markdown]
# # **Visualize**

# %% [markdown]
# ## **Plot Histories**

# %%
# def draw_histories(
#     histories: dict,
# ):
#     """Draw 9 histories in one plot."""
    
#     assert len(histories.keys()) == HPARAMS.num_quantile
    
#     plt.figure(figsize = (18, 14), facecolor = "white", dpi = 96)

#     for model_name, history in histories.items():
#         pos = int(model_name.split(".")[-1])
#         plt.subplot(3, 3, pos)
                
# #         plt.plot(history.epoch, history.history["aux_loss"], c = "r", label = "aux_loss")
#         plt.plot(history.epoch, history.history["real_loss"], c = "r", ls = "--", label = "real_loss")
# #         plt.plot(history.epoch, history.history["val_aux_loss"], c = "navy", label = "val_aux_loss")
#         plt.plot(history.epoch, history.history["val_real_loss"], c = "navy", ls = "--", label = "val_real_loss")
    
#         plt.legend(loc = "upper left")
#         plt.title(model_name, fontsize = 20)
#         plt.xlabel("Epoch")
#         plt.ylabel("Pinball Loss")
    
#         plt.grid(True)
        
#     plt.tight_layout()
#     plt.show()

# %%
# draw_histories(histories)

# %% [markdown]
# ## **Target Model Prediction**

# %%
def load_latest_models(
    ckpt_folders: list,
) -> list:
    """Load latest weights of target model from saved ckeckpoints."""   
    
    models = []
    val_losses = []
    
    for f in ckpt_folders:
        latest = tf.train.latest_checkpoint(f)
        print(f"Load latest checkpoints: {latest}...")
        
        model_name = latest.split(os.path.sep)[-2] # ckpt/[notebookname]/P0.1/...
        val_loss = np.float32(latest.split(os.path.sep)[-1].split("-")[2][:6])

        # Define a new AR-LSTM model and load checkpoints.
        model = create_AR_ConvLSTM2D(model_name = model_name, units = 64)

        ckpt = tf.train.Checkpoint(model)
        ckpt.restore(latest).expect_partial()
        models.append(model)
        
        val_losses.append(val_loss)
        
    return models, val_losses


def draw_pred(
    inputs, 
    y_preds, 
    y_true, 
    save_fig = False,
):
    """Draw the predictions and labels."""
    
    plt.figure(figsize = (14, 4 * HPARAMS.num_quantile), facecolor = "white")
    
    for i, (y_pred, tau) in enumerate(zip(y_preds, np.arange(0.1, 1, 0.1))):
        plt.subplot(9, 1, i + 1)
        
        plt.plot(np.arange(len(inputs)), inputs, lw = 1.5, label = "Inputs")
        plt.plot(np.arange(len(inputs), len(inputs) + len(y_pred), 1), y_pred, marker = "o", lw = 1.5, label = "Predictions")
        plt.plot(np.arange(len(inputs), len(inputs) + len(y_true), 1), y_true, marker = "X", lw = 1.5, label = "Label")
    
        plt.title(f"Target Model T{tau:.1f}")
        plt.xlabel("Time [half day]")
        plt.ylabel("Target")
        plt.ylim([-0.8, max(y_true) * 1.1])
        plt.legend()

        plt.xticks(
            np.arange(0, (HPARAMS.w_inp + HPARAMS.w_tar) * HPARAMS.real_day + 1, HPARAMS.real_day), 
            [f"D+{i}" for i in np.arange(HPARAMS.w_inp + HPARAMS.w_tar + 1)])
        plt.grid(True)
        
    plt.tight_layout()
    
    if save_fig:
        plt.savefig(os.path.join("pngs", f"{os.environ['NOTEBOOKNAME']}.png"), dpi = 96)
        
    plt.show()

# %%
# Restore latest models from saved checkpoints.
ckpt_folders = sorted(glob.glob(os.path.join(os.environ["CHECKPOINT_PATH"], os.environ["NOTEBOOKNAME"], "P*")))
models, val_losses = load_latest_models(ckpt_folders)

print(f"Averaged Validation Loss: {np.mean(val_losses):.4f}")

# Now, unbatch the dataset to predict only one sequences (i.e. 7 days).
unbatched_vl_dataset = vl_dataset.unbatch().batch(1)

num_skip = 0
for t in unbatched_vl_dataset.skip(num_skip).take(1):
    x, r_y = t # inp, aux_tar, real_tar
    
    draw_pred(
        inputs = vl_tensor[num_skip * HPARAMS.w_inp * HPARAMS.real_day:(num_skip + 1) * HPARAMS.w_inp * HPARAMS.real_day, -1][::2], # not x
        y_preds = [tf.reshape(model.predict(x), (-1, )).numpy() for model in models],
        y_true = tf.reshape(r_y, (-1, )))
# Out:
# Load latest checkpoints: ckpt/try163/P0.1/cp-009-1.4550.ckpt...
# Load latest checkpoints: ckpt/try163/P0.2/cp-014-2.3275.ckpt...
# Load latest checkpoints: ckpt/try163/P0.3/cp-011-2.7355.ckpt...
# Load latest checkpoints: ckpt/try163/P0.4/cp-011-2.8326.ckpt...
# Load latest checkpoints: ckpt/try163/P0.5/cp-016-2.7103.ckpt...
# Load latest checkpoints: ckpt/try163/P0.6/cp-024-2.3700.ckpt...
# Load latest checkpoints: ckpt/try163/P0.7/cp-014-1.8871.ckpt...
# Load latest checkpoints: ckpt/try163/P0.8/cp-013-1.3317.ckpt...
# Load latest checkpoints: ckpt/try163/P0.9/cp-050-0.7075.ckpt...
# Averaged Validation Loss: 2.0397
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb0b412e400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb09c4859d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb09c10af28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb064313620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb0842b6bf8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb0845eb268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb0842b6400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb08441c510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c34b400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# # **Make Submissions**

# %%
# %%time
# Restore latest models from saved checkpoints.
ckpt_folders = sorted(glob.glob(os.path.join(os.environ["CHECKPOINT_PATH"], os.environ["NOTEBOOKNAME"], "P*")))
models, _ = load_latest_models(ckpt_folders)

# Predict the test datasets.
# We need to drop auxiliary outputs and squeeze dimensions (i.e. [batch, 96, 1] => [batch, 96]).
preds = [np.array(tf.reshape(model.predict(ts_dataset)[-1], (-1, ))) for model in models]

# %%
submission = pd.read_csv(os.path.join(os.environ["LOCAL_DATA_PATH"], "sample_submission.csv"), index_col = "id")
submission.head()

# %%
for column, pred in zip(submission.columns, preds):
    foo = np.reshape(pred, (-1,))
    foo = np.where(foo < HPARAMS.epsilon, 0, foo) # clip by value
    
    submission[column] = foo

# %%
submission.head()

# %%
submission.to_csv(os.path.join(os.environ["SUBMISSION_PATH"], f"{os.environ['NOTEBOOKNAME']}_submission.csv"))

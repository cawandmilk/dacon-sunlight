# %% [markdown]
# # **Default Setting**
#
# * Python: 3.6.9
# * ML Framework: tensorflow-gpu 2.4.0 / tensorflow-addons 0.12.0
# * CPU: AMD Ryzen 5 5600X 6-Core Processor
# * GPU: GeForce RTX 3070 (8G) (CUDA 11.1)
# * RAM: 32G
# * Platform: Linux Ubuntu 20.04 LTS (desktop)
#
# Install below APIs using anaconda as belows.
#
# ```
# conda create -n py36 python=3.6.9
# conda acitvate py36
# pip3 install tensorflow-gpu=2.4.0 tensorflow-addons=0.12.0
# conda install pandas, matplotlib, pydot, jupyterlab, cudatoolkit
# ```
#
# And now, you can run jupyter lab (or jupyter notebook).
#
# ```
# jupyter lab
# ```

# %%
# %env NOTEBOOKNAME try158
# %env LOCAL_DATA_PATH data
# %env CHECKPOINT_PATH ckpt
# %env SUBMISSION_PATH submission
# Out:
# env: NOTEBOOKNAME=try158
# env: LOCAL_DATA_PATH=data
# env: CHECKPOINT_PATH=ckpt
# env: SUBMISSION_PATH=submission

# %%
import tensorflow as tf
import tensorflow_addons as tfa

import datetime
import glob
import os

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

print(f"tf.__version__: {tf.__version__}")
print(f"tfa.__version__: {tfa.__version__}")
# Out:
# tf.__version__: 2.4.0
# tfa.__version__: 0.12.0

# %%
# If you wanna avoid below error, you need to run below codes when you start kernel.

# UnknownError: Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, 
# so try looking to see if a warning log message was printed above. [Op:Conv2D]

# Ref: https://blog.naver.com/vft1500/221793591386

gpus = tf.config.list_physical_devices("GPU")
if gpus:
    try:
    # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices("GPU")
        print(f"{len(gpus)} Physical GPUs, {len(logical_gpus)} Logical GPUs.")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs.

# %%
# !python -V

# %%
# !cat /proc/cpuinfo

# %%
# !nvidia-smi
# Out:
# Sat Jan  9 14:51:04 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.32.00    Driver Version: 455.32.00    CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Graphics Device     On   | 00000000:0A:00.0 Off |                  N/A |
# |  0%   29C    P2    29W / 220W |    373MiB /  7979MiB |      4%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A       901      G   /usr/lib/xorg/Xorg                 56MiB |
# |    0   N/A  N/A      1047      G   /usr/bin/gnome-shell                9MiB |
# |    0   N/A  N/A     13757      C   ...nda3/envs/py36/bin/python      303MiB |
# +-----------------------------------------------------------------------------+

# %%
# !df -h

# %%
# !free -h
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:           31Gi       1.3Gi        25Gi        11Mi       4.3Gi        29Gi
# Swap:         2.0Gi          0B       2.0Gi

# %%
# Load the TensorBoard notebook extension.
# %load_ext tensorboard

# %% [markdown]
# # **Define Arguments**

# %%
class HParams(object):
    def __init__(self):
        # Basic
        self.seed = 42
        self.test_size = 0.2
        self.epoch = 50
        self.lr = 1e-3
        
        # Dataframe
        self.feature_dict = {}
        self.num_test_csv = 81
        self.day_split = 1
        self.day = 48
        self.inp = 7
        self.tar = 2
        
        # Dataset Pipeline
        self.w_inp = self.inp * self.day
        self.w_tar = self.tar * self.day
        self.w_shift = self.day
        self.w_stride = 1
        self.w_dr = True
        
        self.shuffle_buffer_sz = 100_000
        
        self.auto = tf.data.experimental.AUTOTUNE
        
        self.global_batch_size = 128
        
        # model
        self.num_features = 8
        self.num_quantile = 9
        
        self.input_shape = [self.inp, self.day, self.num_features]
        self.input_dtype = tf.float32
        self.units = 64
        self.out_steps = self.tar
        self.dropout_rate = 0.4
        
        # Remove checkpoints.
        self.max_to_keep = 3
        
        # Post-processing.
#         self.epsilon = 5e-2 # almost min(df["TARGET"]) / 2
        
        
HPARAMS = HParams()

# %% [markdown]
# # **Load Datasets**

# %% [markdown]
# ## **Define Preprocessing Funciton**

# %%
def preprocessing(
    df: pd.DataFrame, 
    is_training: bool = True
) -> pd.DataFrame:
    """Preprocess dataframes without any normalize."""
    
    # Timestamp to signals.
    time = 2 * np.int64(df["Hour"]) + (np.int64(df["Minute"]) // 30)
    df.insert(loc = 0, column = "Time", value = time)
    
    day_sin = np.sin(df["Time"] * (2 * np.pi / HPARAMS.day))
    day_cos = np.cos(df["Time"] * (2 * np.pi / HPARAMS.day))
        
    df.insert(loc = 0, column = "DAY_SIN", value = day_sin)
    df.insert(loc = 1, column = "DAY_COS", value = day_cos)
    
    df = df.drop(["Day", "Hour", "Minute", "Time"], axis = 1)
    
#     for column in df.columns:
#         if is_training:
#             HPARAMS.feature_dict[f"{column}_MEAN"] = np.float32(df[column].mean())
#             HPARAMS.feature_dict[f"{column}_STD"] = np.float32(df[column].std())
        
#         df[column] = (df[column] - HPARAMS.feature_dict[f"{column}_MEAN"]) \
#             / HPARAMS.feature_dict[f"{column}_STD"]
    
    return df

# %% [markdown]
# ## **Train & Validation Dataframes**

# %%
df = pd.read_csv(os.path.join(os.environ["LOCAL_DATA_PATH"], "train", "train.csv"))
df.head(n = 10)
# Out:
#    Day  Hour  Minute  DHI  DNI   WS     RH   T  TARGET
# 0    0     0       0    0    0  1.5  69.08 -12     0.0
# 1    0     0      30    0    0  1.5  69.06 -12     0.0
# 2    0     1       0    0    0  1.6  71.78 -12     0.0
# 3    0     1      30    0    0  1.6  71.75 -12     0.0
# 4    0     2       0    0    0  1.6  75.20 -12     0.0
# 5    0     2      30    0    0  1.5  69.29 -11     0.0
# 6    0     3       0    0    0  1.5  72.56 -11     0.0
# 7    0     3      30    0    0  1.4  72.55 -11     0.0
# 8    0     4       0    0    0  1.3  74.62 -11     0.0
# 9    0     4      30    0    0  1.3  74.61 -11     0.0

# %%
# Forces the length of train and test data to be a multiple of the day.
HPARAMS.split_len = int(df.shape[0] * (1. - HPARAMS.test_size))
HPARAMS.split_len = HPARAMS.split_len - (HPARAMS.split_len % HPARAMS.day)

tr_df = df[:HPARAMS.split_len]
vl_df = df[HPARAMS.split_len:]

HPARAMS.epsilon = np.float32(tr_df["TARGET"][tr_df["TARGET"] > 0].min() * 0.9)

tr_df = preprocessing(tr_df)
vl_df = preprocessing(vl_df, is_training = False)

print(f"tr_df.shape: {tr_df.shape}, columns: {','.join(tr_df.columns)}")
print(f"vl_df.shape: {vl_df.shape}, columns: {','.join(vl_df.columns)}")
# Out:
# tr_df.shape: (42048, 8), columns: DAY_SIN,DAY_COS,DHI,DNI,WS,RH,T,TARGET
# vl_df.shape: (10512, 8), columns: DAY_SIN,DAY_COS,DHI,DNI,WS,RH,T,TARGET

# %% [markdown]
# ## **Test Dataframe**

# %%
ts_filenames = [os.path.join(os.environ["LOCAL_DATA_PATH"], "test", f"{i}.csv") for i in range(HPARAMS.num_test_csv)]
ts_dfs = [preprocessing(pd.read_csv(ts_filename), is_training = False) for ts_filename in ts_filenames]
ts_df = pd.concat(ts_dfs)

print(f"ts_df.shape: {ts_df.shape}, columns: {','.join(ts_df.columns)}")
# Out:
# ts_df.shape: (27216, 8), columns: DAY_SIN,DAY_COS,DHI,DNI,WS,RH,T,TARGET

# %% [markdown]
# # **Make Dataset Pipelines**
#
# The first batch is to bundle the tensors as input into units of a day. The operation below can guarantee that the number of sequences of tr_tensor and vl_tensor is a multiple of a day (i.e. 48), so `drop_remainder = True` is actually meaningless. However, it was added to specify the shape of the input data during the window division process (`.window(...)`)
#
# ```
# args["SPLIT_LEN"] = int(df.shape[0] * (1. - args["TEST_SIZE"]))
# args["SPLIT_LEN"] = args["SPLIT_LEN"] - np.mod(args["SPLIT_LEN"], args["DAY"]) # this process
#
# tr_df = df[:args["SPLIT_LEN"]]
# vl_df = df[args["SPLIT_LEN"]:]
# ```
#
# It is recommended to cache the dataset after the map transformation except if this transformation makes the data too big to fit in memory. A trade-off can be achieved if your mapped function can be split in two parts: a time consuming one and a memory consuming part. In this case, you can chain your transformations like below:
#
# ```
# dataset.map(time_consuming_mapping).cache().map(memory_consuming_mapping)
# ```
#
# If the cache is executed after partioning the window, the amount of data loaded in the memory increases by about 9 times (=`(W_INP + W_TAR) / W_STRIDE)`. Obviously, the mapping process comsumes a lot of time, but since we have to train a model like this 9 times, it would be desirable to load it into the cache mory before the window split.
#
# Also `cache` produce exactly the same elements during each iteration through the dataset. If you wish to randomize the iteration order, make sure to call `shuffle` after calling `cache`.
#
# Immediately after the window is splited, the mapping function `_split_window` is called after stacking with `GLOBAL_BATCH_SIZE`. This time, the vectorized mapping function is called once and applies to a batch of sample. While the function could takes more time to execute, the overhead appear only once, improving the overall time performance.
#
# *References*
#    * *https://www.tensorflow.org/guide/data_performance*
#    * *https://www.tensorflow.org/api_docs/python/tf/data/Dataset*

# %%
@tf.function
def _flat_fn_tr(x):
    return x.batch(HPARAMS.w_inp + HPARAMS.w_tar)


@tf.function
def _flat_fn_ts(x):
    return x.batch(HPARAMS.w_inp)


@tf.function
def _reshape_tr(features):
    return tf.reshape(features, (-1, HPARAMS.inp + HPARAMS.tar, HPARAMS.day, HPARAMS.num_features))


@tf.function
def _reshape_ts(features):
    return tf.reshape(features, (-1, HPARAMS.inp, HPARAMS.day, HPARAMS.num_features))


@tf.function
def _split_window_tr(features):
    """
        input:  (batch, 9, 48, 8)
        output: (batch, 7, 48, 8), (aux: (batch, 2, 48, 1), real: (batch, 2, 48, 1))
    """
    inp, tar = tf.split(features, [HPARAMS.inp, HPARAMS.tar], axis = 1)
    _, tar = tf.split(tar, [-1, 1], axis = -1)
    
    return inp, tar

# %%
# Dataframe to tensor. (TARGET column located on axis = -1)
tr_tensor = tf.constant(tr_df, dtype = tf.float32)
vl_tensor = tf.constant(vl_df, dtype = tf.float32)
ts_tensor = tf.constant(ts_df, dtype = tf.float32)

# Tensor to dataset.
tr_dataset = tf.data.Dataset.from_tensor_slices(tr_tensor
                    ).window(HPARAMS.w_inp + HPARAMS.w_tar, HPARAMS.w_shift, HPARAMS.w_stride, HPARAMS.w_dr).flat_map(_flat_fn_tr
                    ).cache(
                    ).shuffle(HPARAMS.shuffle_buffer_sz, reshuffle_each_iteration = True
                    ).batch(HPARAMS.global_batch_size
                    ).map(_reshape_tr, num_parallel_calls = HPARAMS.auto
                    ).map(_split_window_tr, num_parallel_calls = HPARAMS.auto
                    ).prefetch(HPARAMS.auto)
                                                
vl_dataset = tf.data.Dataset.from_tensor_slices(vl_tensor
                    ).window(HPARAMS.w_inp + HPARAMS.w_tar, HPARAMS.w_shift, HPARAMS.w_stride, HPARAMS.w_dr).flat_map(_flat_fn_tr
                    ).cache(
#                     ).shuffle(HPARAMS.shuffle_buffer_sz, reshuffle_each_iteration = True
                    ).batch(HPARAMS.global_batch_size
                    ).map(_reshape_tr, num_parallel_calls = HPARAMS.auto
                    ).map(_split_window_tr, num_parallel_calls = HPARAMS.auto
                    ).prefetch(HPARAMS.auto)

ts_dataset = tf.data.Dataset.from_tensor_slices(ts_tensor
                    ).window(HPARAMS.w_inp, HPARAMS.w_inp, 1, HPARAMS.w_dr).flat_map(_flat_fn_ts
                    ).cache(
#                     ).shuffle(HPARAMS.shuffle_buffer_sz, reshuffle_each_iteration = True
                    ).batch(HPARAMS.num_test_csv # not HPARAMS.global_batch_size
                    ).map(_reshape_ts, num_parallel_calls = HPARAMS.auto
                    ).prefetch(HPARAMS.auto)

# Print the shapes.
print("tr_dataset:")
print(f"\tinp: {tr_dataset.element_spec[0]}")
print(f"\ttar: {tr_dataset.element_spec[1]}")

print("vl_dataset:")
print(f"\tinp: {vl_dataset.element_spec[0]}")
print(f"\ttar: {vl_dataset.element_spec[1]}")

print("ts_dataset:")
print(f"\tinp: {ts_dataset.element_spec}")
# Out:
# tr_dataset:
# 	inp: TensorSpec(shape=(None, 7, 48, 8), dtype=tf.float32, name=None)
# 	tar: TensorSpec(shape=(None, 2, 48, 1), dtype=tf.float32, name=None)
# vl_dataset:
# 	inp: TensorSpec(shape=(None, 7, 48, 8), dtype=tf.float32, name=None)
# 	tar: TensorSpec(shape=(None, 2, 48, 1), dtype=tf.float32, name=None)
# ts_dataset:
# 	inp: TensorSpec(shape=(None, 7, 48, 8), dtype=tf.float32, name=None)

# %% [markdown]
# ## **Take Samples**

# %%
# for element in tr_dataset.take(1):
#     foo, (bar, qux) = element
#     print(foo.shape, bar.shape, qux.shape)

# %%
# for element in vl_dataset.take(1):
#     foo, (bar, qux) = element
#     print(foo.shape, bar.shape, qux.shape)

# %%
# for element in ts_dataset.take(1):
#     foo = element
#     print(foo.shape)

# %% [markdown]
# # **Define Loss Function**

# %% [markdown]
# Dacon defines the loss as shown below.
#
# $$ L_\tau = maximum(\zeta\tau, \zeta(\tau-1)) $$
#
# However, [the pinball loss of tensorflow-addons](https://www.tensorflow.org/addons/api_docs/python/tfa/losses/pinball_loss) is implemented as follows.
#
# $$ L_\tau = \begin{cases} \zeta\tau & \text{ if } \zeta \geq 0 \\ -\zeta(1-\tau)=\zeta(\tau-1) & \text{ if } \zeta < 0 \end{cases}$$
#
# The description of the symbols used in is as follows.
#
# * $\zeta$ : y_true - y_pred
# * $\tau$ : Quantile values in \[0.1, 0.2, ..., 0.9\]
# * $L_\tau$ : Pinball loss function with $\tau$
#
# The two formulas seem intuitively different, but if you actually divide the interval, you can see that they are the same. However, in experience, it seems to force an underforecast when the evaluation expression of dacon is $\tau=0.1, 0.2$. In fact, for $\tau=0.1, 0.2$, the prediction (blue lines) in the target models mostly overlaps the label (yellow lines) or lies below the graph.

# %% [markdown]
# # **Create Network**

# %% [markdown]
# ## **Autoregressive-ConvLSTM2D Model**

# %%
def create_AR_ConvLSTM2D(
    model_name: str, 
    units: int = 32, 
    out_steps: int = 2,
    dropout_rate: float = 0.4,
) -> tf.keras.Model:
    """Create an Autoregressive-ConvLSTM2D model."""
    
    convlstm2d = tf.keras.layers.ConvLSTM2D(
        units, 3, padding = "same", dropout = dropout_rate, return_state = True)
    reshape = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis = 1), name = "expand_timestamp_dim")
    
    # (batch, 48, 8, 64) -> (batch, 48, 8)
    predict_features = tf.keras.layers.TimeDistributed(tf.keras.Sequential([
        tf.keras.layers.Dense(2 * units, activation = "relu"),
        tf.keras.layers.Dense(1, kernel_initializer = tf.keras.initializers.Zeros()),
        tf.keras.layers.Reshape((-1,))], name = "predict_features"))
    # (batch, 48, 8) -> (batch, 48, 1)
    predict_target = tf.keras.layers.TimeDistributed(tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation = "relu"),
        tf.keras.layers.Dense(1, kernel_initializer = tf.keras.initializers.Zeros())], name = "predict_target"))
    
    add_1 = tf.keras.layers.Add(name = "add_residual_features_delta")
    add_2 = tf.keras.layers.Add(name = "add_residual_target_delta")
    
    features_outputs, target_outputs = [], []
    
    # Entry flow.
    model_input = tf.keras.layers.Input(shape = HPARAMS.input_shape, dtype = HPARAMS.input_dtype)
    
    x = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis = -1), name = "expand_channel_dim")(model_input)
    x = tf.keras.layers.TimeDistributed(tf.keras.Sequential([
        tf.keras.layers.Conv2D(units, 3, padding = "same", activation = "relu"),
        tf.keras.layers.BatchNormalization()], name = "stem"))(x)
    
    # Warm up.
    residual_features_seed = tf.keras.layers.Lambda(
        lambda x: x[:, -1, ...], name = "residual_features_seed")(model_input)
    residual_target_seed = tf.keras.layers.Lambda(
        lambda x: x[:, -1, :, -1:], name = "residual_target_seed")(model_input)
    
    x, *state = convlstm2d(x)
    features_outputs.append(add_1([residual_features_seed, predict_features(x)]))
    target_outputs.append(add_2([residual_target_seed, predict_target(features_outputs[-1])]))
    
    # Middle flow.
    for _ in range(1, out_steps):
        x = reshape(x)
        x, *state = convlstm2d(x, initial_state = state, training = False)

        features_outputs.append(add_1([features_outputs[-1], predict_features(x)]))
        target_outputs.append(add_2([target_outputs[-1], predict_target(features_outputs[-1])]))
        
    # Exit flow.
    model_output = tf.keras.layers.Lambda(
        lambda x: tf.stack(x, axis = 1), name = "stack_outputs")(target_outputs)
    
    return tf.keras.Model(
        inputs = model_input,
        outputs = model_output,
        name = model_name)

# %%
tmp = create_AR_ConvLSTM2D(
    "tmp", 
    units = HPARAMS.units, 
    out_steps = HPARAMS.out_steps,
    dropout_rate = HPARAMS.dropout_rate)

tmp.summary()
# Out:
# Model: "tmp"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 7, 48, 8)]   0
# __________________________________________________________________________________________________
# expand_channel_dim (Lambda)     (None, 7, 48, 8, 1)  0           input_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_11 (TimeDistri (None, 7, 48, 8, 64) 896         expand_channel_dim[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_3 (ConvLSTM2D)     [(None, 48, 8, 64),  295168      time_distributed_11[0][0]
#                                                                  expand_timestamp_dim[0][0]
#                                                                  conv_lst_m2d_3[0][1]
#                                                                  conv_lst_m2d_3[0][2]
# __________________________________________________________________________________________________
# expand_timestamp_dim (Lambda)   (None, 1, 48, 8, 64) 0           conv_lst_m2d_3[0][0]
# __________________________________________________________________________________________________
# residual_features_seed (Lambda) (None, 48, 8)        0           input_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (None, 48, 8)        8449        conv_lst_m2d_3[0][0]
#                                                                  conv_lst_m2d_3[1][0]
# __________________________________________________________________________________________________
# add_residual_features_delta (Ad (None, 48, 8)        0           residual_features_seed[0][0]
#                                                                  time_distributed_9[0][0]
#                                                                  add_residual_features_delta[0][0]
#                                                                  time_distributed_9[1][0]
# __________________________________________________________________________________________________
# residual_target_seed (Lambda)   (None, 48, 1)        0           input_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_10 (TimeDistri (None, 48, 1)        641         add_residual_features_delta[0][0]
#                                                                  add_residual_features_delta[1][0]
# __________________________________________________________________________________________________
# add_residual_target_delta (Add) (None, 48, 1)        0           residual_target_seed[0][0]
#                                                                  time_distributed_10[0][0]
#                                                                  add_residual_target_delta[0][0]
#                                                                  time_distributed_10[1][0]
# __________________________________________________________________________________________________
# stack_outputs (Lambda)          (None, 2, 48, 1)     0           add_residual_target_delta[0][0]
#                                                                  add_residual_target_delta[1][0]
# ==================================================================================================
# Total params: 305,154
# Trainable params: 305,026
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(tmp, show_layer_names = True, show_shapes = False)

# %%
tf.keras.utils.plot_model(tmp, show_shapes = True)

# %%
del tmp

# %% [markdown]
# # **Compile and Fit**

# %%
def get_callbacks(
    model_name: str,
) -> list:
    """Get checkpoint and tensorboard callbacks."""
    
    # Checkpoint callback.
    ckpt_path = os.path.join(
        os.environ["CHECKPOINT_PATH"], os.environ["NOTEBOOKNAME"], 
        model_name, "cp-{epoch:03d}-{val_loss:.4f}.ckpt")
    ckpt_dir = os.path.dirname(ckpt_path)
    os.makedirs(ckpt_dir, exist_ok = True)
    
    cp_callback = tf.keras.callbacks.ModelCheckpoint(
        ckpt_path, verbose = 0, monitor = "val_loss", save_weights_only = True, save_best_only = True)
    
    # TensorBoard callback.
    log_dir = os.path.join(
        "logs", "fit", os.environ["NOTEBOOKNAME"], datetime.datetime.now().strftime(f"{model_name}-%Y%m%d-%H%M%S"))
    tb_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1, update_freq = "batch")
    
    return [cp_callback, tb_callback]
    

def compile_and_fit(
    model: tf.keras.Model, 
    tau: float, 
    tr_dataset: tf.data.Dataset, 
    vl_dataset: tf.data.Dataset, 
    epochs: int,
    lr: float,
    verbose: int = 0, 
) -> dict:
    """Compile and fit the model."""
    
    model.compile(
        loss = tfa.losses.PinballLoss(tau = tau),
        optimizer = tf.keras.optimizers.Adam(lr))
    
    print(f"Model {model.name}...")

    history = model.fit(
        tr_dataset,
        validation_data = vl_dataset,
        epochs = epochs,
        verbose = verbose,
        callbacks = get_callbacks(model.name))

    return history

# %%
# %%time

for tau in np.arange(0.1, 1, 0.1):
    model = create_AR_ConvLSTM2D(
        model_name = f"P{tau:.1f}", 
        units = HPARAMS.units,
        out_steps = HPARAMS.out_steps,
        dropout_rate = HPARAMS.dropout_rate)
    
    _ = compile_and_fit(
        model, 
        tau, 
        tr_dataset, 
        vl_dataset, 
        HPARAMS.epoch,
        HPARAMS.lr,
        verbose = 2)
    
    del model # for save memories
# Out:
# Model P0.1...
# Epoch 1/50
# 7/7 - 7s - loss: 2.2953 - val_loss: 1.9252
# Epoch 2/50
# 7/7 - 1s - loss: 1.8518 - val_loss: 1.9556
# Epoch 3/50
# 7/7 - 1s - loss: 1.8764 - val_loss: 1.8771
# Epoch 4/50
# 7/7 - 1s - loss: 1.7783 - val_loss: 1.8000
# Epoch 5/50
# 7/7 - 1s - loss: 1.7182 - val_loss: 1.7994
# Epoch 6/50
# 7/7 - 1s - loss: 1.7127 - val_loss: 1.7826
# Epoch 7/50
# 7/7 - 1s - loss: 1.6863 - val_loss: 1.7494
# Epoch 8/50
# 7/7 - 1s - loss: 1.6721 - val_loss: 1.7347
# Epoch 9/50
# 7/7 - 1s - loss: 1.6550 - val_loss: 1.7236
# Epoch 10/50
# 7/7 - 1s - loss: 1.6363 - val_loss: 1.7008
# Epoch 11/50
# 7/7 - 1s - loss: 1.6136 - val_loss: 1.6655
# Epoch 12/50
# 7/7 - 1s - loss: 1.5852 - val_loss: 1.6308
# Epoch 13/50
# 7/7 - 1s - loss: 1.5687 - val_loss: 1.6237
# Epoch 14/50
# 7/7 - 1s - loss: 1.5527 - val_loss: 1.5816
# Epoch 15/50
# 7/7 - 1s - loss: 1.5254 - val_loss: 1.5855
# Epoch 16/50
# 7/7 - 1s - loss: 1.5118 - val_loss: 1.5468
# Epoch 17/50
# 7/7 - 1s - loss: 1.4926 - val_loss: 1.5286
# Epoch 18/50
# 7/7 - 1s - loss: 1.4732 - val_loss: 1.5246
# Epoch 19/50
# 7/7 - 1s - loss: 1.4563 - val_loss: 1.5013
# Epoch 20/50
# 7/7 - 1s - loss: 1.4399 - val_loss: 1.4901
# Epoch 21/50
# 7/7 - 1s - loss: 1.4250 - val_loss: 1.4873
# Epoch 22/50
# 7/7 - 1s - loss: 1.4234 - val_loss: 1.4706
# Epoch 23/50
# 7/7 - 1s - loss: 1.4095 - val_loss: 1.4689
# Epoch 24/50
# 7/7 - 1s - loss: 1.3988 - val_loss: 1.4533
# Epoch 25/50
# 7/7 - 1s - loss: 1.3936 - val_loss: 1.4764
# Epoch 26/50
# 7/7 - 1s - loss: 1.3894 - val_loss: 1.4618
# Epoch 27/50
# 7/7 - 1s - loss: 1.3853 - val_loss: 1.4570
# Epoch 28/50
# 7/7 - 1s - loss: 1.3695 - val_loss: 1.4478
# Epoch 29/50
# 7/7 - 1s - loss: 1.3560 - val_loss: 1.4553
# Epoch 30/50
# 7/7 - 1s - loss: 1.3524 - val_loss: 1.4494
# Epoch 31/50
# 7/7 - 1s - loss: 1.3447 - val_loss: 1.4485
# Epoch 32/50
# 7/7 - 1s - loss: 1.3459 - val_loss: 1.4734
# Epoch 33/50
# 7/7 - 1s - loss: 1.3436 - val_loss: 1.4481
# Epoch 34/50
# 7/7 - 1s - loss: 1.3483 - val_loss: 1.4559
# Epoch 35/50
# 7/7 - 1s - loss: 1.3360 - val_loss: 1.4640
# Epoch 36/50
# 7/7 - 1s - loss: 1.3278 - val_loss: 1.4577
# Epoch 37/50
# 7/7 - 1s - loss: 1.3120 - val_loss: 1.5128
# Epoch 38/50
# 7/7 - 1s - loss: 1.3058 - val_loss: 1.4772
# Epoch 39/50
# 7/7 - 1s - loss: 1.2927 - val_loss: 1.4686
# Epoch 40/50
# 7/7 - 1s - loss: 1.2762 - val_loss: 1.4704
# Epoch 41/50
# 7/7 - 1s - loss: 1.2692 - val_loss: 1.4995
# Epoch 42/50
# 7/7 - 1s - loss: 1.2615 - val_loss: 1.4783
# Epoch 43/50
# 7/7 - 1s - loss: 1.2498 - val_loss: 1.4770
# Epoch 44/50
# 7/7 - 1s - loss: 1.2432 - val_loss: 1.5017
# Epoch 45/50
# 7/7 - 1s - loss: 1.2370 - val_loss: 1.4952
# Epoch 46/50
# 7/7 - 1s - loss: 1.2198 - val_loss: 1.5029
# Epoch 47/50
# 7/7 - 1s - loss: 1.2187 - val_loss: 1.5097
# Epoch 48/50
# 7/7 - 1s - loss: 1.2055 - val_loss: 1.4969
# Epoch 49/50
# 7/7 - 1s - loss: 1.2134 - val_loss: 1.5956
# Epoch 50/50
# 7/7 - 1s - loss: 1.2098 - val_loss: 1.4995
# Model P0.2...
# Epoch 1/50
# 7/7 - 5s - loss: 2.7626 - val_loss: 2.7814
# Epoch 2/50
# 7/7 - 1s - loss: 2.6832 - val_loss: 2.7384
# Epoch 3/50
# 7/7 - 1s - loss: 2.5824 - val_loss: 2.6600
# Epoch 4/50
# 7/7 - 1s - loss: 2.5505 - val_loss: 2.6398
# Epoch 5/50
# 7/7 - 1s - loss: 2.5185 - val_loss: 2.6166
# Epoch 6/50
# 7/7 - 1s - loss: 2.5045 - val_loss: 2.6020
# Epoch 7/50
# 7/7 - 1s - loss: 2.4892 - val_loss: 2.5866
# Epoch 8/50
# 7/7 - 1s - loss: 2.4765 - val_loss: 2.5690
# Epoch 9/50
# 7/7 - 1s - loss: 2.4556 - val_loss: 2.5489
# Epoch 10/50
# 7/7 - 1s - loss: 2.4362 - val_loss: 2.5347
# Epoch 11/50
# 7/7 - 1s - loss: 2.4177 - val_loss: 2.4897
# Epoch 12/50
# 7/7 - 1s - loss: 2.3855 - val_loss: 2.4609
# Epoch 13/50
# 7/7 - 1s - loss: 2.3620 - val_loss: 2.4653
# Epoch 14/50
# 7/7 - 1s - loss: 2.3559 - val_loss: 2.4147
# Epoch 15/50
# 7/7 - 1s - loss: 2.3433 - val_loss: 2.4123
# Epoch 16/50
# 7/7 - 1s - loss: 2.3307 - val_loss: 2.3890
# Epoch 17/50
# 7/7 - 1s - loss: 2.3194 - val_loss: 2.3804
# Epoch 18/50
# 7/7 - 1s - loss: 2.3006 - val_loss: 2.3668
# Epoch 19/50
# 7/7 - 1s - loss: 2.2922 - val_loss: 2.3610
# Epoch 20/50
# 7/7 - 1s - loss: 2.2874 - val_loss: 2.3864
# Epoch 21/50
# 7/7 - 1s - loss: 2.3151 - val_loss: 2.3675
# Epoch 22/50
# 7/7 - 1s - loss: 2.2972 - val_loss: 2.3717
# Epoch 23/50
# 7/7 - 1s - loss: 2.2747 - val_loss: 2.3650
# Epoch 24/50
# 7/7 - 1s - loss: 2.2710 - val_loss: 2.3736
# Epoch 25/50
# 7/7 - 1s - loss: 2.2659 - val_loss: 2.3571
# Epoch 26/50
# 7/7 - 1s - loss: 2.2517 - val_loss: 2.3510
# Epoch 27/50
# 7/7 - 1s - loss: 2.2479 - val_loss: 2.3523
# Epoch 28/50
# 7/7 - 1s - loss: 2.2235 - val_loss: 2.3542
# Epoch 29/50
# 7/7 - 1s - loss: 2.2215 - val_loss: 2.3750
# Epoch 30/50
# 7/7 - 1s - loss: 2.2087 - val_loss: 2.3715
# Epoch 31/50
# 7/7 - 1s - loss: 2.1896 - val_loss: 2.3621
# Epoch 32/50
# 7/7 - 1s - loss: 2.1728 - val_loss: 2.3658
# Epoch 33/50
# 7/7 - 1s - loss: 2.1517 - val_loss: 2.4172
# Epoch 34/50
# 7/7 - 1s - loss: 2.1481 - val_loss: 2.3729
# Epoch 35/50
# 7/7 - 1s - loss: 2.1582 - val_loss: 2.3780
# Epoch 36/50
# 7/7 - 1s - loss: 2.1580 - val_loss: 2.4153
# Epoch 37/50
# 7/7 - 1s - loss: 2.1183 - val_loss: 2.3899
# Epoch 38/50
# 7/7 - 1s - loss: 2.0995 - val_loss: 2.4176
# Epoch 39/50
# 7/7 - 1s - loss: 2.0743 - val_loss: 2.3934
# Epoch 40/50
# 7/7 - 1s - loss: 2.0556 - val_loss: 2.3890
# Epoch 41/50
# 7/7 - 1s - loss: 2.0257 - val_loss: 2.4161
# Epoch 42/50
# 7/7 - 1s - loss: 2.0209 - val_loss: 2.4306
# Epoch 43/50
# 7/7 - 1s - loss: 2.0187 - val_loss: 2.4328
# Epoch 44/50
# 7/7 - 1s - loss: 2.0073 - val_loss: 2.4726
# Epoch 45/50
# 7/7 - 1s - loss: 1.9854 - val_loss: 2.4636
# Epoch 46/50
# 7/7 - 1s - loss: 1.9720 - val_loss: 2.5209
# Epoch 47/50
# 7/7 - 1s - loss: 1.9669 - val_loss: 2.4018
# Epoch 48/50
# 7/7 - 1s - loss: 1.9381 - val_loss: 2.4717
# Epoch 49/50
# 7/7 - 1s - loss: 1.9163 - val_loss: 2.5300
# Epoch 50/50
# 7/7 - 1s - loss: 1.8960 - val_loss: 2.6056
# Model P0.3...
# Epoch 1/50
# 7/7 - 5s - loss: 3.1273 - val_loss: 3.2091
# Epoch 2/50
# 7/7 - 1s - loss: 3.0205 - val_loss: 3.0848
# Epoch 3/50
# 7/7 - 1s - loss: 3.0081 - val_loss: 3.0573
# Epoch 4/50
# 7/7 - 1s - loss: 2.9869 - val_loss: 3.0906
# Epoch 5/50
# 7/7 - 1s - loss: 2.9917 - val_loss: 3.0583
# Epoch 6/50
# 7/7 - 1s - loss: 2.9849 - val_loss: 3.0464
# Epoch 7/50
# 7/7 - 1s - loss: 2.9580 - val_loss: 3.0423
# Epoch 8/50
# 7/7 - 1s - loss: 2.9432 - val_loss: 3.0301
# Epoch 9/50
# 7/7 - 1s - loss: 2.9288 - val_loss: 3.0198
# Epoch 10/50
# 7/7 - 1s - loss: 2.9144 - val_loss: 3.0130
# Epoch 11/50
# 7/7 - 1s - loss: 2.9034 - val_loss: 2.9910
# Epoch 12/50
# 7/7 - 1s - loss: 2.8851 - val_loss: 2.9772
# Epoch 13/50
# 7/7 - 1s - loss: 2.8732 - val_loss: 2.9550
# Epoch 14/50
# 7/7 - 1s - loss: 2.8517 - val_loss: 2.9359
# Epoch 15/50
# 7/7 - 1s - loss: 2.8298 - val_loss: 2.9013
# Epoch 16/50
# 7/7 - 1s - loss: 2.8087 - val_loss: 2.8844
# Epoch 17/50
# 7/7 - 1s - loss: 2.7956 - val_loss: 2.8637
# Epoch 18/50
# 7/7 - 1s - loss: 2.7759 - val_loss: 2.8335
# Epoch 19/50
# 7/7 - 1s - loss: 2.7643 - val_loss: 2.8357
# Epoch 20/50
# 7/7 - 1s - loss: 2.7668 - val_loss: 2.8193
# Epoch 21/50
# 7/7 - 1s - loss: 2.7518 - val_loss: 2.8169
# Epoch 22/50
# 7/7 - 1s - loss: 2.7293 - val_loss: 2.8058
# Epoch 23/50
# 7/7 - 1s - loss: 2.7223 - val_loss: 2.8104
# Epoch 24/50
# 7/7 - 1s - loss: 2.7108 - val_loss: 2.7752
# Epoch 25/50
# 7/7 - 1s - loss: 2.6935 - val_loss: 2.8004
# Epoch 26/50
# 7/7 - 1s - loss: 2.6946 - val_loss: 2.7782
# Epoch 27/50
# 7/7 - 1s - loss: 2.6673 - val_loss: 2.8024
# Epoch 28/50
# 7/7 - 1s - loss: 2.6536 - val_loss: 2.8032
# Epoch 29/50
# 7/7 - 1s - loss: 2.6366 - val_loss: 2.8006
# Epoch 30/50
# 7/7 - 1s - loss: 2.6313 - val_loss: 2.7915
# Epoch 31/50
# 7/7 - 1s - loss: 2.5933 - val_loss: 2.7922
# Epoch 32/50
# 7/7 - 1s - loss: 2.5816 - val_loss: 2.8260
# Epoch 33/50
# 7/7 - 1s - loss: 2.5756 - val_loss: 2.8373
# Epoch 34/50
# 7/7 - 1s - loss: 2.5584 - val_loss: 2.7995
# Epoch 35/50
# 7/7 - 1s - loss: 2.5356 - val_loss: 2.8193
# Epoch 36/50
# 7/7 - 1s - loss: 2.5164 - val_loss: 2.9100
# Epoch 37/50
# 7/7 - 1s - loss: 2.5259 - val_loss: 2.8205
# Epoch 38/50
# 7/7 - 1s - loss: 2.5127 - val_loss: 2.8337
# Epoch 39/50
# 7/7 - 1s - loss: 2.4608 - val_loss: 2.8782
# Epoch 40/50
# 7/7 - 1s - loss: 2.4402 - val_loss: 2.8973
# Epoch 41/50
# 7/7 - 1s - loss: 2.4409 - val_loss: 2.7991
# Epoch 42/50
# 7/7 - 1s - loss: 2.4210 - val_loss: 2.8172
# Epoch 43/50
# 7/7 - 1s - loss: 2.4109 - val_loss: 2.8587
# Epoch 44/50
# 7/7 - 1s - loss: 2.3730 - val_loss: 2.8892
# Epoch 45/50
# 7/7 - 1s - loss: 2.3493 - val_loss: 2.9169
# Epoch 46/50
# 7/7 - 1s - loss: 2.3583 - val_loss: 2.8104
# Epoch 47/50
# 7/7 - 1s - loss: 2.3253 - val_loss: 2.9006
# Epoch 48/50
# 7/7 - 1s - loss: 2.2992 - val_loss: 2.9052
# Epoch 49/50
# 7/7 - 1s - loss: 2.2948 - val_loss: 2.9306
# Epoch 50/50
# 7/7 - 1s - loss: 2.2552 - val_loss: 2.9264
# Model P0.4...
# Epoch 1/50
# 7/7 - 5s - loss: 3.2784 - val_loss: 3.2187
# Epoch 2/50
# 7/7 - 1s - loss: 3.1774 - val_loss: 3.1922
# Epoch 3/50
# 7/7 - 1s - loss: 3.1418 - val_loss: 3.1959
# Epoch 4/50
# 7/7 - 1s - loss: 3.1286 - val_loss: 3.1772
# Epoch 5/50
# 7/7 - 1s - loss: 3.1103 - val_loss: 3.1672
# Epoch 6/50
# 7/7 - 1s - loss: 3.0882 - val_loss: 3.1358
# Epoch 7/50
# 7/7 - 1s - loss: 3.0669 - val_loss: 3.1179
# Epoch 8/50
# 7/7 - 1s - loss: 3.0360 - val_loss: 3.0901
# Epoch 9/50
# 7/7 - 1s - loss: 3.0111 - val_loss: 3.0760
# Epoch 10/50
# 7/7 - 1s - loss: 2.9946 - val_loss: 3.0504
# Epoch 11/50
# 7/7 - 1s - loss: 2.9749 - val_loss: 3.0495
# Epoch 12/50
# 7/7 - 1s - loss: 2.9625 - val_loss: 3.0194
# Epoch 13/50
# 7/7 - 1s - loss: 2.9429 - val_loss: 3.0181
# Epoch 14/50
# 7/7 - 1s - loss: 2.9375 - val_loss: 3.0237
# Epoch 15/50
# 7/7 - 1s - loss: 2.9280 - val_loss: 2.9849
# Epoch 16/50
# 7/7 - 1s - loss: 2.9050 - val_loss: 2.9652
# Epoch 17/50
# 7/7 - 1s - loss: 2.8921 - val_loss: 2.9617
# Epoch 18/50
# 7/7 - 1s - loss: 2.8817 - val_loss: 2.9627
# Epoch 19/50
# 7/7 - 1s - loss: 2.8575 - val_loss: 2.9288
# Epoch 20/50
# 7/7 - 1s - loss: 2.8618 - val_loss: 2.9569
# Epoch 21/50
# 7/7 - 1s - loss: 2.8635 - val_loss: 2.9790
# Epoch 22/50
# 7/7 - 1s - loss: 2.8469 - val_loss: 2.9164
# Epoch 23/50
# 7/7 - 1s - loss: 2.8253 - val_loss: 2.9183
# Epoch 24/50
# 7/7 - 1s - loss: 2.8348 - val_loss: 2.9113
# Epoch 25/50
# 7/7 - 1s - loss: 2.8137 - val_loss: 2.9458
# Epoch 26/50
# 7/7 - 1s - loss: 2.7997 - val_loss: 2.9029
# Epoch 27/50
# 7/7 - 1s - loss: 2.7826 - val_loss: 2.8726
# Epoch 28/50
# 7/7 - 1s - loss: 2.7691 - val_loss: 2.9035
# Epoch 29/50
# 7/7 - 1s - loss: 2.7545 - val_loss: 2.8690
# Epoch 30/50
# 7/7 - 1s - loss: 2.7643 - val_loss: 2.8844
# Epoch 31/50
# 7/7 - 1s - loss: 2.7341 - val_loss: 2.8918
# Epoch 32/50
# 7/7 - 1s - loss: 2.7389 - val_loss: 2.9357
# Epoch 33/50
# 7/7 - 1s - loss: 2.7514 - val_loss: 2.9172
# Epoch 34/50
# 7/7 - 1s - loss: 2.7203 - val_loss: 2.9237
# Epoch 35/50
# 7/7 - 1s - loss: 2.7061 - val_loss: 2.8788
# Epoch 36/50
# 7/7 - 1s - loss: 2.6828 - val_loss: 2.8848
# Epoch 37/50
# 7/7 - 1s - loss: 2.6646 - val_loss: 2.9523
# Epoch 38/50
# 7/7 - 1s - loss: 2.6640 - val_loss: 3.0587
# Epoch 39/50
# 7/7 - 1s - loss: 2.6778 - val_loss: 3.0092
# Epoch 40/50
# 7/7 - 1s - loss: 2.6614 - val_loss: 2.9383
# Epoch 41/50
# 7/7 - 1s - loss: 2.6358 - val_loss: 2.9642
# Epoch 42/50
# 7/7 - 1s - loss: 2.6150 - val_loss: 2.9209
# Epoch 43/50
# 7/7 - 1s - loss: 2.6102 - val_loss: 3.0186
# Epoch 44/50
# 7/7 - 1s - loss: 2.6359 - val_loss: 3.1144
# Epoch 45/50
# 7/7 - 1s - loss: 2.6180 - val_loss: 2.9855
# Epoch 46/50
# 7/7 - 1s - loss: 2.5944 - val_loss: 2.9065
# Epoch 47/50
# 7/7 - 1s - loss: 2.5418 - val_loss: 2.9596
# Epoch 48/50
# 7/7 - 1s - loss: 2.5301 - val_loss: 3.0324
# Epoch 49/50
# 7/7 - 1s - loss: 2.5345 - val_loss: 2.9368
# Epoch 50/50
# 7/7 - 1s - loss: 2.5051 - val_loss: 2.9343
# Model P0.5...
# Epoch 1/50
# 7/7 - 5s - loss: 3.3178 - val_loss: 3.2617
# Epoch 2/50
# 7/7 - 1s - loss: 3.2143 - val_loss: 3.2113
# Epoch 3/50
# 7/7 - 1s - loss: 3.1569 - val_loss: 3.1517
# Epoch 4/50
# 7/7 - 1s - loss: 3.1009 - val_loss: 3.1190
# Epoch 5/50
# 7/7 - 1s - loss: 3.0743 - val_loss: 3.1017
# Epoch 6/50
# 7/7 - 1s - loss: 3.0519 - val_loss: 3.0784
# Epoch 7/50
# 7/7 - 1s - loss: 3.0261 - val_loss: 3.0420
# Epoch 8/50
# 7/7 - 1s - loss: 2.9938 - val_loss: 3.0067
# Epoch 9/50
# 7/7 - 1s - loss: 2.9516 - val_loss: 2.9911
# Epoch 10/50
# 7/7 - 1s - loss: 2.9207 - val_loss: 2.9553
# Epoch 11/50
# 7/7 - 1s - loss: 2.8946 - val_loss: 2.9271
# Epoch 12/50
# 7/7 - 1s - loss: 2.8676 - val_loss: 2.9441
# Epoch 13/50
# 7/7 - 1s - loss: 2.8479 - val_loss: 2.9166
# Epoch 14/50
# 7/7 - 1s - loss: 2.8223 - val_loss: 2.8619
# Epoch 15/50
# 7/7 - 1s - loss: 2.8042 - val_loss: 2.8790
# Epoch 16/50
# 7/7 - 1s - loss: 2.7839 - val_loss: 2.8575
# Epoch 17/50
# 7/7 - 1s - loss: 2.7612 - val_loss: 2.8311
# Epoch 18/50
# 7/7 - 1s - loss: 2.7395 - val_loss: 2.8171
# Epoch 19/50
# 7/7 - 1s - loss: 2.7313 - val_loss: 2.8033
# Epoch 20/50
# 7/7 - 1s - loss: 2.7273 - val_loss: 2.7861
# Epoch 21/50
# 7/7 - 1s - loss: 2.7114 - val_loss: 2.8612
# Epoch 22/50
# 7/7 - 1s - loss: 2.7050 - val_loss: 2.8247
# Epoch 23/50
# 7/7 - 1s - loss: 2.6889 - val_loss: 2.7821
# Epoch 24/50
# 7/7 - 1s - loss: 2.6696 - val_loss: 2.7985
# Epoch 25/50
# 7/7 - 1s - loss: 2.6693 - val_loss: 2.8078
# Epoch 26/50
# 7/7 - 1s - loss: 2.6639 - val_loss: 2.7800
# Epoch 27/50
# 7/7 - 1s - loss: 2.6534 - val_loss: 2.7826
# Epoch 28/50
# 7/7 - 1s - loss: 2.6416 - val_loss: 2.7783
# Epoch 29/50
# 7/7 - 1s - loss: 2.6352 - val_loss: 2.7874
# Epoch 30/50
# 7/7 - 1s - loss: 2.6191 - val_loss: 2.7759
# Epoch 31/50
# 7/7 - 1s - loss: 2.6197 - val_loss: 2.7348
# Epoch 32/50
# 7/7 - 1s - loss: 2.6254 - val_loss: 2.7519
# Epoch 33/50
# 7/7 - 1s - loss: 2.6342 - val_loss: 2.7524
# Epoch 34/50
# 7/7 - 1s - loss: 2.6005 - val_loss: 2.7820
# Epoch 35/50
# 7/7 - 1s - loss: 2.5830 - val_loss: 2.7800
# Epoch 36/50
# 7/7 - 1s - loss: 2.5821 - val_loss: 2.7461
# Epoch 37/50
# 7/7 - 1s - loss: 2.5778 - val_loss: 2.7670
# Epoch 38/50
# 7/7 - 1s - loss: 2.5696 - val_loss: 2.7714
# Epoch 39/50
# 7/7 - 1s - loss: 2.5524 - val_loss: 2.7284
# Epoch 40/50
# 7/7 - 1s - loss: 2.5530 - val_loss: 2.8060
# Epoch 41/50
# 7/7 - 1s - loss: 2.5415 - val_loss: 2.7796
# Epoch 42/50
# 7/7 - 1s - loss: 2.5296 - val_loss: 2.7867
# Epoch 43/50
# 7/7 - 1s - loss: 2.5165 - val_loss: 2.8799
# Epoch 44/50
# 7/7 - 1s - loss: 2.5187 - val_loss: 2.8608
# Epoch 45/50
# 7/7 - 1s - loss: 2.5112 - val_loss: 2.7915
# Epoch 46/50
# 7/7 - 1s - loss: 2.5000 - val_loss: 2.8533
# Epoch 47/50
# 7/7 - 1s - loss: 2.4900 - val_loss: 2.8859
# Epoch 48/50
# 7/7 - 1s - loss: 2.5127 - val_loss: 2.8077
# Epoch 49/50
# 7/7 - 1s - loss: 2.4852 - val_loss: 2.8062
# Epoch 50/50
# 7/7 - 1s - loss: 2.4660 - val_loss: 2.7925
# Model P0.6...
# Epoch 1/50
# 7/7 - 5s - loss: 3.2950 - val_loss: 3.1420
# Epoch 2/50
# 7/7 - 1s - loss: 3.0844 - val_loss: 3.0291
# Epoch 3/50
# 7/7 - 1s - loss: 2.9870 - val_loss: 3.0126
# Epoch 4/50
# 7/7 - 1s - loss: 2.9579 - val_loss: 2.9783
# Epoch 5/50
# 7/7 - 1s - loss: 2.9210 - val_loss: 2.9302
# Epoch 6/50
# 7/7 - 1s - loss: 2.8866 - val_loss: 2.8865
# Epoch 7/50
# 7/7 - 1s - loss: 2.8485 - val_loss: 2.8500
# Epoch 8/50
# 7/7 - 1s - loss: 2.8170 - val_loss: 2.8194
# Epoch 9/50
# 7/7 - 1s - loss: 2.7679 - val_loss: 2.7657
# Epoch 10/50
# 7/7 - 1s - loss: 2.7075 - val_loss: 2.7345
# Epoch 11/50
# 7/7 - 1s - loss: 2.6571 - val_loss: 2.6739
# Epoch 12/50
# 7/7 - 1s - loss: 2.6203 - val_loss: 2.6459
# Epoch 13/50
# 7/7 - 1s - loss: 2.6023 - val_loss: 2.6350
# Epoch 14/50
# 7/7 - 1s - loss: 2.5718 - val_loss: 2.6312
# Epoch 15/50
# 7/7 - 1s - loss: 2.5548 - val_loss: 2.5860
# Epoch 16/50
# 7/7 - 1s - loss: 2.5397 - val_loss: 2.5455
# Epoch 17/50
# 7/7 - 1s - loss: 2.5115 - val_loss: 2.5422
# Epoch 18/50
# 7/7 - 1s - loss: 2.4802 - val_loss: 2.5134
# Epoch 19/50
# 7/7 - 1s - loss: 2.4435 - val_loss: 2.5061
# Epoch 20/50
# 7/7 - 1s - loss: 2.4322 - val_loss: 2.4474
# Epoch 21/50
# 7/7 - 1s - loss: 2.4085 - val_loss: 2.4667
# Epoch 22/50
# 7/7 - 1s - loss: 2.4044 - val_loss: 2.4281
# Epoch 23/50
# 7/7 - 1s - loss: 2.3826 - val_loss: 2.4412
# Epoch 24/50
# 7/7 - 1s - loss: 2.3759 - val_loss: 2.4602
# Epoch 25/50
# 7/7 - 1s - loss: 2.3607 - val_loss: 2.4361
# Epoch 26/50
# 7/7 - 1s - loss: 2.3545 - val_loss: 2.4086
# Epoch 27/50
# 7/7 - 1s - loss: 2.3378 - val_loss: 2.3976
# Epoch 28/50
# 7/7 - 1s - loss: 2.3345 - val_loss: 2.4138
# Epoch 29/50
# 7/7 - 1s - loss: 2.3269 - val_loss: 2.4219
# Epoch 30/50
# 7/7 - 1s - loss: 2.3336 - val_loss: 2.4006
# Epoch 31/50
# 7/7 - 1s - loss: 2.3154 - val_loss: 2.4332
# Epoch 32/50
# 7/7 - 1s - loss: 2.3113 - val_loss: 2.4055
# Epoch 33/50
# 7/7 - 1s - loss: 2.3022 - val_loss: 2.3982
# Epoch 34/50
# 7/7 - 1s - loss: 2.2935 - val_loss: 2.4031
# Epoch 35/50
# 7/7 - 1s - loss: 2.3125 - val_loss: 2.4240
# Epoch 36/50
# 7/7 - 1s - loss: 2.3062 - val_loss: 2.4597
# Epoch 37/50
# 7/7 - 1s - loss: 2.2900 - val_loss: 2.4193
# Epoch 38/50
# 7/7 - 1s - loss: 2.2866 - val_loss: 2.4488
# Epoch 39/50
# 7/7 - 1s - loss: 2.3095 - val_loss: 2.4247
# Epoch 40/50
# 7/7 - 1s - loss: 2.2980 - val_loss: 2.4559
# Epoch 41/50
# 7/7 - 1s - loss: 2.2845 - val_loss: 2.4519
# Epoch 42/50
# 7/7 - 1s - loss: 2.2700 - val_loss: 2.4414
# Epoch 43/50
# 7/7 - 1s - loss: 2.2637 - val_loss: 2.4271
# Epoch 44/50
# 7/7 - 1s - loss: 2.2612 - val_loss: 2.4056
# Epoch 45/50
# 7/7 - 1s - loss: 2.2466 - val_loss: 2.4181
# Epoch 46/50
# 7/7 - 1s - loss: 2.2280 - val_loss: 2.4325
# Epoch 47/50
# 7/7 - 1s - loss: 2.2251 - val_loss: 2.4271
# Epoch 48/50
# 7/7 - 1s - loss: 2.2276 - val_loss: 2.4477
# Epoch 49/50
# 7/7 - 1s - loss: 2.2335 - val_loss: 2.4319
# Epoch 50/50
# 7/7 - 1s - loss: 2.2331 - val_loss: 2.4660
# Model P0.7...
# Epoch 1/50
# 7/7 - 5s - loss: 3.2626 - val_loss: 3.0875
# Epoch 2/50
# 7/7 - 1s - loss: 2.9093 - val_loss: 2.8235
# Epoch 3/50
# 7/7 - 1s - loss: 2.7417 - val_loss: 2.7194
# Epoch 4/50
# 7/7 - 1s - loss: 2.6731 - val_loss: 2.7038
# Epoch 5/50
# 7/7 - 1s - loss: 2.6386 - val_loss: 2.6631
# Epoch 6/50
# 7/7 - 1s - loss: 2.5977 - val_loss: 2.6265
# Epoch 7/50
# 7/7 - 1s - loss: 2.5544 - val_loss: 2.5660
# Epoch 8/50
# 7/7 - 1s - loss: 2.4983 - val_loss: 2.5153
# Epoch 9/50
# 7/7 - 1s - loss: 2.4481 - val_loss: 2.4853
# Epoch 10/50
# 7/7 - 1s - loss: 2.4035 - val_loss: 2.4073
# Epoch 11/50
# 7/7 - 1s - loss: 2.3465 - val_loss: 2.3406
# Epoch 12/50
# 7/7 - 1s - loss: 2.2964 - val_loss: 2.2868
# Epoch 13/50
# 7/7 - 1s - loss: 2.2382 - val_loss: 2.2225
# Epoch 14/50
# 7/7 - 1s - loss: 2.1751 - val_loss: 2.1677
# Epoch 15/50
# 7/7 - 1s - loss: 2.1319 - val_loss: 2.1175
# Epoch 16/50
# 7/7 - 1s - loss: 2.0712 - val_loss: 2.0704
# Epoch 17/50
# 7/7 - 1s - loss: 2.0433 - val_loss: 2.0473
# Epoch 18/50
# 7/7 - 1s - loss: 2.0087 - val_loss: 2.0505
# Epoch 19/50
# 7/7 - 1s - loss: 1.9881 - val_loss: 2.0074
# Epoch 20/50
# 7/7 - 1s - loss: 1.9587 - val_loss: 2.0066
# Epoch 21/50
# 7/7 - 1s - loss: 1.9485 - val_loss: 2.0201
# Epoch 22/50
# 7/7 - 1s - loss: 1.9415 - val_loss: 1.9872
# Epoch 23/50
# 7/7 - 1s - loss: 1.9227 - val_loss: 1.9785
# Epoch 24/50
# 7/7 - 1s - loss: 1.9215 - val_loss: 1.9517
# Epoch 25/50
# 7/7 - 1s - loss: 1.9116 - val_loss: 1.9481
# Epoch 26/50
# 7/7 - 1s - loss: 1.9052 - val_loss: 1.9602
# Epoch 27/50
# 7/7 - 1s - loss: 1.8899 - val_loss: 1.9631
# Epoch 28/50
# 7/7 - 1s - loss: 1.8822 - val_loss: 1.9634
# Epoch 29/50
# 7/7 - 1s - loss: 1.8773 - val_loss: 1.9694
# Epoch 30/50
# 7/7 - 1s - loss: 1.8712 - val_loss: 1.9427
# Epoch 31/50
# 7/7 - 1s - loss: 1.8622 - val_loss: 1.9637
# Epoch 32/50
# 7/7 - 1s - loss: 1.8702 - val_loss: 1.9472
# Epoch 33/50
# 7/7 - 1s - loss: 1.8644 - val_loss: 1.9402
# Epoch 34/50
# 7/7 - 1s - loss: 1.8540 - val_loss: 1.9221
# Epoch 35/50
# 7/7 - 1s - loss: 1.8384 - val_loss: 1.9197
# Epoch 36/50
# 7/7 - 1s - loss: 1.8332 - val_loss: 1.9464
# Epoch 37/50
# 7/7 - 1s - loss: 1.8326 - val_loss: 1.9188
# Epoch 38/50
# 7/7 - 1s - loss: 1.8335 - val_loss: 1.9367
# Epoch 39/50
# 7/7 - 1s - loss: 1.8300 - val_loss: 1.9511
# Epoch 40/50
# 7/7 - 1s - loss: 1.8217 - val_loss: 1.9465
# Epoch 41/50
# 7/7 - 1s - loss: 1.8259 - val_loss: 1.9194
# Epoch 42/50
# 7/7 - 1s - loss: 1.8239 - val_loss: 1.9311
# Epoch 43/50
# 7/7 - 1s - loss: 1.8175 - val_loss: 1.9442
# Epoch 44/50
# 7/7 - 1s - loss: 1.8174 - val_loss: 1.9372
# Epoch 45/50
# 7/7 - 1s - loss: 1.8069 - val_loss: 1.9255
# Epoch 46/50
# 7/7 - 1s - loss: 1.7958 - val_loss: 1.9300
# Epoch 47/50
# 7/7 - 1s - loss: 1.7962 - val_loss: 1.9645
# Epoch 48/50
# 7/7 - 1s - loss: 1.8057 - val_loss: 1.9382
# Epoch 49/50
# 7/7 - 1s - loss: 1.7893 - val_loss: 1.9189
# Epoch 50/50
# 7/7 - 1s - loss: 1.7888 - val_loss: 1.9368
# Model P0.8...
# Epoch 1/50
# 7/7 - 5s - loss: 3.1954 - val_loss: 2.9250
# Epoch 2/50
# 7/7 - 1s - loss: 2.7344 - val_loss: 2.5784
# Epoch 3/50
# 7/7 - 1s - loss: 2.4748 - val_loss: 2.4722
# Epoch 4/50
# 7/7 - 1s - loss: 2.3551 - val_loss: 2.3872
# Epoch 5/50
# 7/7 - 1s - loss: 2.3006 - val_loss: 2.3334
# Epoch 6/50
# 7/7 - 1s - loss: 2.2493 - val_loss: 2.2783
# Epoch 7/50
# 7/7 - 1s - loss: 2.1945 - val_loss: 2.2118
# Epoch 8/50
# 7/7 - 1s - loss: 2.1308 - val_loss: 2.1351
# Epoch 9/50
# 7/7 - 1s - loss: 2.0656 - val_loss: 2.0670
# Epoch 10/50
# 7/7 - 1s - loss: 2.0074 - val_loss: 1.9985
# Epoch 11/50
# 7/7 - 1s - loss: 1.9441 - val_loss: 1.9239
# Epoch 12/50
# 7/7 - 1s - loss: 1.8917 - val_loss: 1.8763
# Epoch 13/50
# 7/7 - 1s - loss: 1.8652 - val_loss: 1.8538
# Epoch 14/50
# 7/7 - 1s - loss: 1.8053 - val_loss: 1.7866
# Epoch 15/50
# 7/7 - 1s - loss: 1.7625 - val_loss: 1.7856
# Epoch 16/50
# 7/7 - 1s - loss: 1.7196 - val_loss: 1.7045
# Epoch 17/50
# 7/7 - 1s - loss: 1.6776 - val_loss: 1.6524
# Epoch 18/50
# 7/7 - 1s - loss: 1.6251 - val_loss: 1.6321
# Epoch 19/50
# 7/7 - 1s - loss: 1.5878 - val_loss: 1.5945
# Epoch 20/50
# 7/7 - 1s - loss: 1.5527 - val_loss: 1.5556
# Epoch 21/50
# 7/7 - 1s - loss: 1.5108 - val_loss: 1.5417
# Epoch 22/50
# 7/7 - 1s - loss: 1.4905 - val_loss: 1.5025
# Epoch 23/50
# 7/7 - 1s - loss: 1.4629 - val_loss: 1.4956
# Epoch 24/50
# 7/7 - 1s - loss: 1.4504 - val_loss: 1.4591
# Epoch 25/50
# 7/7 - 1s - loss: 1.4302 - val_loss: 1.4634
# Epoch 26/50
# 7/7 - 1s - loss: 1.4189 - val_loss: 1.4443
# Epoch 27/50
# 7/7 - 1s - loss: 1.4026 - val_loss: 1.4447
# Epoch 28/50
# 7/7 - 1s - loss: 1.3993 - val_loss: 1.4421
# Epoch 29/50
# 7/7 - 1s - loss: 1.3999 - val_loss: 1.4357
# Epoch 30/50
# 7/7 - 1s - loss: 1.3813 - val_loss: 1.4066
# Epoch 31/50
# 7/7 - 1s - loss: 1.3748 - val_loss: 1.4227
# Epoch 32/50
# 7/7 - 1s - loss: 1.3665 - val_loss: 1.4188
# Epoch 33/50
# 7/7 - 1s - loss: 1.3566 - val_loss: 1.3874
# Epoch 34/50
# 7/7 - 1s - loss: 1.3403 - val_loss: 1.3956
# Epoch 35/50
# 7/7 - 1s - loss: 1.3384 - val_loss: 1.3835
# Epoch 36/50
# 7/7 - 1s - loss: 1.3318 - val_loss: 1.3901
# Epoch 37/50
# 7/7 - 1s - loss: 1.3315 - val_loss: 1.3888
# Epoch 38/50
# 7/7 - 1s - loss: 1.3227 - val_loss: 1.4124
# Epoch 39/50
# 7/7 - 1s - loss: 1.3337 - val_loss: 1.4107
# Epoch 40/50
# 7/7 - 1s - loss: 1.3173 - val_loss: 1.3801
# Epoch 41/50
# 7/7 - 1s - loss: 1.3318 - val_loss: 1.4028
# Epoch 42/50
# 7/7 - 1s - loss: 1.3284 - val_loss: 1.3748
# Epoch 43/50
# 7/7 - 1s - loss: 1.3162 - val_loss: 1.3811
# Epoch 44/50
# 7/7 - 1s - loss: 1.3156 - val_loss: 1.3886
# Epoch 45/50
# 7/7 - 1s - loss: 1.3066 - val_loss: 1.3730
# Epoch 46/50
# 7/7 - 1s - loss: 1.3011 - val_loss: 1.3817
# Epoch 47/50
# 7/7 - 1s - loss: 1.3068 - val_loss: 1.3729
# Epoch 48/50
# 7/7 - 1s - loss: 1.3029 - val_loss: 1.3905
# Epoch 49/50
# 7/7 - 1s - loss: 1.2987 - val_loss: 1.3554
# Epoch 50/50
# 7/7 - 1s - loss: 1.2921 - val_loss: 1.3703
# Model P0.9...
# Epoch 1/50
# 7/7 - 5s - loss: 3.0040 - val_loss: 2.8377
# Epoch 2/50
# 7/7 - 1s - loss: 2.5914 - val_loss: 2.3379
# Epoch 3/50
# 7/7 - 1s - loss: 2.1357 - val_loss: 2.0037
# Epoch 4/50
# 7/7 - 1s - loss: 1.9215 - val_loss: 1.8712
# Epoch 5/50
# 7/7 - 1s - loss: 1.7632 - val_loss: 1.7793
# Epoch 6/50
# 7/7 - 1s - loss: 1.6451 - val_loss: 1.6287
# Epoch 7/50
# 7/7 - 1s - loss: 1.5424 - val_loss: 1.5494
# Epoch 8/50
# 7/7 - 1s - loss: 1.4652 - val_loss: 1.4901
# Epoch 9/50
# 7/7 - 1s - loss: 1.4076 - val_loss: 1.4253
# Epoch 10/50
# 7/7 - 1s - loss: 1.3511 - val_loss: 1.3691
# Epoch 11/50
# 7/7 - 1s - loss: 1.3014 - val_loss: 1.3052
# Epoch 12/50
# 7/7 - 1s - loss: 1.2617 - val_loss: 1.2634
# Epoch 13/50
# 7/7 - 1s - loss: 1.2348 - val_loss: 1.2177
# Epoch 14/50
# 7/7 - 1s - loss: 1.1898 - val_loss: 1.1927
# Epoch 15/50
# 7/7 - 1s - loss: 1.1562 - val_loss: 1.1441
# Epoch 16/50
# 7/7 - 1s - loss: 1.1192 - val_loss: 1.1041
# Epoch 17/50
# 7/7 - 1s - loss: 1.0810 - val_loss: 1.0834
# Epoch 18/50
# 7/7 - 1s - loss: 1.0458 - val_loss: 1.0341
# Epoch 19/50
# 7/7 - 1s - loss: 1.0129 - val_loss: 0.9817
# Epoch 20/50
# 7/7 - 1s - loss: 0.9775 - val_loss: 0.9521
# Epoch 21/50
# 7/7 - 1s - loss: 0.9460 - val_loss: 0.9483
# Epoch 22/50
# 7/7 - 1s - loss: 0.9256 - val_loss: 0.9679
# Epoch 23/50
# 7/7 - 1s - loss: 0.9270 - val_loss: 0.9221
# Epoch 24/50
# 7/7 - 1s - loss: 0.9058 - val_loss: 0.9067
# Epoch 25/50
# 7/7 - 1s - loss: 0.9038 - val_loss: 0.9786
# Epoch 26/50
# 7/7 - 1s - loss: 0.9117 - val_loss: 0.8895
# Epoch 27/50
# 7/7 - 1s - loss: 0.8714 - val_loss: 0.8901
# Epoch 28/50
# 7/7 - 1s - loss: 0.8475 - val_loss: 0.8810
# Epoch 29/50
# 7/7 - 1s - loss: 0.8428 - val_loss: 0.8823
# Epoch 30/50
# 7/7 - 1s - loss: 0.8446 - val_loss: 0.8426
# Epoch 31/50
# 7/7 - 1s - loss: 0.8298 - val_loss: 0.8470
# Epoch 32/50
# 7/7 - 1s - loss: 0.8287 - val_loss: 0.8617
# Epoch 33/50
# 7/7 - 1s - loss: 0.8369 - val_loss: 0.8730
# Epoch 34/50
# 7/7 - 1s - loss: 0.8476 - val_loss: 0.8417
# Epoch 35/50
# 7/7 - 1s - loss: 0.8295 - val_loss: 0.8699
# Epoch 36/50
# 7/7 - 1s - loss: 0.8289 - val_loss: 0.8397
# Epoch 37/50
# 7/7 - 1s - loss: 0.8152 - val_loss: 0.8139
# Epoch 38/50
# 7/7 - 1s - loss: 0.7944 - val_loss: 0.8092
# Epoch 39/50
# 7/7 - 1s - loss: 0.7958 - val_loss: 0.8295
# Epoch 40/50
# 7/7 - 1s - loss: 0.7997 - val_loss: 0.8036
# Epoch 41/50
# 7/7 - 1s - loss: 0.7930 - val_loss: 0.8052
# Epoch 42/50
# 7/7 - 1s - loss: 0.7900 - val_loss: 0.7982
# Epoch 43/50
# 7/7 - 1s - loss: 0.7785 - val_loss: 0.8114
# Epoch 44/50
# 7/7 - 1s - loss: 0.8042 - val_loss: 0.8154
# Epoch 45/50
# 7/7 - 1s - loss: 0.7756 - val_loss: 0.7938
# Epoch 46/50
# 7/7 - 1s - loss: 0.7609 - val_loss: 0.7925
# Epoch 47/50
# 7/7 - 1s - loss: 0.7634 - val_loss: 0.7965
# Epoch 48/50
# 7/7 - 1s - loss: 0.7742 - val_loss: 0.8155
# Epoch 49/50
# 7/7 - 1s - loss: 0.7556 - val_loss: 0.7754
# Epoch 50/50
# 7/7 - 1s - loss: 0.7578 - val_loss: 0.8012
# CPU times: user 11min 19s, sys: 16.7 s, total: 11min 35s
# Wall time: 10min 12s

# %%
# %tensorboard --logdir logs/fit --host jupyter-server --port 6006

# %% [markdown]
# ## **Make Clean Checkpoints**

# %%
# %%time

ckpt_folders = sorted(glob.glob(os.path.join(os.environ["CHECKPOINT_PATH"], os.environ["NOTEBOOKNAME"], "P*")))

num_rm_files = 0
rm_files_sz = 0 # bytes

for f in ckpt_folders:
    # 7 files must be located in ckpt_folders. (latest 3 ckpt, it's index and checkpoint file)
    assert len(os.listdir(f)) >= (1 + HPARAMS.max_to_keep * 2), f"Checkpoints in {f} is less then 3 (max_to_keep)."
    
    rm_files = [os.path.join(f, i) for i in sorted(os.listdir(f))[1:-2*HPARAMS.max_to_keep]] # [1:-6]
    num_rm_files += len(rm_files)
    rm_files_sz += sum([os.path.getsize(rm_file) for rm_file in rm_files])
    
    _ = [os.remove(rm_file) for rm_file in rm_files]
    
print(f"{num_rm_files} files removed.")
print(f"{rm_files_sz / 2**20:.2f}MB saved.")
# Out:
# 404 files removed.
# 707.56MB saved.
# CPU times: user 471 µs, sys: 41.1 ms, total: 41.6 ms
# Wall time: 40.9 ms

# %% [markdown]
# # **Visualize**

# %% [markdown]
# ## **Plot Histories**

# %%
# def draw_histories(
#     histories: dict,
# ):
#     """Draw 9 histories in one plot."""
    
#     assert len(histories.keys()) == HPARAMS.num_quantile
    
#     plt.figure(figsize = (18, 14), facecolor = "white", dpi = 96)

#     for model_name, history in histories.items():
#         pos = int(model_name.split(".")[-1])
#         plt.subplot(3, 3, pos)
                
# #         plt.plot(history.epoch, history.history["aux_loss"], c = "r", label = "aux_loss")
#         plt.plot(history.epoch, history.history["real_loss"], c = "r", ls = "--", label = "real_loss")
# #         plt.plot(history.epoch, history.history["val_aux_loss"], c = "navy", label = "val_aux_loss")
#         plt.plot(history.epoch, history.history["val_real_loss"], c = "navy", ls = "--", label = "val_real_loss")
    
#         plt.legend(loc = "upper left")
#         plt.title(model_name, fontsize = 20)
#         plt.xlabel("Epoch")
#         plt.ylabel("Pinball Loss")
    
#         plt.grid(True)
        
#     plt.tight_layout()
#     plt.show()

# %%
# draw_histories(histories)

# %% [markdown]
# ## **Target Model Prediction**

# %%
def load_latest_models(
    ckpt_folders: list,
) -> list:
    """Load latest weights of target model from saved ckeckpoints."""   
    
    models = []
    val_losses = []
    
    for f in ckpt_folders:
        latest = tf.train.latest_checkpoint(f)
        print(f"Load latest checkpoints: {latest}...")
        
        model_name = latest.split(os.path.sep)[-2] # ckpt/[notebookname]/P0.1/...
        val_loss = np.float32(latest.split(os.path.sep)[-1].split("-")[2][:6])

        # Define a new AR-LSTM model and load checkpoints.
        model = create_AR_ConvLSTM2D(model_name = model_name, units = 64)

        ckpt = tf.train.Checkpoint(model)
        ckpt.restore(latest).expect_partial()
        models.append(model)
        
        val_losses.append(val_loss)
        
    return models, val_losses


def draw_pred(
    inputs, 
    y_preds, 
    y_true, 
    save_fig = False,
):
    """Draw the predictions and labels."""
    
    plt.figure(figsize = (14, 4 * HPARAMS.num_quantile), facecolor = "white")
    
    for i, (y_pred, tau) in enumerate(zip(y_preds, np.arange(0.1, 1, 0.1))):
        plt.subplot(9, 1, i + 1)
        
        plt.plot(np.arange(len(inputs)), inputs, lw = 1.5, label = "Inputs")
        plt.plot(np.arange(len(inputs), len(inputs) + len(y_pred), 1), y_pred, marker = "o", lw = 1.5, label = "Predictions")
        plt.plot(np.arange(len(inputs), len(inputs) + len(y_true), 1), y_true, marker = "X", lw = 1.5, label = "Label")
    
        plt.title(f"Target Model T{tau:.1f}")
        plt.xlabel("Time [day]")
        plt.ylabel("Target")
        plt.ylim([-0.8, max(y_true) * 1.1])
        plt.legend()

        plt.xticks(
            np.arange(0, HPARAMS.w_inp + HPARAMS.w_tar + 1, HPARAMS.day), 
            [f"D+{i}" for i in np.arange(HPARAMS.inp + HPARAMS.tar + 1)])
        plt.grid(True)
        
    plt.tight_layout()
    
    if save_fig:
        plt.savefig(os.path.join("pngs", f"{os.environ['NOTEBOOKNAME']}.png"), dpi = 96)
        
    plt.show()

# %%
# Restore latest models from saved checkpoints.
ckpt_folders = sorted(glob.glob(os.path.join(os.environ["CHECKPOINT_PATH"], os.environ["NOTEBOOKNAME"], "P*")))
models, val_losses = load_latest_models(ckpt_folders)
print(f"Averaged Validation Loss: {np.mean(val_losses):.4f}")

# Now, unbatch the dataset to predict only one sequences (i.e. 7 days).
unbatched_vl_dataset = vl_dataset.unbatch().batch(1)

for t in unbatched_vl_dataset.take(1):
    x, r_y = t # inp, tar
    
    draw_pred(
        inputs = vl_tensor[:HPARAMS.w_inp, -1], # not x
        y_preds = [tf.reshape(model.predict(x), (-1, )).numpy() for model in models],
        y_true = tf.reshape(r_y, (-1, )))
# Out:
# Load latest checkpoints: ckpt/try158/P0.1/cp-028-1.4478.ckpt...
# Load latest checkpoints: ckpt/try158/P0.2/cp-026-2.3510.ckpt...
# Load latest checkpoints: ckpt/try158/P0.3/cp-024-2.7752.ckpt...
# Load latest checkpoints: ckpt/try158/P0.4/cp-029-2.8690.ckpt...
# Load latest checkpoints: ckpt/try158/P0.5/cp-039-2.7284.ckpt...
# Load latest checkpoints: ckpt/try158/P0.6/cp-027-2.3976.ckpt...
# Load latest checkpoints: ckpt/try158/P0.7/cp-037-1.9188.ckpt...
# Load latest checkpoints: ckpt/try158/P0.8/cp-049-1.3554.ckpt...
# Load latest checkpoints: ckpt/try158/P0.9/cp-049-0.7754.ckpt...
# Averaged Validation Loss: 2.0687
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f244829f6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f24980dca60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2448502f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f249041e378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f24280df950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# # **Make Submissions**

# %%
# %%time
# Restore latest models from saved checkpoints.
ckpt_folders = sorted(glob.glob(os.path.join(os.environ["CHECKPOINT_PATH"], os.environ["NOTEBOOKNAME"], "P*")))
models, _ = load_latest_models(ckpt_folders)

# Predict the test datasets.
# We need to drop auxiliary outputs and squeeze dimensions (i.e. [batch, 96, 1] => [batch, 96]).
preds = [np.array(tf.reshape(model.predict(ts_dataset)[-1], (-1, ))) for model in models]

# %%
submission = pd.read_csv(os.path.join(os.environ["LOCAL_DATA_PATH"], "sample_submission.csv"), index_col = "id")
submission.head()

# %%
for column, pred in zip(submission.columns, preds):
    foo = np.reshape(pred, (-1,))
    foo = np.where(foo < HPARAMS.epsilon, 0, foo) # clip by value
    
    submission[column] = foo

# %%
submission.head()

# %%
submission.to_csv(os.path.join(os.environ["SUBMISSION_PATH"], f"{os.environ['NOTEBOOKNAME']}_submission.csv"))

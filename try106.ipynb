# %% [markdown]
# # **Default Setting**
#
# * Python: 3.6.9
# * ML Framework: tensorflow-gpu 2.4.0 / tensorflow-addons 0.12.0
# * CPU: AMD Ryzen 5 5600X 6-Core Processor
# * GPU: GeForce RTX 3070 (8G) (CUDA 11.1)
# * RAM: 32G
# * Platform: Linux Ubuntu 20.04 LTS (desktop)
#
# Install below APIs using anaconda as belows.
#
# ```
# conda create -n py36 python=3.6.9
# conda acitvate py36
# pip3 install tensorflow-gpu=2.4.0 tensorflow-addons=0.12.0
# conda install pandas, matplotlib, pydot, jupyterlab, cudatoolkit
# ```
#
# And now, you can run jupyter lab (or jupyter notebook).
#
# ```
# jupyter lab
# ```

# %%
# %env NOTEBOOKNAME try106
# %env LOCAL_DATA_PATH data
# %env CHECKPOINT_PATH ckpt
# %env SUBMISSION_PATH submission
# Out:
# env: NOTEBOOKNAME=try106
# env: LOCAL_DATA_PATH=data
# env: CHECKPOINT_PATH=ckpt
# env: SUBMISSION_PATH=submission

# %%
import tensorflow as tf
import tensorflow_addons as tfa

import datetime
import glob
import os
import platform

import numpy as np
import pandas as pd

from collections import OrderedDict
from matplotlib import pyplot as plt

print(f"tf.__version__: {tf.__version__}")
print(f"tfa.__version__: {tfa.__version__}")
# Out:
# tf.__version__: 2.4.0
# tfa.__version__: 0.12.0

# %%
# If you wanna avoid below error, you need to run below codes when you start kernel.

# UnknownError: Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, 
# so try looking to see if a warning log message was printed above. [Op:Conv2D]

# Ref: https://blog.naver.com/vft1500/221793591386

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
    # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# !python -V

# %%
# !cat /proc/cpuinfo

# %%
# !nvidia-smi
# Out:
# Sat Jan  2 14:07:10 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.32.00    Driver Version: 455.32.00    CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Graphics Device     On   | 00000000:0A:00.0 Off |                  N/A |
# |  0%   36C    P2    28W / 220W |    374MiB /  7979MiB |      6%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A       926      G   /usr/lib/xorg/Xorg                 56MiB |
# |    0   N/A  N/A      1083      G   /usr/bin/gnome-shell               10MiB |
# |    0   N/A  N/A     41761      C   ...nda3/envs/py36/bin/python      303MiB |
# +-----------------------------------------------------------------------------+

# %%
# !df -h

# %%
# !free -h
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:           31Gi       1.3Gi        22Gi        11Mi       8.0Gi        29Gi
# Swap:         2.0Gi          0B       2.0Gi

# %%
# platform.platform()

# %%
# Load the TensorBoard notebook extension.
# %load_ext tensorboard

# %% [markdown]
# # **Define Arguments**

# %%
args = OrderedDict({
    # Basic
    "SEED": 42,
    "TEST_SIZE": 0.2,
    "EPOCH": 50,
    "INIT_LR": 1e-3,
    
    # Dataframe
    "NUM_TEST_CSV": 81,
    "DAY": 48,
    
    # Dataset Pipeline
    "W_INP": 7,    # 7 days
    "W_TAR": 2,    # 2 days
    "W_SHIFT": 1,  # 1 day
    "W_STRIDE": 1, # 1 day
    "W_DR": True,  # Drop remainders
    "AUTO": tf.data.experimental.AUTOTUNE,
    
    "GLOBAL_BATCH_SIZE": 128,
    
    # Model
    "NUM_UNITS": 128, # lstm & dense units
    "NUM_FEATURES": 8, # DAY_SIN, DAY_COS, DHI, DNI, WS, RH, T, TARGET
    "NUM_QUANTILE": 9, # tau = 0.1 to 0.9
    
    # Postprocessing
    "EPSILON": 5e-2,
})

args
# Out:
# OrderedDict([('SEED', 42),
#              ('TEST_SIZE', 0.2),
#              ('EPOCH', 50),
#              ('INIT_LR', 0.001),
#              ('NUM_TEST_CSV', 81),
#              ('DAY', 48),
#              ('W_INP', 7),
#              ('W_TAR', 2),
#              ('W_SHIFT', 1),
#              ('W_STRIDE', 1),
#              ('W_DR', True),
#              ('AUTO', -1),
#              ('GLOBAL_BATCH_SIZE', 128),
#              ('NUM_UNITS', 128),
#              ('NUM_FEATURES', 8),
#              ('NUM_QUANTILE', 9),
#              ('EPSILON', 0.05)])

# %% [markdown]
# # **Load Datasets**

# %% [markdown]
# ## **Define Preprocessing Funciton**

# %%
def preprocessing(df, is_training = True, day = args["DAY"]): # 24 / 0.5 [h]
    # Drop timestampes.
    try:
        # We cannot use day features, thus there is no day-position in test dataset.
        df = df.drop(["Day"], axis = 1) 
    except:
        pass
    
    
    # Timestamp to sin/cos.
    df["Time"] = 2 * df["Hour"].map(int) + (df["Minute"].map(int) // 30)
    
    day_sin = np.sin(df["Time"] * (2 * np.pi / day))
    day_cos = np.cos(df["Time"] * (2 * np.pi / day))
        
    df.insert(loc = 0, column = "DAY_SIN", value = day_sin)
    df.insert(loc = 1, column = "DAY_COS", value = day_cos)
    
    df = df.drop(["Hour", "Minute", "Time"], axis = 1)
    
    
    # Standarize.
    for column in df.columns:
        if is_training:
            args[f"{column}_MEAN"] = df[column].mean().astype(np.float32)
            args[f"{column}_STD"] = df[column].std().astype(np.float32)
        
        df[column] = (df[column] - args[f"{column}_MEAN"]) / args[f"{column}_STD"]
        df[column] = df[column].astype(np.float32)
        
    return df

# %% [markdown]
# ## **Train & Validation Dataframes**

# %%
df = pd.read_csv(os.path.join(os.environ["LOCAL_DATA_PATH"], "train", "train.csv"))
df.head()
# Out:
#    Day  Hour  Minute  DHI  DNI   WS     RH   T  TARGET
# 0    0     0       0    0    0  1.5  69.08 -12     0.0
# 1    0     0      30    0    0  1.5  69.06 -12     0.0
# 2    0     1       0    0    0  1.6  71.78 -12     0.0
# 3    0     1      30    0    0  1.6  71.75 -12     0.0
# 4    0     2       0    0    0  1.6  75.20 -12     0.0

# %%
args["SPLIT_LEN"] = int(df.shape[0] * (1. - args["TEST_SIZE"]))
args["SPLIT_LEN"] = args["SPLIT_LEN"] - np.mod(args["SPLIT_LEN"], args["DAY"])

tr_df = df[:args["SPLIT_LEN"]]
vl_df = df[args["SPLIT_LEN"]:]

tr_df = preprocessing(tr_df)
vl_df = preprocessing(vl_df, is_training = False)

tr_df.shape, vl_df.shape
# Out:
# ((42048, 8), (10512, 8))

# %%
plt.plot(np.array(tr_df["DAY_SIN"])[:args["DAY"]], label = "day_sin")
plt.plot(np.array(tr_df["DAY_COS"])[:args["DAY"]], label = "day_cos")
plt.legend()
plt.xticks(np.arange(0, 48, 12), np.arange(0, 24, 6))
plt.xlabel('Time [h]')
plt.grid(True)
plt.title('Time of day signal')
plt.show()

# %% [markdown]
# ## **Test Dataframe**

# %%
ts_filenames = [os.path.join(os.environ["LOCAL_DATA_PATH"], "test", f"{i}.csv") for i in range(args["NUM_TEST_CSV"])]
ts_dfs = [preprocessing(pd.read_csv(ts_filename), is_training = False) for ts_filename in ts_filenames]
ts_df = pd.concat(ts_dfs)

ts_df.shape
# Out:
# (27216, 8)

# %% [markdown]
# # **Make Dataset Pipelines**
#
# The first batch is to bundle the tensors as input into units of a day. The operation below can guarantee that the number of sequences of tr_tensor and vl_tensor is a multiple of a day (i.e. 48), so `drop_remainder = True` is actually meaningless. However, it was added to specify the shape of the input data during the window division process (`.window(...)`)
#
# ```
# args["SPLIT_LEN"] = int(df.shape[0] * (1. - args["TEST_SIZE"]))
# args["SPLIT_LEN"] = args["SPLIT_LEN"] - np.mod(args["SPLIT_LEN"], args["DAY"]) # this process
#
# tr_df = df[:args["SPLIT_LEN"]]
# vl_df = df[args["SPLIT_LEN"]:]
# ```
#
# It is recommended to cache the dataset after the map transformation except if this transformation makes the data too big to fit in memory. A trade-off can be achieved if your mapped function can be split in two parts: a time consuming one and a memory consuming part. In this case, you can chain your transformations like below:
#
# ```
# dataset.map(time_consuming_mapping).cache().map(memory_consuming_mapping)
# ```
#
# If the cache is executed after partioning the window, the amount of data loaded in the memory increases by about 9 times (=`(W_INP + W_TAR) / W_STRIDE)`. Obviously, the mapping process comsumes a lot of time, but since we have to train a model like this 9 times, it would be desirable to load it into the cache mory before the window split.
#
# Also `cache` produce exactly the same elements during each iteration through the dataset. If you wish to randomize the iteration order, make sure to call `shuffle` after calling `cache`.
#
# Immediately after the window is splited, the mapping function `_split_window` is called after stacking with `GLOBAL_BATCH_SIZE`. This time, the vectorized mapping function is called once and applies to a batch of sample. While the function could takes more time to execute, the overhead appear only once, improving the overall time performance.
#
# *References*
#    * *https://www.tensorflow.org/guide/data_performance*
#    * *https://www.tensorflow.org/api_docs/python/tf/data/Dataset*

# %%
@tf.function
def _flat_fn_tr(x):
    return x.batch(args["W_INP"] + args["W_TAR"])


@tf.function
def _flat_fn_ts(x):
    return x.batch(args["W_INP"])


@tf.function
def _split_W_tr(features):
    """
        input:  (batch, 9, 48, 8)
        output: (batch, 7, 48, 8), (batch, 2, 48, 1)
    """
    inp, tar = tf.split(features, [args["W_INP"], args["W_TAR"]], axis = 1)
    _, tar = tf.split(tar, [-1, 1], axis = -1)
    
    return inp, tar
    

# @tf.function
# def _split_W_ts(features):
#     """
#         input:  (batch, 7, 48, 8)
#         output: (batch, 7, 48, 8)
#     """
#     inp, _ = tf.split(features, [args["NUM_FEATURES"], -1], axis = -1)
    
#     return inp

# %%
# Dataframe to tensor.
tr_tensor = tf.constant(tr_df, dtype = tf.float32)
vl_tensor = tf.constant(vl_df, dtype = tf.float32)
ts_tensor = tf.constant(ts_df, dtype = tf.float32)

# Tensor to dataset.
tr_dataset = tf.data.Dataset.from_tensor_slices(tr_tensor
                    ).batch(args["DAY"], drop_remainder = True
                    ).cache(
                    ).window(args["W_INP"] + args["W_TAR"], args["W_SHIFT"], args["W_STRIDE"], args["W_DR"]).flat_map(_flat_fn_tr
                    ).shuffle(100_000, reshuffle_each_iteration = True
                    ).batch(args["GLOBAL_BATCH_SIZE"]
                    ).map(_split_W_tr, num_parallel_calls = args["AUTO"]
                    ).prefetch(args["AUTO"])

vl_dataset = tf.data.Dataset.from_tensor_slices(vl_tensor
                    ).batch(args["DAY"], drop_remainder = True
                    ).cache(
                    ).window(args["W_INP"] + args["W_TAR"], args["W_SHIFT"], args["W_STRIDE"], args["W_DR"]).flat_map(_flat_fn_tr
#                     ).shuffle(100_000, reshuffle_each_iteration = True
                    ).batch(args["GLOBAL_BATCH_SIZE"]
                    ).map(_split_W_tr, num_parallel_calls = args["AUTO"]
                    ).prefetch(args["AUTO"])

ts_dataset = tf.data.Dataset.from_tensor_slices(ts_tensor
                    ).batch(args["DAY"], drop_remainder = True
#                     ).cache(
                    ).window(args["W_INP"], args["W_INP"], args["W_STRIDE"], args["W_DR"]).flat_map(_flat_fn_ts
#                     ).shuffle(100_000, reshuffle_each_iteration = True
                    ).batch(args["NUM_TEST_CSV"], # not GLOBA_BATCH_SIZE
#                     ).map(_split_W_ts, num_parallel_calls = args["AUTO"]
                    ).prefetch(args["AUTO"])

# Print the shapes.
print("tr_dataset:")
print(f"\tinp: {tr_dataset.element_spec[0]}")
print(f"\ttar: {tr_dataset.element_spec[1]}")

print("vl_dataset:")
print(f"\tinp: {vl_dataset.element_spec[0]}")
print(f"\ttar: {vl_dataset.element_spec[1]}")

print("ts_dataset:")
print(f"\tinp: {ts_dataset.element_spec}")
# Out:
# tr_dataset:
# 	inp: TensorSpec(shape=(None, 7, 48, 8), dtype=tf.float32, name=None)
# 	tar: TensorSpec(shape=(None, 2, 48, 1), dtype=tf.float32, name=None)
# vl_dataset:
# 	inp: TensorSpec(shape=(None, 7, 48, 8), dtype=tf.float32, name=None)
# 	tar: TensorSpec(shape=(None, 2, 48, 1), dtype=tf.float32, name=None)
# ts_dataset:
# 	inp: TensorSpec(shape=(None, None, 48, 8), dtype=tf.float32, name=None)

# %% [markdown]
# ## **Take Samples**

# %%
# for element in tr_dataset.take(1):
#     foo, bar = element
#     print(foo.shape, bar.shape)

# %%
# for element in vl_dataset.take(1):
#     foo, bar = element
#     print(foo.shape, bar.shape)

# %%
# for element in ts_dataset.take(1):
#     foo = element
#     print(foo.shape)

# %% [markdown]
# # **Define Loss Function**

# %% [markdown]
# Dacon defines the loss as shown below.
#
# $$ L_\tau = maximum(\zeta\tau, \zeta(\tau-1)) $$
#
# However, [the pinball loss of tensorflow-addons](https://www.tensorflow.org/addons/api_docs/python/tfa/losses/pinball_loss) is implemented as follows.
#
# $$ L_\tau = \begin{cases} \zeta\tau & \text{ if } \zeta \geq 0 \\ -\zeta(1-\tau)=\zeta(\tau-1) & \text{ if } \zeta < 0 \end{cases}$$
#
# The description of the symbols used in is as follows.
#
# * $\zeta$ : y_true - y_pred
# * $\tau$ : Quantile values in \[0.1, 0.2, ..., 0.9\]
# * $L_\tau$ : Pinball loss function with $\tau$
#
# The two formulas seem intuitively different, but if you actually divide the interval, you can see that they are the same. However, in experience, it seems to force an underforecast when the evaluation expression of dacon is $\tau=0.1, 0.2$. In fact, for $\tau=0.1, 0.2$, the prediction (blue lines) in the target models mostly overlaps the label (yellow lines) or lies below the graph.

# %%
# Define customized pinball loss function, named tuned_pinball_loss thus there exists finely differences 
# between the function of tensorflow-addons and the requirements of DACON.

# Ref: https://github.com/tensorflow/addons/blob/v0.11.2/tensorflow_addons/losses/quantiles.py

@tf.function
def custom_pinball_loss(
    y_true: tf.Tensor, 
    y_pred: tf.Tensor, 
    tau: float = 0.5,
) -> tf.Tensor:
    """Computes the pinball loss between "y_true" and "y_pred" like dacon-style."""
    y_pred = tf.convert_to_tensor(y_pred)
    y_true = tf.cast(y_true, y_pred.dtype)
    tau = tf.cast(tau, y_pred.dtype)
    
    delta_y = tf.math.abs(y_true - y_pred)
    # It performs "tau = tau if y_true >= y_pred else (1 - tau)" for elemental-wise.
    _tau = tf.where(tf.math.greater_equal(y_true, y_pred), tau, 1 - tau)
    
    pinball = delta_y * _tau
    return tf.reduce_mean(pinball, axis = -1)


class CustomPinballLoss(tfa.utils.keras_utils.LossFunctionWrapper):
    def __init__(
        self,
        tau: tfa.utils.types.FloatTensorLike = 0.5,
        reduction: str = tf.keras.losses.Reduction.AUTO,
        name: str = "custom_pinball_loss",
    ):
        super().__init__(custom_pinball_loss, reduction = reduction, name = name, tau = tau)

# %% [markdown]
# # **Create Network**

# %% [markdown]
# ## **Autoregressive-ConvLSTM2D Model**

# %%
def make_residual(theta = np.float32((args["EPSILON"] - args["TARGET_MEAN"]) / args["TARGET_STD"])):
    model_input = tf.keras.layers.Input(shape = (args["DAY"], 1), dtype = tf.float32)
    
    _x = model_input
    _y = tf.keras.layers.Lambda(lambda x: x[:, ::-1, :], name = "reverse")(model_input)
    
    avg = tf.keras.layers.Average()([_x, _y])
    model_output = tf.where(tf.math.logical_or(_x < theta, _y < theta), theta, avg)
    
    return tf.keras.Model(
        inputs = model_input,
        outputs = model_output,
        name = "residual_model")


def create_AR_LSTM(model_name, units = 32, out_steps = 2):
    convlstm2d = tf.keras.layers.ConvLSTM2D(units, 3, padding = "same", dropout = 0.4, return_state = True)
    residual_model = make_residual()
    reshape = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis = 1), name = "expand_timestamp_dim")
    predict = tf.keras.layers.TimeDistributed(
        tf.keras.Sequential([
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(args["NUM_FEATURES"] * units, activation = "relu"),
            tf.keras.layers.Dense(1, kernel_initializer = tf.keras.initializers.Zeros())], name = "predict"))
    add = tf.keras.layers.Add(name = "residual_add")
    outputs = []
    
    # Entry flow.
    model_input = tf.keras.layers.Input(
        shape = [args["W_INP"], args["DAY"], args["NUM_FEATURES"]], dtype = tf.float32)
    
    x = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis = -1), name = "expand_channel_dim")(model_input)
    x = tf.keras.layers.TimeDistributed(
        tf.keras.layers.Conv2D(units, 3, padding = "same", activation = "relu"))(x)
    
    # warmup
    residual = tf.keras.layers.Lambda(lambda x: x[:, -1, :, -1:], name = "residual")(model_input)
    residual = residual_model(residual)
    x, *state = convlstm2d(x)
    outputs.append(add([residual, predict(x)]))
    
    # Middle flow.
    for _ in range(1, out_steps):
        residual = outputs[-1]
        residual = residual_model(residual)
        x = reshape(x)
        x, *state = convlstm2d(x, initial_state = state)
        outputs.append(add([residual, predict(x)]))
        
    # Exit flow.
    model_output = tf.keras.layers.Lambda(lambda x: tf.stack(x, axis = 1), name = "stacked_output")(outputs)
    
    return tf.keras.Model(
        inputs = model_input,
        outputs = model_output,
        name = model_name)

# %%
tmp = create_AR_LSTM("tmp")
tmp.summary()
# Out:
# Model: "tmp"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           [(None, 7, 48, 8)]   0
# __________________________________________________________________________________________________
# expand_channel_dim (Lambda)     (None, 7, 48, 8, 1)  0           input_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (None, 7, 48, 8, 32) 320         expand_channel_dim[0][0]
# __________________________________________________________________________________________________
# residual (Lambda)               (None, 48, 1)        0           input_10[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_7 (ConvLSTM2D)     [(None, 48, 8, 32),  73856       time_distributed_5[0][0]
#                                                                  expand_timestamp_dim[0][0]
#                                                                  conv_lst_m2d_7[0][1]
#                                                                  conv_lst_m2d_7[0][2]
# __________________________________________________________________________________________________
# residual_model (Functional)     (None, 48, 1)        0           residual[0][0]
#                                                                  residual_add[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 48, 1)        66049       conv_lst_m2d_7[0][0]
#                                                                  conv_lst_m2d_7[1][0]
# __________________________________________________________________________________________________
# expand_timestamp_dim (Lambda)   (None, 1, 48, 8, 32) 0           conv_lst_m2d_7[0][0]
# __________________________________________________________________________________________________
# residual_add (Add)              (None, 48, 1)        0           residual_model[0][0]
#                                                                  time_distributed_4[0][0]
#                                                                  residual_model[1][0]
#                                                                  time_distributed_4[1][0]
# __________________________________________________________________________________________________
# stacked_output (Lambda)         (None, 2, 48, 1)     0           residual_add[0][0]
#                                                                  residual_add[1][0]
# ==================================================================================================
# Total params: 140,225
# Trainable params: 140,225
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(tmp, show_layer_names = True, show_shapes = False)

# %%
tf.keras.utils.plot_model(tmp, show_shapes = True)

# %%
del tmp

# %% [markdown]
# # **Compile and Fit**

# %%
def get_callbacks(model_name: str):
    """Get checkpoint and tensorboard callbacks."""
    # Checkpoint callback.
    ckpt_path = os.path.join(
        os.environ["CHECKPOINT_PATH"], os.environ["NOTEBOOKNAME"], 
        model_name, "cp-{epoch:03d}-{val_loss:.4f}.ckpt")
    ckpt_dir = os.path.dirname(ckpt_path)
    os.makedirs(ckpt_dir, exist_ok = True)
    
    cp_callback = tf.keras.callbacks.ModelCheckpoint(
        ckpt_path, verbose = 0, monitor = "val_loss", save_weights_only = True, save_best_only = True)
    
    # TensorBoard callback.
    log_dir = os.path.join(
        "logs", "fit", os.environ["NOTEBOOKNAME"], datetime.datetime.now().strftime(f"{model_name}-%Y%m%d-%H%M%S"))
    tb_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)
    
    return [cp_callback, tb_callback]
    

def compile_and_fit(model, tau, tr_dataset, vl_dataset, epochs, verbose = 0, loss_weights = None):
    """Compile and fit the model."""
    model.compile(
        loss = CustomPinballLoss(tau = tau),
        loss_weights = loss_weights,
        optimizer = tf.keras.optimizers.Adam(args["INIT_LR"]))
    
    print(f"Model {model.name}...")

    history = model.fit(
        tr_dataset,
        validation_data = vl_dataset,
        epochs = epochs,
        verbose = verbose,
        callbacks = get_callbacks(model.name))

    return history

# %%
# %%time

for tau in np.arange(0.1, 1, 0.1):
    model = create_AR_LSTM(model_name = f"P{tau:.1f}")
    _ = compile_and_fit(model, tau, tr_dataset, vl_dataset, args["EPOCH"], verbose = 2)
    
    del model # for save memories
# Out:
# Model P0.1...
# Epoch 1/50
# 7/7 - 5s - loss: 0.1104 - val_loss: 0.1009
# Epoch 2/50
# 7/7 - 1s - loss: 0.0846 - val_loss: 0.0777
# Epoch 3/50
# 7/7 - 1s - loss: 0.0691 - val_loss: 0.0726
# Epoch 4/50
# 7/7 - 1s - loss: 0.0675 - val_loss: 0.0688
# Epoch 5/50
# 7/7 - 1s - loss: 0.0647 - val_loss: 0.0659
# Epoch 6/50
# 7/7 - 1s - loss: 0.0626 - val_loss: 0.0637
# Epoch 7/50
# 7/7 - 1s - loss: 0.0615 - val_loss: 0.0632
# Epoch 8/50
# 7/7 - 1s - loss: 0.0608 - val_loss: 0.0614
# Epoch 9/50
# 7/7 - 1s - loss: 0.0597 - val_loss: 0.0611
# Epoch 10/50
# 7/7 - 1s - loss: 0.0594 - val_loss: 0.0608
# Epoch 11/50
# 7/7 - 1s - loss: 0.0590 - val_loss: 0.0611
# Epoch 12/50
# 7/7 - 1s - loss: 0.0585 - val_loss: 0.0604
# Epoch 13/50
# 7/7 - 1s - loss: 0.0584 - val_loss: 0.0604
# Epoch 14/50
# 7/7 - 1s - loss: 0.0584 - val_loss: 0.0610
# Epoch 15/50
# 7/7 - 1s - loss: 0.0577 - val_loss: 0.0600
# Epoch 16/50
# 7/7 - 1s - loss: 0.0578 - val_loss: 0.0602
# Epoch 17/50
# 7/7 - 1s - loss: 0.0573 - val_loss: 0.0599
# Epoch 18/50
# 7/7 - 1s - loss: 0.0572 - val_loss: 0.0600
# Epoch 19/50
# 7/7 - 1s - loss: 0.0568 - val_loss: 0.0603
# Epoch 20/50
# 7/7 - 1s - loss: 0.0567 - val_loss: 0.0606
# Epoch 21/50
# 7/7 - 1s - loss: 0.0568 - val_loss: 0.0602
# Epoch 22/50
# 7/7 - 1s - loss: 0.0563 - val_loss: 0.0602
# Epoch 23/50
# 7/7 - 1s - loss: 0.0563 - val_loss: 0.0601
# Epoch 24/50
# 7/7 - 1s - loss: 0.0562 - val_loss: 0.0615
# Epoch 25/50
# 7/7 - 1s - loss: 0.0559 - val_loss: 0.0618
# Epoch 26/50
# 7/7 - 1s - loss: 0.0562 - val_loss: 0.0610
# Epoch 27/50
# 7/7 - 1s - loss: 0.0562 - val_loss: 0.0592
# Epoch 28/50
# 7/7 - 1s - loss: 0.0564 - val_loss: 0.0596
# Epoch 29/50
# 7/7 - 1s - loss: 0.0556 - val_loss: 0.0596
# Epoch 30/50
# 7/7 - 1s - loss: 0.0557 - val_loss: 0.0602
# Epoch 31/50
# 7/7 - 1s - loss: 0.0559 - val_loss: 0.0599
# Epoch 32/50
# 7/7 - 1s - loss: 0.0551 - val_loss: 0.0595
# Epoch 33/50
# 7/7 - 1s - loss: 0.0547 - val_loss: 0.0593
# Epoch 34/50
# 7/7 - 1s - loss: 0.0542 - val_loss: 0.0588
# Epoch 35/50
# 7/7 - 1s - loss: 0.0537 - val_loss: 0.0597
# Epoch 36/50
# 7/7 - 1s - loss: 0.0537 - val_loss: 0.0591
# Epoch 37/50
# 7/7 - 1s - loss: 0.0535 - val_loss: 0.0597
# Epoch 38/50
# 7/7 - 1s - loss: 0.0536 - val_loss: 0.0593
# Epoch 39/50
# 7/7 - 1s - loss: 0.0533 - val_loss: 0.0599
# Epoch 40/50
# 7/7 - 1s - loss: 0.0535 - val_loss: 0.0588
# Epoch 41/50
# 7/7 - 1s - loss: 0.0534 - val_loss: 0.0595
# Epoch 42/50
# 7/7 - 1s - loss: 0.0531 - val_loss: 0.0601
# Epoch 43/50
# 7/7 - 1s - loss: 0.0540 - val_loss: 0.0603
# Epoch 44/50
# 7/7 - 1s - loss: 0.0536 - val_loss: 0.0594
# Epoch 45/50
# 7/7 - 1s - loss: 0.0525 - val_loss: 0.0608
# Epoch 46/50
# 7/7 - 1s - loss: 0.0520 - val_loss: 0.0592
# Epoch 47/50
# 7/7 - 1s - loss: 0.0519 - val_loss: 0.0600
# Epoch 48/50
# 7/7 - 1s - loss: 0.0518 - val_loss: 0.0593
# Epoch 49/50
# 7/7 - 1s - loss: 0.0514 - val_loss: 0.0601
# Epoch 50/50
# 7/7 - 1s - loss: 0.0513 - val_loss: 0.0595
# Model P0.2...
# Epoch 1/50
# 7/7 - 4s - loss: 0.1198 - val_loss: 0.1128
# Epoch 2/50
# 7/7 - 1s - loss: 0.1021 - val_loss: 0.1052
# Epoch 3/50
# 7/7 - 1s - loss: 0.0996 - val_loss: 0.1036
# Epoch 4/50
# 7/7 - 1s - loss: 0.0980 - val_loss: 0.1012
# Epoch 5/50
# 7/7 - 1s - loss: 0.0961 - val_loss: 0.0992
# Epoch 6/50
# 7/7 - 1s - loss: 0.0955 - val_loss: 0.0978
# Epoch 7/50
# 7/7 - 1s - loss: 0.0942 - val_loss: 0.0983
# Epoch 8/50
# 7/7 - 1s - loss: 0.0937 - val_loss: 0.0972
# Epoch 9/50
# 7/7 - 1s - loss: 0.0928 - val_loss: 0.0958
# Epoch 10/50
# 7/7 - 1s - loss: 0.0922 - val_loss: 0.0965
# Epoch 11/50
# 7/7 - 1s - loss: 0.0920 - val_loss: 0.0954
# Epoch 12/50
# 7/7 - 1s - loss: 0.0918 - val_loss: 0.0966
# Epoch 13/50
# 7/7 - 1s - loss: 0.0911 - val_loss: 0.0957
# Epoch 14/50
# 7/7 - 1s - loss: 0.0907 - val_loss: 0.0945
# Epoch 15/50
# 7/7 - 1s - loss: 0.0904 - val_loss: 0.0974
# Epoch 16/50
# 7/7 - 1s - loss: 0.0903 - val_loss: 0.0946
# Epoch 17/50
# 7/7 - 1s - loss: 0.0895 - val_loss: 0.0952
# Epoch 18/50
# 7/7 - 1s - loss: 0.0889 - val_loss: 0.0941
# Epoch 19/50
# 7/7 - 1s - loss: 0.0887 - val_loss: 0.0940
# Epoch 20/50
# 7/7 - 1s - loss: 0.0877 - val_loss: 0.0957
# Epoch 21/50
# 7/7 - 1s - loss: 0.0873 - val_loss: 0.0957
# Epoch 22/50
# 7/7 - 1s - loss: 0.0873 - val_loss: 0.0977
# Epoch 23/50
# 7/7 - 1s - loss: 0.0870 - val_loss: 0.0946
# Epoch 24/50
# 7/7 - 1s - loss: 0.0863 - val_loss: 0.0946
# Epoch 25/50
# 7/7 - 1s - loss: 0.0862 - val_loss: 0.0998
# Epoch 26/50
# 7/7 - 1s - loss: 0.0868 - val_loss: 0.0953
# Epoch 27/50
# 7/7 - 1s - loss: 0.0859 - val_loss: 0.0949
# Epoch 28/50
# 7/7 - 1s - loss: 0.0844 - val_loss: 0.0944
# Epoch 29/50
# 7/7 - 1s - loss: 0.0839 - val_loss: 0.0939
# Epoch 30/50
# 7/7 - 1s - loss: 0.0839 - val_loss: 0.0947
# Epoch 31/50
# 7/7 - 1s - loss: 0.0826 - val_loss: 0.0927
# Epoch 32/50
# 7/7 - 1s - loss: 0.0828 - val_loss: 0.1009
# Epoch 33/50
# 7/7 - 1s - loss: 0.0832 - val_loss: 0.0973
# Epoch 34/50
# 7/7 - 1s - loss: 0.0818 - val_loss: 0.0944
# Epoch 35/50
# 7/7 - 1s - loss: 0.0808 - val_loss: 0.0951
# Epoch 36/50
# 7/7 - 1s - loss: 0.0800 - val_loss: 0.0959
# Epoch 37/50
# 7/7 - 1s - loss: 0.0798 - val_loss: 0.0932
# Epoch 38/50
# 7/7 - 1s - loss: 0.0790 - val_loss: 0.0948
# Epoch 39/50
# 7/7 - 1s - loss: 0.0792 - val_loss: 0.0946
# Epoch 40/50
# 7/7 - 1s - loss: 0.0796 - val_loss: 0.0951
# Epoch 41/50
# 7/7 - 1s - loss: 0.0793 - val_loss: 0.0961
# Epoch 42/50
# 7/7 - 1s - loss: 0.0779 - val_loss: 0.0962
# Epoch 43/50
# 7/7 - 1s - loss: 0.0777 - val_loss: 0.0974
# Epoch 44/50
# 7/7 - 1s - loss: 0.0777 - val_loss: 0.0971
# Epoch 45/50
# 7/7 - 1s - loss: 0.0772 - val_loss: 0.0988
# Epoch 46/50
# 7/7 - 1s - loss: 0.0764 - val_loss: 0.0958
# Epoch 47/50
# 7/7 - 1s - loss: 0.0760 - val_loss: 0.0957
# Epoch 48/50
# 7/7 - 1s - loss: 0.0749 - val_loss: 0.0966
# Epoch 49/50
# 7/7 - 1s - loss: 0.0750 - val_loss: 0.0998
# Epoch 50/50
# 7/7 - 1s - loss: 0.0740 - val_loss: 0.0968
# Model P0.3...
# Epoch 1/50
# 7/7 - 4s - loss: 0.1245 - val_loss: 0.1250
# Epoch 2/50
# 7/7 - 1s - loss: 0.1185 - val_loss: 0.1228
# Epoch 3/50
# 7/7 - 1s - loss: 0.1175 - val_loss: 0.1220
# Epoch 4/50
# 7/7 - 1s - loss: 0.1162 - val_loss: 0.1203
# Epoch 5/50
# 7/7 - 1s - loss: 0.1150 - val_loss: 0.1190
# Epoch 6/50
# 7/7 - 1s - loss: 0.1140 - val_loss: 0.1180
# Epoch 7/50
# 7/7 - 1s - loss: 0.1134 - val_loss: 0.1167
# Epoch 8/50
# 7/7 - 1s - loss: 0.1123 - val_loss: 0.1159
# Epoch 9/50
# 7/7 - 1s - loss: 0.1114 - val_loss: 0.1141
# Epoch 10/50
# 7/7 - 1s - loss: 0.1106 - val_loss: 0.1135
# Epoch 11/50
# 7/7 - 1s - loss: 0.1097 - val_loss: 0.1206
# Epoch 12/50
# 7/7 - 1s - loss: 0.1109 - val_loss: 0.1122
# Epoch 13/50
# 7/7 - 1s - loss: 0.1090 - val_loss: 0.1137
# Epoch 14/50
# 7/7 - 1s - loss: 0.1084 - val_loss: 0.1118
# Epoch 15/50
# 7/7 - 1s - loss: 0.1076 - val_loss: 0.1123
# Epoch 16/50
# 7/7 - 1s - loss: 0.1088 - val_loss: 0.1120
# Epoch 17/50
# 7/7 - 1s - loss: 0.1091 - val_loss: 0.1183
# Epoch 18/50
# 7/7 - 1s - loss: 0.1093 - val_loss: 0.1111
# Epoch 19/50
# 7/7 - 1s - loss: 0.1072 - val_loss: 0.1121
# Epoch 20/50
# 7/7 - 1s - loss: 0.1065 - val_loss: 0.1113
# Epoch 21/50
# 7/7 - 1s - loss: 0.1055 - val_loss: 0.1116
# Epoch 22/50
# 7/7 - 1s - loss: 0.1052 - val_loss: 0.1121
# Epoch 23/50
# 7/7 - 1s - loss: 0.1054 - val_loss: 0.1124
# Epoch 24/50
# 7/7 - 1s - loss: 0.1048 - val_loss: 0.1121
# Epoch 25/50
# 7/7 - 1s - loss: 0.1039 - val_loss: 0.1127
# Epoch 26/50
# 7/7 - 1s - loss: 0.1039 - val_loss: 0.1131
# Epoch 27/50
# 7/7 - 1s - loss: 0.1033 - val_loss: 0.1119
# Epoch 28/50
# 7/7 - 1s - loss: 0.1034 - val_loss: 0.1143
# Epoch 29/50
# 7/7 - 1s - loss: 0.1031 - val_loss: 0.1132
# Epoch 30/50
# 7/7 - 1s - loss: 0.1020 - val_loss: 0.1121
# Epoch 31/50
# 7/7 - 1s - loss: 0.1020 - val_loss: 0.1122
# Epoch 32/50
# 7/7 - 1s - loss: 0.1008 - val_loss: 0.1127
# Epoch 33/50
# 7/7 - 1s - loss: 0.1001 - val_loss: 0.1124
# Epoch 34/50
# 7/7 - 1s - loss: 0.0997 - val_loss: 0.1150
# Epoch 35/50
# 7/7 - 1s - loss: 0.0997 - val_loss: 0.1127
# Epoch 36/50
# 7/7 - 1s - loss: 0.0990 - val_loss: 0.1150
# Epoch 37/50
# 7/7 - 1s - loss: 0.0995 - val_loss: 0.1114
# Epoch 38/50
# 7/7 - 1s - loss: 0.0979 - val_loss: 0.1134
# Epoch 39/50
# 7/7 - 1s - loss: 0.0969 - val_loss: 0.1116
# Epoch 40/50
# 7/7 - 1s - loss: 0.0965 - val_loss: 0.1130
# Epoch 41/50
# 7/7 - 1s - loss: 0.0949 - val_loss: 0.1141
# Epoch 42/50
# 7/7 - 1s - loss: 0.0950 - val_loss: 0.1142
# Epoch 43/50
# 7/7 - 1s - loss: 0.0947 - val_loss: 0.1181
# Epoch 44/50
# 7/7 - 1s - loss: 0.0945 - val_loss: 0.1124
# Epoch 45/50
# 7/7 - 1s - loss: 0.0931 - val_loss: 0.1137
# Epoch 46/50
# 7/7 - 1s - loss: 0.0921 - val_loss: 0.1126
# Epoch 47/50
# 7/7 - 1s - loss: 0.0928 - val_loss: 0.1154
# Epoch 48/50
# 7/7 - 1s - loss: 0.0917 - val_loss: 0.1134
# Epoch 49/50
# 7/7 - 1s - loss: 0.0908 - val_loss: 0.1153
# Epoch 50/50
# 7/7 - 1s - loss: 0.0911 - val_loss: 0.1125
# Model P0.4...
# Epoch 1/50
# 7/7 - 4s - loss: 0.1283 - val_loss: 0.1297
# Epoch 2/50
# 7/7 - 1s - loss: 0.1262 - val_loss: 0.1293
# Epoch 3/50
# 7/7 - 1s - loss: 0.1253 - val_loss: 0.1288
# Epoch 4/50
# 7/7 - 1s - loss: 0.1243 - val_loss: 0.1281
# Epoch 5/50
# 7/7 - 1s - loss: 0.1231 - val_loss: 0.1269
# Epoch 6/50
# 7/7 - 1s - loss: 0.1220 - val_loss: 0.1259
# Epoch 7/50
# 7/7 - 1s - loss: 0.1207 - val_loss: 0.1228
# Epoch 8/50
# 7/7 - 1s - loss: 0.1188 - val_loss: 0.1217
# Epoch 9/50
# 7/7 - 1s - loss: 0.1181 - val_loss: 0.1200
# Epoch 10/50
# 7/7 - 1s - loss: 0.1169 - val_loss: 0.1201
# Epoch 11/50
# 7/7 - 1s - loss: 0.1163 - val_loss: 0.1199
# Epoch 12/50
# 7/7 - 1s - loss: 0.1159 - val_loss: 0.1185
# Epoch 13/50
# 7/7 - 1s - loss: 0.1150 - val_loss: 0.1186
# Epoch 14/50
# 7/7 - 1s - loss: 0.1147 - val_loss: 0.1181
# Epoch 15/50
# 7/7 - 1s - loss: 0.1142 - val_loss: 0.1180
# Epoch 16/50
# 7/7 - 1s - loss: 0.1142 - val_loss: 0.1175
# Epoch 17/50
# 7/7 - 1s - loss: 0.1136 - val_loss: 0.1188
# Epoch 18/50
# 7/7 - 1s - loss: 0.1135 - val_loss: 0.1170
# Epoch 19/50
# 7/7 - 1s - loss: 0.1128 - val_loss: 0.1200
# Epoch 20/50
# 7/7 - 1s - loss: 0.1132 - val_loss: 0.1181
# Epoch 21/50
# 7/7 - 1s - loss: 0.1124 - val_loss: 0.1185
# Epoch 22/50
# 7/7 - 1s - loss: 0.1121 - val_loss: 0.1180
# Epoch 23/50
# 7/7 - 1s - loss: 0.1117 - val_loss: 0.1173
# Epoch 24/50
# 7/7 - 1s - loss: 0.1107 - val_loss: 0.1194
# Epoch 25/50
# 7/7 - 1s - loss: 0.1108 - val_loss: 0.1193
# Epoch 26/50
# 7/7 - 1s - loss: 0.1104 - val_loss: 0.1184
# Epoch 27/50
# 7/7 - 1s - loss: 0.1104 - val_loss: 0.1186
# Epoch 28/50
# 7/7 - 1s - loss: 0.1101 - val_loss: 0.1205
# Epoch 29/50
# 7/7 - 1s - loss: 0.1092 - val_loss: 0.1186
# Epoch 30/50
# 7/7 - 1s - loss: 0.1088 - val_loss: 0.1194
# Epoch 31/50
# 7/7 - 1s - loss: 0.1083 - val_loss: 0.1193
# Epoch 32/50
# 7/7 - 1s - loss: 0.1078 - val_loss: 0.1192
# Epoch 33/50
# 7/7 - 1s - loss: 0.1089 - val_loss: 0.1216
# Epoch 34/50
# 7/7 - 1s - loss: 0.1069 - val_loss: 0.1190
# Epoch 35/50
# 7/7 - 1s - loss: 0.1066 - val_loss: 0.1206
# Epoch 36/50
# 7/7 - 1s - loss: 0.1056 - val_loss: 0.1202
# Epoch 37/50
# 7/7 - 1s - loss: 0.1057 - val_loss: 0.1218
# Epoch 38/50
# 7/7 - 1s - loss: 0.1053 - val_loss: 0.1218
# Epoch 39/50
# 7/7 - 1s - loss: 0.1061 - val_loss: 0.1239
# Epoch 40/50
# 7/7 - 1s - loss: 0.1055 - val_loss: 0.1182
# Epoch 41/50
# 7/7 - 1s - loss: 0.1042 - val_loss: 0.1210
# Epoch 42/50
# 7/7 - 1s - loss: 0.1019 - val_loss: 0.1230
# Epoch 43/50
# 7/7 - 1s - loss: 0.1025 - val_loss: 0.1214
# Epoch 44/50
# 7/7 - 1s - loss: 0.1015 - val_loss: 0.1216
# Epoch 45/50
# 7/7 - 1s - loss: 0.1014 - val_loss: 0.1217
# Epoch 46/50
# 7/7 - 1s - loss: 0.1006 - val_loss: 0.1214
# Epoch 47/50
# 7/7 - 1s - loss: 0.1002 - val_loss: 0.1213
# Epoch 48/50
# 7/7 - 1s - loss: 0.0994 - val_loss: 0.1213
# Epoch 49/50
# 7/7 - 1s - loss: 0.0982 - val_loss: 0.1221
# Epoch 50/50
# 7/7 - 1s - loss: 0.0978 - val_loss: 0.1219
# Model P0.5...
# Epoch 1/50
# 7/7 - 4s - loss: 0.1294 - val_loss: 0.1311
# Epoch 2/50
# 7/7 - 1s - loss: 0.1285 - val_loss: 0.1308
# Epoch 3/50
# 7/7 - 1s - loss: 0.1274 - val_loss: 0.1298
# Epoch 4/50
# 7/7 - 1s - loss: 0.1252 - val_loss: 0.1276
# Epoch 5/50
# 7/7 - 1s - loss: 0.1214 - val_loss: 0.1237
# Epoch 6/50
# 7/7 - 1s - loss: 0.1195 - val_loss: 0.1232
# Epoch 7/50
# 7/7 - 1s - loss: 0.1184 - val_loss: 0.1212
# Epoch 8/50
# 7/7 - 1s - loss: 0.1167 - val_loss: 0.1194
# Epoch 9/50
# 7/7 - 1s - loss: 0.1152 - val_loss: 0.1183
# Epoch 10/50
# 7/7 - 1s - loss: 0.1141 - val_loss: 0.1182
# Epoch 11/50
# 7/7 - 1s - loss: 0.1137 - val_loss: 0.1179
# Epoch 12/50
# 7/7 - 1s - loss: 0.1133 - val_loss: 0.1174
# Epoch 13/50
# 7/7 - 1s - loss: 0.1126 - val_loss: 0.1161
# Epoch 14/50
# 7/7 - 1s - loss: 0.1119 - val_loss: 0.1168
# Epoch 15/50
# 7/7 - 1s - loss: 0.1114 - val_loss: 0.1155
# Epoch 16/50
# 7/7 - 1s - loss: 0.1106 - val_loss: 0.1158
# Epoch 17/50
# 7/7 - 1s - loss: 0.1100 - val_loss: 0.1148
# Epoch 18/50
# 7/7 - 1s - loss: 0.1100 - val_loss: 0.1152
# Epoch 19/50
# 7/7 - 1s - loss: 0.1090 - val_loss: 0.1155
# Epoch 20/50
# 7/7 - 1s - loss: 0.1089 - val_loss: 0.1149
# Epoch 21/50
# 7/7 - 1s - loss: 0.1086 - val_loss: 0.1167
# Epoch 22/50
# 7/7 - 1s - loss: 0.1086 - val_loss: 0.1159
# Epoch 23/50
# 7/7 - 1s - loss: 0.1081 - val_loss: 0.1152
# Epoch 24/50
# 7/7 - 1s - loss: 0.1075 - val_loss: 0.1156
# Epoch 25/50
# 7/7 - 1s - loss: 0.1071 - val_loss: 0.1160
# Epoch 26/50
# 7/7 - 1s - loss: 0.1063 - val_loss: 0.1178
# Epoch 27/50
# 7/7 - 1s - loss: 0.1065 - val_loss: 0.1165
# Epoch 28/50
# 7/7 - 1s - loss: 0.1061 - val_loss: 0.1187
# Epoch 29/50
# 7/7 - 1s - loss: 0.1061 - val_loss: 0.1176
# Epoch 30/50
# 7/7 - 1s - loss: 0.1048 - val_loss: 0.1183
# Epoch 31/50
# 7/7 - 1s - loss: 0.1046 - val_loss: 0.1186
# Epoch 32/50
# 7/7 - 1s - loss: 0.1046 - val_loss: 0.1182
# Epoch 33/50
# 7/7 - 1s - loss: 0.1036 - val_loss: 0.1168
# Epoch 34/50
# 7/7 - 1s - loss: 0.1029 - val_loss: 0.1187
# Epoch 35/50
# 7/7 - 1s - loss: 0.1026 - val_loss: 0.1215
# Epoch 36/50
# 7/7 - 1s - loss: 0.1025 - val_loss: 0.1193
# Epoch 37/50
# 7/7 - 1s - loss: 0.1020 - val_loss: 0.1199
# Epoch 38/50
# 7/7 - 1s - loss: 0.1014 - val_loss: 0.1196
# Epoch 39/50
# 7/7 - 1s - loss: 0.1010 - val_loss: 0.1201
# Epoch 40/50
# 7/7 - 1s - loss: 0.1010 - val_loss: 0.1253
# Epoch 41/50
# 7/7 - 1s - loss: 0.1014 - val_loss: 0.1202
# Epoch 42/50
# 7/7 - 1s - loss: 0.1005 - val_loss: 0.1190
# Epoch 43/50
# 7/7 - 1s - loss: 0.0993 - val_loss: 0.1197
# Epoch 44/50
# 7/7 - 1s - loss: 0.0987 - val_loss: 0.1215
# Epoch 45/50
# 7/7 - 1s - loss: 0.0978 - val_loss: 0.1215
# Epoch 46/50
# 7/7 - 1s - loss: 0.0974 - val_loss: 0.1193
# Epoch 47/50
# 7/7 - 1s - loss: 0.0970 - val_loss: 0.1199
# Epoch 48/50
# 7/7 - 1s - loss: 0.0964 - val_loss: 0.1235
# Epoch 49/50
# 7/7 - 1s - loss: 0.0963 - val_loss: 0.1210
# Epoch 50/50
# 7/7 - 1s - loss: 0.0963 - val_loss: 0.1195
# Model P0.6...
# Epoch 1/50
# 7/7 - 4s - loss: 0.1294 - val_loss: 0.1290
# Epoch 2/50
# 7/7 - 1s - loss: 0.1268 - val_loss: 0.1271
# Epoch 3/50
# 7/7 - 1s - loss: 0.1240 - val_loss: 0.1258
# Epoch 4/50
# 7/7 - 1s - loss: 0.1205 - val_loss: 0.1227
# Epoch 5/50
# 7/7 - 1s - loss: 0.1153 - val_loss: 0.1173
# Epoch 6/50
# 7/7 - 1s - loss: 0.1110 - val_loss: 0.1136
# Epoch 7/50
# 7/7 - 1s - loss: 0.1091 - val_loss: 0.1114
# Epoch 8/50
# 7/7 - 1s - loss: 0.1066 - val_loss: 0.1095
# Epoch 9/50
# 7/7 - 1s - loss: 0.1052 - val_loss: 0.1083
# Epoch 10/50
# 7/7 - 1s - loss: 0.1036 - val_loss: 0.1081
# Epoch 11/50
# 7/7 - 1s - loss: 0.1029 - val_loss: 0.1068
# Epoch 12/50
# 7/7 - 1s - loss: 0.1022 - val_loss: 0.1075
# Epoch 13/50
# 7/7 - 1s - loss: 0.1016 - val_loss: 0.1063
# Epoch 14/50
# 7/7 - 1s - loss: 0.1013 - val_loss: 0.1061
# Epoch 15/50
# 7/7 - 1s - loss: 0.1004 - val_loss: 0.1053
# Epoch 16/50
# 7/7 - 1s - loss: 0.0999 - val_loss: 0.1058
# Epoch 17/50
# 7/7 - 1s - loss: 0.1001 - val_loss: 0.1077
# Epoch 18/50
# 7/7 - 1s - loss: 0.1001 - val_loss: 0.1067
# Epoch 19/50
# 7/7 - 1s - loss: 0.1003 - val_loss: 0.1073
# Epoch 20/50
# 7/7 - 1s - loss: 0.0999 - val_loss: 0.1055
# Epoch 21/50
# 7/7 - 1s - loss: 0.0990 - val_loss: 0.1047
# Epoch 22/50
# 7/7 - 1s - loss: 0.0988 - val_loss: 0.1070
# Epoch 23/50
# 7/7 - 1s - loss: 0.0984 - val_loss: 0.1048
# Epoch 24/50
# 7/7 - 1s - loss: 0.0979 - val_loss: 0.1084
# Epoch 25/50
# 7/7 - 1s - loss: 0.0985 - val_loss: 0.1047
# Epoch 26/50
# 7/7 - 1s - loss: 0.0975 - val_loss: 0.1056
# Epoch 27/50
# 7/7 - 1s - loss: 0.0973 - val_loss: 0.1063
# Epoch 28/50
# 7/7 - 1s - loss: 0.0968 - val_loss: 0.1053
# Epoch 29/50
# 7/7 - 1s - loss: 0.0965 - val_loss: 0.1070
# Epoch 30/50
# 7/7 - 1s - loss: 0.0965 - val_loss: 0.1051
# Epoch 31/50
# 7/7 - 1s - loss: 0.0962 - val_loss: 0.1052
# Epoch 32/50
# 7/7 - 1s - loss: 0.0964 - val_loss: 0.1072
# Epoch 33/50
# 7/7 - 1s - loss: 0.0968 - val_loss: 0.1062
# Epoch 34/50
# 7/7 - 1s - loss: 0.0960 - val_loss: 0.1082
# Epoch 35/50
# 7/7 - 1s - loss: 0.0959 - val_loss: 0.1056
# Epoch 36/50
# 7/7 - 1s - loss: 0.0947 - val_loss: 0.1069
# Epoch 37/50
# 7/7 - 1s - loss: 0.0944 - val_loss: 0.1072
# Epoch 38/50
# 7/7 - 1s - loss: 0.0942 - val_loss: 0.1059
# Epoch 39/50
# 7/7 - 1s - loss: 0.0934 - val_loss: 0.1072
# Epoch 40/50
# 7/7 - 1s - loss: 0.0927 - val_loss: 0.1058
# Epoch 41/50
# 7/7 - 1s - loss: 0.0925 - val_loss: 0.1068
# Epoch 42/50
# 7/7 - 1s - loss: 0.0925 - val_loss: 0.1081
# Epoch 43/50
# 7/7 - 1s - loss: 0.0923 - val_loss: 0.1069
# Epoch 44/50
# 7/7 - 1s - loss: 0.0913 - val_loss: 0.1071
# Epoch 45/50
# 7/7 - 1s - loss: 0.0916 - val_loss: 0.1069
# Epoch 46/50
# 7/7 - 1s - loss: 0.0911 - val_loss: 0.1091
# Epoch 47/50
# 7/7 - 1s - loss: 0.0910 - val_loss: 0.1084
# Epoch 48/50
# 7/7 - 1s - loss: 0.0906 - val_loss: 0.1067
# Epoch 49/50
# 7/7 - 1s - loss: 0.0903 - val_loss: 0.1073
# Epoch 50/50
# 7/7 - 1s - loss: 0.0896 - val_loss: 0.1080
# Model P0.7...
# Epoch 1/50
# 7/7 - 4s - loss: 0.1280 - val_loss: 0.1206
# Epoch 2/50
# 7/7 - 1s - loss: 0.1195 - val_loss: 0.1173
# Epoch 3/50
# 7/7 - 1s - loss: 0.1158 - val_loss: 0.1156
# Epoch 4/50
# 7/7 - 1s - loss: 0.1124 - val_loss: 0.1136
# Epoch 5/50
# 7/7 - 1s - loss: 0.1080 - val_loss: 0.1083
# Epoch 6/50
# 7/7 - 1s - loss: 0.1017 - val_loss: 0.1043
# Epoch 7/50
# 7/7 - 1s - loss: 0.0971 - val_loss: 0.0980
# Epoch 8/50
# 7/7 - 1s - loss: 0.0937 - val_loss: 0.0951
# Epoch 9/50
# 7/7 - 1s - loss: 0.0915 - val_loss: 0.0932
# Epoch 10/50
# 7/7 - 1s - loss: 0.0898 - val_loss: 0.0919
# Epoch 11/50
# 7/7 - 1s - loss: 0.0880 - val_loss: 0.0919
# Epoch 12/50
# 7/7 - 1s - loss: 0.0872 - val_loss: 0.0911
# Epoch 13/50
# 7/7 - 1s - loss: 0.0873 - val_loss: 0.0903
# Epoch 14/50
# 7/7 - 1s - loss: 0.0857 - val_loss: 0.0902
# Epoch 15/50
# 7/7 - 1s - loss: 0.0852 - val_loss: 0.0900
# Epoch 16/50
# 7/7 - 1s - loss: 0.0853 - val_loss: 0.0896
# Epoch 17/50
# 7/7 - 1s - loss: 0.0843 - val_loss: 0.0890
# Epoch 18/50
# 7/7 - 1s - loss: 0.0842 - val_loss: 0.0886
# Epoch 19/50
# 7/7 - 1s - loss: 0.0844 - val_loss: 0.0891
# Epoch 20/50
# 7/7 - 1s - loss: 0.0836 - val_loss: 0.0885
# Epoch 21/50
# 7/7 - 1s - loss: 0.0834 - val_loss: 0.0887
# Epoch 22/50
# 7/7 - 1s - loss: 0.0829 - val_loss: 0.0881
# Epoch 23/50
# 7/7 - 1s - loss: 0.0827 - val_loss: 0.0878
# Epoch 24/50
# 7/7 - 1s - loss: 0.0824 - val_loss: 0.0875
# Epoch 25/50
# 7/7 - 1s - loss: 0.0824 - val_loss: 0.0879
# Epoch 26/50
# 7/7 - 1s - loss: 0.0822 - val_loss: 0.0873
# Epoch 27/50
# 7/7 - 1s - loss: 0.0820 - val_loss: 0.0873
# Epoch 28/50
# 7/7 - 1s - loss: 0.0817 - val_loss: 0.0875
# Epoch 29/50
# 7/7 - 1s - loss: 0.0814 - val_loss: 0.0873
# Epoch 30/50
# 7/7 - 1s - loss: 0.0812 - val_loss: 0.0872
# Epoch 31/50
# 7/7 - 1s - loss: 0.0809 - val_loss: 0.0889
# Epoch 32/50
# 7/7 - 1s - loss: 0.0805 - val_loss: 0.0878
# Epoch 33/50
# 7/7 - 1s - loss: 0.0805 - val_loss: 0.0880
# Epoch 34/50
# 7/7 - 1s - loss: 0.0802 - val_loss: 0.0883
# Epoch 35/50
# 7/7 - 1s - loss: 0.0802 - val_loss: 0.0877
# Epoch 36/50
# 7/7 - 1s - loss: 0.0797 - val_loss: 0.0882
# Epoch 37/50
# 7/7 - 1s - loss: 0.0795 - val_loss: 0.0882
# Epoch 38/50
# 7/7 - 1s - loss: 0.0797 - val_loss: 0.0894
# Epoch 39/50
# 7/7 - 1s - loss: 0.0800 - val_loss: 0.0903
# Epoch 40/50
# 7/7 - 1s - loss: 0.0794 - val_loss: 0.0874
# Epoch 41/50
# 7/7 - 1s - loss: 0.0789 - val_loss: 0.0888
# Epoch 42/50
# 7/7 - 1s - loss: 0.0790 - val_loss: 0.0910
# Epoch 43/50
# 7/7 - 1s - loss: 0.0798 - val_loss: 0.0909
# Epoch 44/50
# 7/7 - 1s - loss: 0.0795 - val_loss: 0.0888
# Epoch 45/50
# 7/7 - 1s - loss: 0.0789 - val_loss: 0.0888
# Epoch 46/50
# 7/7 - 1s - loss: 0.0782 - val_loss: 0.0890
# Epoch 47/50
# 7/7 - 1s - loss: 0.0777 - val_loss: 0.0886
# Epoch 48/50
# 7/7 - 1s - loss: 0.0775 - val_loss: 0.0894
# Epoch 49/50
# 7/7 - 1s - loss: 0.0773 - val_loss: 0.0891
# Epoch 50/50
# 7/7 - 1s - loss: 0.0773 - val_loss: 0.0884
# Model P0.8...
# Epoch 1/50
# 7/7 - 4s - loss: 0.1206 - val_loss: 0.1047
# Epoch 2/50
# 7/7 - 1s - loss: 0.1037 - val_loss: 0.0991
# Epoch 3/50
# 7/7 - 1s - loss: 0.0973 - val_loss: 0.0967
# Epoch 4/50
# 7/7 - 1s - loss: 0.0947 - val_loss: 0.0953
# Epoch 5/50
# 7/7 - 1s - loss: 0.0912 - val_loss: 0.0916
# Epoch 6/50
# 7/7 - 1s - loss: 0.0862 - val_loss: 0.0854
# Epoch 7/50
# 7/7 - 1s - loss: 0.0799 - val_loss: 0.0805
# Epoch 8/50
# 7/7 - 1s - loss: 0.0763 - val_loss: 0.0775
# Epoch 9/50
# 7/7 - 1s - loss: 0.0730 - val_loss: 0.0736
# Epoch 10/50
# 7/7 - 1s - loss: 0.0708 - val_loss: 0.0721
# Epoch 11/50
# 7/7 - 1s - loss: 0.0691 - val_loss: 0.0709
# Epoch 12/50
# 7/7 - 1s - loss: 0.0684 - val_loss: 0.0720
# Epoch 13/50
# 7/7 - 1s - loss: 0.0676 - val_loss: 0.0698
# Epoch 14/50
# 7/7 - 1s - loss: 0.0662 - val_loss: 0.0692
# Epoch 15/50
# 7/7 - 1s - loss: 0.0658 - val_loss: 0.0687
# Epoch 16/50
# 7/7 - 1s - loss: 0.0653 - val_loss: 0.0682
# Epoch 17/50
# 7/7 - 1s - loss: 0.0645 - val_loss: 0.0677
# Epoch 18/50
# 7/7 - 1s - loss: 0.0643 - val_loss: 0.0675
# Epoch 19/50
# 7/7 - 1s - loss: 0.0640 - val_loss: 0.0678
# Epoch 20/50
# 7/7 - 1s - loss: 0.0638 - val_loss: 0.0676
# Epoch 21/50
# 7/7 - 1s - loss: 0.0638 - val_loss: 0.0679
# Epoch 22/50
# 7/7 - 1s - loss: 0.0634 - val_loss: 0.0670
# Epoch 23/50
# 7/7 - 1s - loss: 0.0630 - val_loss: 0.0670
# Epoch 24/50
# 7/7 - 1s - loss: 0.0627 - val_loss: 0.0672
# Epoch 25/50
# 7/7 - 1s - loss: 0.0623 - val_loss: 0.0660
# Epoch 26/50
# 7/7 - 1s - loss: 0.0621 - val_loss: 0.0666
# Epoch 27/50
# 7/7 - 1s - loss: 0.0620 - val_loss: 0.0669
# Epoch 28/50
# 7/7 - 1s - loss: 0.0625 - val_loss: 0.0669
# Epoch 29/50
# 7/7 - 1s - loss: 0.0619 - val_loss: 0.0663
# Epoch 30/50
# 7/7 - 1s - loss: 0.0615 - val_loss: 0.0660
# Epoch 31/50
# 7/7 - 1s - loss: 0.0613 - val_loss: 0.0661
# Epoch 32/50
# 7/7 - 1s - loss: 0.0611 - val_loss: 0.0660
# Epoch 33/50
# 7/7 - 1s - loss: 0.0608 - val_loss: 0.0662
# Epoch 34/50
# 7/7 - 1s - loss: 0.0611 - val_loss: 0.0657
# Epoch 35/50
# 7/7 - 1s - loss: 0.0608 - val_loss: 0.0661
# Epoch 36/50
# 7/7 - 1s - loss: 0.0603 - val_loss: 0.0659
# Epoch 37/50
# 7/7 - 1s - loss: 0.0602 - val_loss: 0.0663
# Epoch 38/50
# 7/7 - 1s - loss: 0.0601 - val_loss: 0.0657
# Epoch 39/50
# 7/7 - 1s - loss: 0.0600 - val_loss: 0.0658
# Epoch 40/50
# 7/7 - 1s - loss: 0.0600 - val_loss: 0.0659
# Epoch 41/50
# 7/7 - 1s - loss: 0.0598 - val_loss: 0.0666
# Epoch 42/50
# 7/7 - 1s - loss: 0.0599 - val_loss: 0.0658
# Epoch 43/50
# 7/7 - 1s - loss: 0.0600 - val_loss: 0.0661
# Epoch 44/50
# 7/7 - 1s - loss: 0.0594 - val_loss: 0.0658
# Epoch 45/50
# 7/7 - 1s - loss: 0.0596 - val_loss: 0.0661
# Epoch 46/50
# 7/7 - 1s - loss: 0.0595 - val_loss: 0.0660
# Epoch 47/50
# 7/7 - 1s - loss: 0.0593 - val_loss: 0.0673
# Epoch 48/50
# 7/7 - 1s - loss: 0.0595 - val_loss: 0.0659
# Epoch 49/50
# 7/7 - 1s - loss: 0.0589 - val_loss: 0.0655
# Epoch 50/50
# 7/7 - 1s - loss: 0.0590 - val_loss: 0.0661
# Model P0.9...
# Epoch 1/50
# 7/7 - 4s - loss: 0.1139 - val_loss: 0.0822
# Epoch 2/50
# 7/7 - 1s - loss: 0.0758 - val_loss: 0.0685
# Epoch 3/50
# 7/7 - 1s - loss: 0.0687 - val_loss: 0.0637
# Epoch 4/50
# 7/7 - 1s - loss: 0.0642 - val_loss: 0.0632
# Epoch 5/50
# 7/7 - 1s - loss: 0.0621 - val_loss: 0.0602
# Epoch 6/50
# 7/7 - 1s - loss: 0.0598 - val_loss: 0.0574
# Epoch 7/50
# 7/7 - 1s - loss: 0.0563 - val_loss: 0.0544
# Epoch 8/50
# 7/7 - 1s - loss: 0.0521 - val_loss: 0.0520
# Epoch 9/50
# 7/7 - 1s - loss: 0.0480 - val_loss: 0.0474
# Epoch 10/50
# 7/7 - 1s - loss: 0.0451 - val_loss: 0.0458
# Epoch 11/50
# 7/7 - 1s - loss: 0.0436 - val_loss: 0.0442
# Epoch 12/50
# 7/7 - 1s - loss: 0.0426 - val_loss: 0.0448
# Epoch 13/50
# 7/7 - 1s - loss: 0.0419 - val_loss: 0.0436
# Epoch 14/50
# 7/7 - 1s - loss: 0.0407 - val_loss: 0.0424
# Epoch 15/50
# 7/7 - 1s - loss: 0.0400 - val_loss: 0.0420
# Epoch 16/50
# 7/7 - 1s - loss: 0.0397 - val_loss: 0.0413
# Epoch 17/50
# 7/7 - 1s - loss: 0.0390 - val_loss: 0.0407
# Epoch 18/50
# 7/7 - 1s - loss: 0.0386 - val_loss: 0.0403
# Epoch 19/50
# 7/7 - 1s - loss: 0.0382 - val_loss: 0.0401
# Epoch 20/50
# 7/7 - 1s - loss: 0.0378 - val_loss: 0.0401
# Epoch 21/50
# 7/7 - 1s - loss: 0.0377 - val_loss: 0.0397
# Epoch 22/50
# 7/7 - 1s - loss: 0.0375 - val_loss: 0.0399
# Epoch 23/50
# 7/7 - 1s - loss: 0.0373 - val_loss: 0.0391
# Epoch 24/50
# 7/7 - 1s - loss: 0.0371 - val_loss: 0.0388
# Epoch 25/50
# 7/7 - 1s - loss: 0.0366 - val_loss: 0.0387
# Epoch 26/50
# 7/7 - 1s - loss: 0.0370 - val_loss: 0.0388
# Epoch 27/50
# 7/7 - 1s - loss: 0.0367 - val_loss: 0.0386
# Epoch 28/50
# 7/7 - 1s - loss: 0.0365 - val_loss: 0.0387
# Epoch 29/50
# 7/7 - 1s - loss: 0.0362 - val_loss: 0.0384
# Epoch 30/50
# 7/7 - 1s - loss: 0.0361 - val_loss: 0.0384
# Epoch 31/50
# 7/7 - 1s - loss: 0.0364 - val_loss: 0.0392
# Epoch 32/50
# 7/7 - 1s - loss: 0.0364 - val_loss: 0.0383
# Epoch 33/50
# 7/7 - 1s - loss: 0.0362 - val_loss: 0.0386
# Epoch 34/50
# 7/7 - 1s - loss: 0.0357 - val_loss: 0.0382
# Epoch 35/50
# 7/7 - 1s - loss: 0.0358 - val_loss: 0.0381
# Epoch 36/50
# 7/7 - 1s - loss: 0.0356 - val_loss: 0.0379
# Epoch 37/50
# 7/7 - 1s - loss: 0.0353 - val_loss: 0.0378
# Epoch 38/50
# 7/7 - 1s - loss: 0.0353 - val_loss: 0.0378
# Epoch 39/50
# 7/7 - 1s - loss: 0.0354 - val_loss: 0.0377
# Epoch 40/50
# 7/7 - 1s - loss: 0.0349 - val_loss: 0.0375
# Epoch 41/50
# 7/7 - 1s - loss: 0.0350 - val_loss: 0.0375
# Epoch 42/50
# 7/7 - 1s - loss: 0.0350 - val_loss: 0.0380
# Epoch 43/50
# 7/7 - 1s - loss: 0.0350 - val_loss: 0.0376
# Epoch 44/50
# 7/7 - 1s - loss: 0.0348 - val_loss: 0.0374
# Epoch 45/50
# 7/7 - 1s - loss: 0.0348 - val_loss: 0.0390
# Epoch 46/50
# 7/7 - 1s - loss: 0.0354 - val_loss: 0.0394
# Epoch 47/50
# 7/7 - 1s - loss: 0.0355 - val_loss: 0.0379
# Epoch 48/50
# 7/7 - 1s - loss: 0.0353 - val_loss: 0.0382
# Epoch 49/50
# 7/7 - 1s - loss: 0.0351 - val_loss: 0.0401
# Epoch 50/50
# 7/7 - 1s - loss: 0.0352 - val_loss: 0.0387
# CPU times: user 6min 25s, sys: 17 s, total: 6min 42s
# Wall time: 5min 5s

# %% [markdown]
# ## **Make Clean Checkpoints**

# %%
# %%time

# ckpt_folders = sorted(glob.glob(os.path.join(os.environ["CHECKPOINT_PATH"], os.environ["NOTEBOOKNAME"], "P*")))
# max_to_keep = 3

# for f in ckpt_folders:
#     # 7 files must be located in ckpt_folders. (latest 3 ckpt and checkpoint file)
#     assert len(os.listdir(f)) >= (1 + max_to_keep * 2), f"Checkpoints in {f} is less then 3 (max_to_keep)."
    
#     rm_files = os.listdir(f)[1:-2*max_to_keep] # [1:-6]
#     _ = [os.remove(rm_file) for rm_file in rm_files]

# %% [markdown]
# # **Visualize**

# %% [markdown]
# ## **Plot Histories**

# %%
# def draw_histories(histories):
#     """Draw 9 histories in one plot."""
#     assert len(histories.keys) == args["NUM_QUANTILE"]
    
#     plt.figure(figsize = (14, 9), facecolor = "white", dpi = 96)

#     for model_name, history in histories.items():
#         pos = int(model_name.split(".")[-1])
#         plt.subplot(3, 3, pos)
                
#         plt.plot(history.epoch, history.history["output_2_loss"], label = "output_2_loss")
#         plt.plot(history.epoch, history.history["val_output_2_loss"], label = "val_output_2_loss")
    
#         plt.legend()
#         plt.title(title, fontsize = "x-large")
#         plt.xlabel("Epoch")
#         plt.ylabel("Pinball Loss")
    
#         plt.grid(True)
        
#     plt.tight_layout()
#     plt.show()

# %%
# draw_histories(histories)

# %% [markdown]
# ## **Target Model Prediction**

# %%
def load_latest_models(ckpt_folders: list) -> list:
    """Load latest weights of target model from saved ckeckpoints."""    
    models = []
    for f in ckpt_folders:
        latest = tf.train.latest_checkpoint(f)
        print(f"Load latest checkpoints: {latest}...")
        
        model_name = latest.split(os.path.sep)[2] # ckpt/[notebookname]/P0.1/...

        # Define a new AR-LSTM model and load checkpoints.
        model = create_AR_LSTM(model_name = model_name)

        ckpt = tf.train.Checkpoint(model)
        ckpt.restore(latest).expect_partial()
        models.append(model)
        
    return models


def draw_pred(foo, bar):
    """Draw the predictions and labels."""
#     inputs, y_true = np.squeeze(inputs), np.squeeze(y_true)
#     y_preds = [np.squeeze(y_pred) for y_pred in y_preds]
    
    plt.figure(figsize = (14, 4), facecolor = "white")
    
    plt.plot(foo, label = "true")
    plt.plot(bar, label = "averaged")

#     plt.plot(np.arange(len(inputs)), inputs, lw = 1.5, label = "Inputs")
#     plt.plot(np.arange(len(inputs), len(inputs) + len(y_pred), 1), y_pred, marker = "o", lw = 1.5, label = "Predictions")
#     plt.plot(np.arange(len(inputs), len(inputs) + len(y_true), 1), y_true, marker = "X", lw = 1.5, label = "Label")

#     plt.title(f"Target Model T{tau:.1f}")
#     plt.xlabel("Time [day]")
#     plt.ylabel("Target")
#     plt.ylim([-0.8, max(y_true) * 1.1])
    plt.legend()

#     plt.xticks(
#         np.arange(0, args["DAY"] * (args["W_INP"] + args["W_TAR"]) + 1, args["DAY"]), 
#         [f"D+{i}" for i in np.arange(args["W_INP"] + args["W_TAR"] + 1)])
#     plt.grid(True)
        
    plt.tight_layout()
    
#     if save_fig:
#         plt.savefig(f"pngs/{os.environ['NOTEBOOKNAME']}_{model_name}.png", dpi = 96)
        
    plt.show()

# %%
# Now, unbatch the dataset to predict only one sequences (i.e. 7 days).
unbatched_vl_dataset = vl_dataset.unbatch().batch(1)
model = make_residual()

for t in unbatched_vl_dataset.take(1):
    x, r_y = t # inp, aux_tar, real_tar
    
    draw_pred(
        foo = tf.reshape(x[0, :, :, -1:], (-1,)).numpy(), # not x
        bar = tf.reshape(model.predict(x[0, :, :, -1:]), (-1,)).numpy())
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f6ad01b40d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# Restore latest models from saved checkpoints.
ckpt_folders = sorted(glob.glob(os.path.join(os.environ["CHECKPOINT_PATH"], os.environ["NOTEBOOKNAME"], "P*")))
models = load_latest_models(ckpt_folders)

# Now, unbatch the dataset to predict only one sequences (i.e. 7 days).
unbatched_vl_dataset = vl_dataset.unbatch().batch(1)

for t in unbatched_vl_dataset.take(1):
    x, r_y = t # inp, aux_tar, real_tar
    
    draw_pred(
        inputs = vl_tensor[:args["DAY"] * args["W_INP"], -1], # not x
        y_preds = [tf.reshape(model.predict(x), (-1, )).numpy() for model in models],
        y_true = tf.reshape(r_y, (-1, )))
# Out:
# Load latest checkpoints: ckpt/try106/P0.1/cp-034-0.0588.ckpt...
# Load latest checkpoints: ckpt/try106/P0.2/cp-031-0.0927.ckpt...
# Load latest checkpoints: ckpt/try106/P0.3/cp-018-0.1111.ckpt...
# Load latest checkpoints: ckpt/try106/P0.4/cp-018-0.1170.ckpt...
# Load latest checkpoints: ckpt/try106/P0.5/cp-017-0.1148.ckpt...
# Load latest checkpoints: ckpt/try106/P0.6/cp-025-0.1047.ckpt...
# Load latest checkpoints: ckpt/try106/P0.7/cp-030-0.0872.ckpt...
# Load latest checkpoints: ckpt/try106/P0.8/cp-049-0.0655.ckpt...
# Load latest checkpoints: ckpt/try106/P0.9/cp-044-0.0374.ckpt...
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f6b1c565598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f6b1c52da60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f6ac4612f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f6abc114378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f6ac4612158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# # **Make Submissions**

# %%
# %%time
# Restore latest models from saved checkpoints.
ckpt_folders = sorted(glob.glob(os.path.join(os.environ["CHECKPOINT_PATH"], os.environ["NOTEBOOKNAME"], "P*")))
models = load_latest_models(ckpt_folders)

# Predict the test datasets.
# We need to drop auxiliary outputs and squeeze dimensions (i.e. [batch, 96, 1] => [batch, 96]).
preds = [np.array(tf.reshape(model.predict(ts_dataset), (-1, ))) for model in models]

# %%
submission = pd.read_csv(os.path.join(os.environ["LOCAL_DATA_PATH"], "sample_submission.csv"), index_col = "id")
submission.head()

# %%
for column, pred in zip(submission.columns, preds):
    foo = np.reshape(pred, (-1,))
    foo = (foo * args["TARGET_STD"]) + args["TARGET_MEAN"]
    foo = np.where(foo < args["EPSILON"], 0, foo) # clip by value
    
    submission[column] = foo

# %%
submission.head()

# %%
submission.to_csv(os.path.join(os.environ["SUBMISSION_PATH"], f"{os.environ['NOTEBOOKNAME']}_submission.csv"))

# %% [markdown]
# # **Default Setting**
#
# * Python: 3.6.9
# * ML Framework: tensorflow-gpu 2.4.0 / tensorflow-addons 0.12.0
# * CPU: AMD Ryzen 5 5600X 6-Core Processor
# * GPU: GeForce RTX 3070 (8G) (CUDA 11.1)
# * RAM: 32G
# * Platform: Linux Ubuntu 20.04 LTS (desktop)
#
# Install below APIs using anaconda as belows.
#
# ```
# conda create -n py36 python=3.6.9
# conda acitvate py36
# pip3 install tensorflow-gpu=2.4.0 tensorflow-addons=0.12.0
# conda install pandas, matplotlib, pydot, jupyterlab, cudatoolkit
# ```
#
# And now, you can run jupyter lab (or jupyter notebook).
#
# ```
# jupyter lab
# ```

# %%
# %env NOTEBOOKNAME try168
# %env LOCAL_DATA_PATH data
# %env CHECKPOINT_PATH ckpt
# %env SUBMISSION_PATH submission
# Out:
# env: NOTEBOOKNAME=try168
# env: LOCAL_DATA_PATH=data
# env: CHECKPOINT_PATH=ckpt
# env: SUBMISSION_PATH=submission

# %%
import tensorflow as tf
import tensorflow_addons as tfa

import datetime
import glob
import os

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

print(f"tf.__version__: {tf.__version__}")
print(f"tfa.__version__: {tfa.__version__}")
# Out:
# tf.__version__: 2.4.0
# tfa.__version__: 0.12.0

# %%
# If you wanna avoid below error, you need to run below codes when you start kernel.

# UnknownError: Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, 
# so try looking to see if a warning log message was printed above. [Op:Conv2D]

# Ref: https://blog.naver.com/vft1500/221793591386

gpus = tf.config.list_physical_devices("GPU")
if gpus:
    try:
    # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices("GPU")
        print(f"{len(gpus)} Physical GPUs, {len(logical_gpus)} Logical GPUs.")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs.

# %%
# !python -V

# %%
# !cat /proc/cpuinfo

# %%
# !nvidia-smi
# Out:
# Mon Jan 11 12:11:38 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.32.00    Driver Version: 455.32.00    CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Graphics Device     On   | 00000000:0A:00.0  On |                  N/A |
# | 41%   37C    P2    32W / 220W |    747MiB /  7979MiB |     18%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A       908      G   /usr/lib/xorg/Xorg                 35MiB |
# |    0   N/A  N/A      1398      G   /usr/lib/xorg/Xorg                 86MiB |
# |    0   N/A  N/A      1525      G   /usr/bin/gnome-shell               29MiB |
# |    0   N/A  N/A      2509      G   ...AAAAAAAA== --shared-files      277MiB |
# |    0   N/A  N/A     85786      C   ...nda3/envs/py36/bin/python      303MiB |
# +-----------------------------------------------------------------------------+

# %%
# !df -h

# %%
# !free -h
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:           31Gi        10Gi        11Gi       686Mi       9.1Gi        19Gi
# Swap:         2.0Gi       4.0Mi       2.0Gi

# %%
# Load the TensorBoard notebook extension.
# %load_ext tensorboard

# %% [markdown]
# # **Define Arguments**

# %%
class HParams(object):
    def __init__(self):
        # Basic
        self.seed = 42
        self.test_size = 0.2
        self.epoch = 50
        self.lr = 1e-3
        
        # Dataframe
        self.feature_dict = {}
        self.num_test_csv = 81
        self.day_split = 1
        self.day = 48
        self.inp = 7
        self.tar = 2
        
        # Dataset Pipeline
        self.w_inp = self.inp * self.day
        self.w_tar = self.tar * self.day
        self.w_shift = self.day
        self.w_stride = 1
        self.w_dr = True
        
        self.shuffle_buffer_sz = 100_000
        
        self.auto = tf.data.experimental.AUTOTUNE
        
        self.global_batch_size = 128
        
        # model
        self.num_features = 3
        self.num_quantile = 9
        
        self.input_shape = [self.inp, self.day, self.num_features]
        self.input_dtype = tf.float32
        self.units = 64
        self.out_steps = self.tar
        self.dropout_rate = 0.4
        
        # Remove checkpoints.
        self.max_to_keep = 3
        
        
HPARAMS = HParams()

# %% [markdown]
# # **Load Datasets**

# %% [markdown]
# ## **Define Preprocessing Funciton**

# %%
def preprocessing(
    df: pd.DataFrame, 
    is_training: bool = True
) -> pd.DataFrame:
    """Preprocess dataframes without any normalize."""
    
#     # Timestamp to signals.
#     time = 2 * np.int64(df["Hour"]) + (np.int64(df["Minute"]) // 30)
#     df.insert(loc = 0, column = "Time", value = time)
    
#     day_sin = np.sin(df["Time"] * (2 * np.pi / HPARAMS.day))
#     day_cos = np.cos(df["Time"] * (2 * np.pi / HPARAMS.day))
        
#     df.insert(loc = 0, column = "DAY_SIN", value = day_sin)
#     df.insert(loc = 1, column = "DAY_COS", value = day_cos)
    
    df = df.drop(["Day", "Hour", "Minute", "WS", "RH", "T"], axis = 1)
    
#     for column in df.columns:
#         if is_training:
#             HPARAMS.feature_dict[f"{column}_MEAN"] = np.float32(df[column].mean())
#             HPARAMS.feature_dict[f"{column}_STD"] = np.float32(df[column].std())
        
#         df[column] = (df[column] - HPARAMS.feature_dict[f"{column}_MEAN"]) \
#             / HPARAMS.feature_dict[f"{column}_STD"]
    
    return df

# %% [markdown]
# ## **Train & Validation Dataframes**

# %%
df = pd.read_csv(os.path.join(os.environ["LOCAL_DATA_PATH"], "train", "train.csv"))
df.head(n = 10)
# Out:
#    Day  Hour  Minute  DHI  DNI   WS     RH   T  TARGET
# 0    0     0       0    0    0  1.5  69.08 -12     0.0
# 1    0     0      30    0    0  1.5  69.06 -12     0.0
# 2    0     1       0    0    0  1.6  71.78 -12     0.0
# 3    0     1      30    0    0  1.6  71.75 -12     0.0
# 4    0     2       0    0    0  1.6  75.20 -12     0.0
# 5    0     2      30    0    0  1.5  69.29 -11     0.0
# 6    0     3       0    0    0  1.5  72.56 -11     0.0
# 7    0     3      30    0    0  1.4  72.55 -11     0.0
# 8    0     4       0    0    0  1.3  74.62 -11     0.0
# 9    0     4      30    0    0  1.3  74.61 -11     0.0

# %%
# Forces the length of train and test data to be a multiple of the day.
HPARAMS.split_len = int(df.shape[0] * (1. - HPARAMS.test_size))
HPARAMS.split_len = HPARAMS.split_len - (HPARAMS.split_len % HPARAMS.day)

tr_df = df[:HPARAMS.split_len]
vl_df = df[HPARAMS.split_len:]

HPARAMS.epsilon = np.float32(tr_df["TARGET"][tr_df["TARGET"] > 0].min() * 0.9)

tr_df = preprocessing(tr_df)
vl_df = preprocessing(vl_df, is_training = False)

print(f"tr_df.shape: {tr_df.shape}, columns: {','.join(tr_df.columns)}")
print(f"vl_df.shape: {vl_df.shape}, columns: {','.join(vl_df.columns)}")
# Out:
# tr_df.shape: (42048, 3), columns: DHI,DNI,TARGET
# vl_df.shape: (10512, 3), columns: DHI,DNI,TARGET

# %% [markdown]
# ## **Test Dataframe**

# %%
ts_filenames = [os.path.join(os.environ["LOCAL_DATA_PATH"], "test", f"{i}.csv") for i in range(HPARAMS.num_test_csv)]
ts_dfs = [preprocessing(pd.read_csv(ts_filename), is_training = False) for ts_filename in ts_filenames]
ts_df = pd.concat(ts_dfs)

print(f"ts_df.shape: {ts_df.shape}, columns: {','.join(ts_df.columns)}")
# Out:
# ts_df.shape: (27216, 3), columns: DHI,DNI,TARGET

# %% [markdown]
# # **Make Dataset Pipelines**
#
# The first batch is to bundle the tensors as input into units of a day. The operation below can guarantee that the number of sequences of tr_tensor and vl_tensor is a multiple of a day (i.e. 48), so `drop_remainder = True` is actually meaningless. However, it was added to specify the shape of the input data during the window division process (`.window(...)`)
#
# ```
# args["SPLIT_LEN"] = int(df.shape[0] * (1. - args["TEST_SIZE"]))
# args["SPLIT_LEN"] = args["SPLIT_LEN"] - np.mod(args["SPLIT_LEN"], args["DAY"]) # this process
#
# tr_df = df[:args["SPLIT_LEN"]]
# vl_df = df[args["SPLIT_LEN"]:]
# ```
#
# It is recommended to cache the dataset after the map transformation except if this transformation makes the data too big to fit in memory. A trade-off can be achieved if your mapped function can be split in two parts: a time consuming one and a memory consuming part. In this case, you can chain your transformations like below:
#
# ```
# dataset.map(time_consuming_mapping).cache().map(memory_consuming_mapping)
# ```
#
# If the cache is executed after partioning the window, the amount of data loaded in the memory increases by about 9 times (=`(W_INP + W_TAR) / W_STRIDE)`. Obviously, the mapping process comsumes a lot of time, but since we have to train a model like this 9 times, it would be desirable to load it into the cache mory before the window split.
#
# Also `cache` produce exactly the same elements during each iteration through the dataset. If you wish to randomize the iteration order, make sure to call `shuffle` after calling `cache`.
#
# Immediately after the window is splited, the mapping function `_split_window` is called after stacking with `GLOBAL_BATCH_SIZE`. This time, the vectorized mapping function is called once and applies to a batch of sample. While the function could takes more time to execute, the overhead appear only once, improving the overall time performance.
#
# *References*
#    * *https://www.tensorflow.org/guide/data_performance*
#    * *https://www.tensorflow.org/api_docs/python/tf/data/Dataset*

# %%
@tf.function
def _flat_fn_tr(x):
    return x.batch(HPARAMS.w_inp + HPARAMS.w_tar)


@tf.function
def _flat_fn_ts(x):
    return x.batch(HPARAMS.w_inp)


@tf.function
def _reshape_tr(features):
    return tf.reshape(features, (-1, HPARAMS.inp + HPARAMS.tar, HPARAMS.day, HPARAMS.num_features))


@tf.function
def _reshape_ts(features):
    return tf.reshape(features, (-1, HPARAMS.inp, HPARAMS.day, HPARAMS.num_features))


@tf.function
def _split_window_tr(features):
    """
        input:  (batch, 9, 48, 8)
        output: (batch, 7, 48, 8), (batch, 2, 48, 1)
    """
    inp, tar = tf.split(features, [HPARAMS.inp, HPARAMS.tar], axis = 1)
    _, tar = tf.split(tar, [-1, 1], axis = -1)
    
    return inp, tar

# %%
# Dataframe to tensor. (TARGET column located on axis = -1)
tr_tensor = tf.constant(tr_df, dtype = tf.float32)
vl_tensor = tf.constant(vl_df, dtype = tf.float32)
ts_tensor = tf.constant(ts_df, dtype = tf.float32)

# Tensor to dataset.
tr_dataset = tf.data.Dataset.from_tensor_slices(tr_tensor
                    ).window(HPARAMS.w_inp + HPARAMS.w_tar, HPARAMS.w_shift, HPARAMS.w_stride, HPARAMS.w_dr).flat_map(_flat_fn_tr
                    ).cache(
                    ).shuffle(HPARAMS.shuffle_buffer_sz, reshuffle_each_iteration = True
                    ).batch(HPARAMS.global_batch_size
                    ).map(_reshape_tr, num_parallel_calls = HPARAMS.auto
                    ).map(_split_window_tr, num_parallel_calls = HPARAMS.auto
                    ).prefetch(HPARAMS.auto)
                                                
vl_dataset = tf.data.Dataset.from_tensor_slices(vl_tensor
                    ).window(HPARAMS.w_inp + HPARAMS.w_tar, HPARAMS.w_shift, HPARAMS.w_stride, HPARAMS.w_dr).flat_map(_flat_fn_tr
                    ).cache(
#                     ).shuffle(HPARAMS.shuffle_buffer_sz, reshuffle_each_iteration = True
                    ).batch(HPARAMS.global_batch_size
                    ).map(_reshape_tr, num_parallel_calls = HPARAMS.auto
                    ).map(_split_window_tr, num_parallel_calls = HPARAMS.auto
                    ).prefetch(HPARAMS.auto)

ts_dataset = tf.data.Dataset.from_tensor_slices(ts_tensor
                    ).window(HPARAMS.w_inp, HPARAMS.w_inp, 1, HPARAMS.w_dr).flat_map(_flat_fn_ts
                    ).cache(
#                     ).shuffle(HPARAMS.shuffle_buffer_sz, reshuffle_each_iteration = True
                    ).batch(HPARAMS.num_test_csv # not HPARAMS.global_batch_size
                    ).map(_reshape_ts, num_parallel_calls = HPARAMS.auto
                    ).prefetch(HPARAMS.auto)

# Print the shapes.
print("tr_dataset:")
print(f"\tinp: {tr_dataset.element_spec[0]}")
print(f"\ttar: {tr_dataset.element_spec[1]}")

print("vl_dataset:")
print(f"\tinp: {vl_dataset.element_spec[0]}")
print(f"\ttar: {vl_dataset.element_spec[1]}")

print("ts_dataset:")
print(f"\tinp: {ts_dataset.element_spec}")
# Out:
# tr_dataset:
# 	inp: TensorSpec(shape=(None, 7, 48, 3), dtype=tf.float32, name=None)
# 	tar: TensorSpec(shape=(None, 2, 48, 1), dtype=tf.float32, name=None)
# vl_dataset:
# 	inp: TensorSpec(shape=(None, 7, 48, 3), dtype=tf.float32, name=None)
# 	tar: TensorSpec(shape=(None, 2, 48, 1), dtype=tf.float32, name=None)
# ts_dataset:
# 	inp: TensorSpec(shape=(None, 7, 48, 3), dtype=tf.float32, name=None)

# %% [markdown]
# ## **Take Samples**

# %%
# for element in tr_dataset.take(1):
#     foo, bar = element
#     print(foo.shape, bar.shape)

# %%
# for element in vl_dataset.take(1):
#     foo, (bar, qux) = element
#     print(foo.shape, bar.shape, qux.shape)

# %%
# for element in ts_dataset.take(1):
#     foo = element
#     print(foo.shape)

# %% [markdown]
# # **Define Loss Function**

# %% [markdown]
# Dacon defines the loss as shown below.
#
# $$ L_\tau = maximum(\zeta\tau, \zeta(\tau-1)) $$
#
# However, [the pinball loss of tensorflow-addons](https://www.tensorflow.org/addons/api_docs/python/tfa/losses/pinball_loss) is implemented as follows.
#
# $$ L_\tau = \begin{cases} \zeta\tau & \text{ if } \zeta \geq 0 \\ -\zeta(1-\tau)=\zeta(\tau-1) & \text{ if } \zeta < 0 \end{cases}$$
#
# The description of the symbols used in is as follows.
#
# * $\zeta$ : y_true - y_pred
# * $\tau$ : Quantile values in \[0.1, 0.2, ..., 0.9\]
# * $L_\tau$ : Pinball loss function with $\tau$
#
# The two formulas seem intuitively different, but if you actually divide the interval, you can see that they are the same. However, in experience, it seems to force an underforecast when the evaluation expression of dacon is $\tau=0.1, 0.2$. In fact, for $\tau=0.1, 0.2$, the prediction (blue lines) in the target models mostly overlaps the label (yellow lines) or lies below the graph.

# %% [markdown]
# # **Create Network**

# %% [markdown]
# ## **Autoregressive-ConvLSTM2D Model**

# %%
class ConvLSTMCells(tf.keras.Model):
    def __init__(
        self,
        hidden_dim: list,
        kernel_sz: tuple = (3, 1),
        num_layers = 3,
    ):
        super(ConvLSTMCells, self).__init__()
        
        self.hidden_dim = hidden_dim
        self.kernel_sz = kernel_sz
        self.num_layers = num_layers
        
        self.convlstm_cells = [
            tf.keras.layers.ConvLSTM2D(
                dim, self.kernel_sz, 
                padding = "same", 
#                 dropout = 0.4,
                return_sequences = False if i == self.num_layers - 1 else True, 
                return_state = True) for i, dim in enumerate(self.hidden_dim)]
        self.states = []
                
        
    def warmup(
        self,
        inputs,
    ):        
        x = inputs
        states = []
        
        for i in range(self.num_layers):
            residual = x
            x, *state = self.convlstm_cells[i](x)
            if i != self.num_layers - 1:
                x = residual + x
                
            states.append(state)
        
        self.states = states
        return x
        
        
    def call(
        self,
        inputs,
    ):         
        x = inputs
        states = []
        
        for i in range(self.num_layers):
            residual = x
            x, *state = self.convlstm_cells[i](x, initial_state = self.states[i], training = False)
            if i != self.num_layers - 1:
                x = residual + x
                
            states.append(state)
        
        self.states = states
        return x
        


class AR_ConvLSTM1D(tf.keras.Model):
    def __init__(
        self, 
        model_name: str,
        units: int = HPARAMS.units,
        out_steps: int = HPARAMS.out_steps,
        dropout_rate: float = HPARAMS.dropout_rate,
        day: int = HPARAMS.day,
    ):
        super(AR_ConvLSTM1D, self).__init__(name = model_name)
        
        self.units = units
        self.out_steps = out_steps
        self.dropout_rate = dropout_rate
        self.day = day
        
        self.kernel_sz = (9, 1)
        
        self.stem = tf.keras.layers.TimeDistributed(
            tf.keras.layers.Conv2D(self.units, self.kernel_sz, padding = "same", activation = "relu"))
        self.convlstm = ConvLSTMCells([self.units] * 3)
#         self.convlstm = tf.keras.layers.ConvLSTM2D(
#             self.units, self.kernel_sz, padding = "same", dropout = self.dropout_rate, return_state = True)
        self.expand_timestamp_dim = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis = 1))
        self.expand_channel_dim = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis = -1))
        self.remove_channel_dim = tf.keras.layers.Reshape((self.out_steps, self.day, -1))
        
        
    def warmup(
        self, 
        inputs,
    ):
        """
             inputs: (batch, 7, 48, 1, units)
            outputs: (batch, 48, 1, units)
        """
        x, *state = self.convlstm(inputs)
        return x, state
    
    
    def call(
        self, 
        inputs, 
    ):
        """
             inputs: (batch, 7, 48, 1)
            outputs: (batch, 2, 48, units)
        """
        outputs = []
        
        # Stem.
        x = self.expand_channel_dim(inputs)
        x = self.stem(x)
        
        # Warm up.
        x = self.convlstm.warmup(x)
        outputs.append(x)
        
        # Autoregressive loops.
        for _ in range(1, self.out_steps):
            x = self.expand_timestamp_dim(x)
            x = self.convlstm(x) #, initial_state = state, training = False)
            outputs.append(x)
        
        output = tf.stack(outputs, axis = 1)
        output = self.remove_channel_dim(output)
        
        return output

# %%
def Ensembled_AR_ConvLSTM1D(
    model_name: str,
    units: int = HPARAMS.units,
    out_steps: int = HPARAMS.out_steps,
    dropout_rate: float = HPARAMS.dropout_rate,
    day: int = HPARAMS.day,
) -> tf.keras.Model:
    """Create an emsembled ar-convlstm model by feature-wise."""
    
    model_input = tf.keras.layers.Input(shape = HPARAMS.input_shape, dtype = HPARAMS.input_dtype)
    
    xs = tf.keras.layers.Lambda(lambda x: tf.split(x, x.shape[-1], axis = -1), name = "feature-wised_split")(model_input)

    submodels = [
        AR_ConvLSTM1D(f"{model_name}_DNI", units, out_steps, dropout_rate),
        AR_ConvLSTM1D(f"{model_name}_DHI", units, out_steps, dropout_rate),
        AR_ConvLSTM1D(f"{model_name}_TARGET", 2 * units, out_steps, dropout_rate)]
    
    # Prediction
    xs = [submodel(x) for submodel, x in zip(submodels, xs)]
    
    # Concat and re-prediction.
    x = tf.keras.layers.Concatenate(axis = -1)(xs)    
    x = tf.keras.layers.Dense(x.shape[-1], activation = "relu")(x)
    
    model_output = tf.keras.layers.Dense(1, activation = "relu")(x)
    
    return tf.keras.Model(
        inputs = model_input,
        outputs = model_output,
        name = model_name)

# %%
tmp = Ensembled_AR_ConvLSTM1D("tmp")
tmp.summary()
# Out:
# Model: "tmp"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 7, 48, 3)]   0
# __________________________________________________________________________________________________
# feature-wised_split (Lambda)    [(None, 7, 48, 1), ( 0           input_4[0][0]
# __________________________________________________________________________________________________
# tmp_DNI (AR_ConvLSTM1D)         (None, 2, 48, 64)    296320      feature-wised_split[0][0]
# __________________________________________________________________________________________________
# tmp_DHI (AR_ConvLSTM1D)         (None, 2, 48, 64)    296320      feature-wised_split[0][1]
# __________________________________________________________________________________________________
# tmp_TARGET (AR_ConvLSTM1D)      (None, 2, 48, 128)   1182464     feature-wised_split[0][2]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 48, 256)   0           tmp_DNI[0][0]
#                                                                  tmp_DHI[0][0]
#                                                                  tmp_TARGET[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2, 48, 256)   65792       concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2, 48, 1)     257         dense[0][0]
# ==================================================================================================
# Total params: 1,841,153
# Trainable params: 1,841,153
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(tmp, show_layer_names = True, show_shapes = False)

# %%
tf.keras.utils.plot_model(tmp, show_shapes = True)

# %%
del tmp

# %% [markdown]
# # **Compile and Fit**

# %%
def get_callbacks(
    model_name: str,
) -> list:
    """Get checkpoint and tensorboard callbacks."""
    
    # Checkpoint callback.
    ckpt_path = os.path.join(
        os.environ["CHECKPOINT_PATH"], os.environ["NOTEBOOKNAME"], 
        model_name, "cp-{epoch:03d}-{val_loss:.4f}.ckpt")
    ckpt_dir = os.path.dirname(ckpt_path)
    os.makedirs(ckpt_dir, exist_ok = True)
    
    cp_callback = tf.keras.callbacks.ModelCheckpoint(
        ckpt_path, verbose = 0, monitor = "val_loss", save_weights_only = True, save_best_only = True)
    
    # TensorBoard callback.
    log_dir = os.path.join(
        "logs", "fit", os.environ["NOTEBOOKNAME"], datetime.datetime.now().strftime(f"{model_name}-%Y%m%d-%H%M%S"))
    tb_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1, update_freq = "batch")
    
    return [cp_callback, tb_callback]
    

def compile_and_fit(
    model: tf.keras.Model, 
    tau: float, 
    tr_dataset: tf.data.Dataset, 
    vl_dataset: tf.data.Dataset, 
    epochs: int,
    lr: float,
    verbose: int = 0, 
) -> dict:
    """Compile and fit the model."""
    
    model.compile(
        loss = tfa.losses.PinballLoss(tau = tau),
        optimizer = tf.keras.optimizers.Adam(lr))
    
    print(f"Model {model.name}...")

    history = model.fit(
        tr_dataset,
        validation_data = vl_dataset,
        epochs = epochs,
        verbose = verbose,
        callbacks = get_callbacks(model.name))

    return history

# %%
# %%time

for tau in np.arange(0.1, 1, 0.1):
    model = Ensembled_AR_ConvLSTM1D(model_name = f"P{tau:.1f}")
    
    _ = compile_and_fit(
        model, 
        tau, 
        tr_dataset, 
        vl_dataset, 
        HPARAMS.epoch,
        HPARAMS.lr,
        verbose = 2)
    
    del model # for save memories
# Out:
# Model P0.1...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Epoch 1/50
# 7/7 - 30s - loss: 1.6737 - val_loss: 1.5362
# Epoch 2/50
# 7/7 - 2s - loss: 1.4748 - val_loss: 1.4596
# Epoch 3/50
# 7/7 - 2s - loss: 1.4282 - val_loss: 1.4512
# Epoch 4/50
# 7/7 - 2s - loss: 1.4183 - val_loss: 1.4481
# Epoch 5/50
# 7/7 - 2s - loss: 1.4110 - val_loss: 1.4454
# Epoch 6/50
# 7/7 - 2s - loss: 1.4034 - val_loss: 1.4388
# Epoch 7/50
# 7/7 - 2s - loss: 1.4056 - val_loss: 1.4364
# Epoch 8/50
# 7/7 - 2s - loss: 1.4008 - val_loss: 1.4436
# Epoch 9/50
# 7/7 - 2s - loss: 1.4025 - val_loss: 1.4770
# Epoch 10/50
# 7/7 - 2s - loss: 1.4028 - val_loss: 1.4511
# Epoch 11/50
# 7/7 - 2s - loss: 1.3900 - val_loss: 1.4859
# Epoch 12/50
# 7/7 - 2s - loss: 1.3891 - val_loss: 1.4844
# Epoch 13/50
# 7/7 - 2s - loss: 1.3847 - val_loss: 1.4778
# Epoch 14/50
# 7/7 - 2s - loss: 1.3804 - val_loss: 1.4629
# Epoch 15/50
# 7/7 - 2s - loss: 1.3719 - val_loss: 1.4481
# Epoch 16/50
# 7/7 - 2s - loss: 1.3712 - val_loss: 1.4824
# Epoch 17/50
# 7/7 - 2s - loss: 1.3630 - val_loss: 1.4536
# Epoch 18/50
# 7/7 - 2s - loss: 1.3602 - val_loss: 1.5029
# Epoch 19/50
# 7/7 - 2s - loss: 1.3566 - val_loss: 1.5316
# Epoch 20/50
# 7/7 - 2s - loss: 1.3603 - val_loss: 1.4925
# Epoch 21/50
# 7/7 - 2s - loss: 1.3469 - val_loss: 1.5623
# Epoch 22/50
# 7/7 - 2s - loss: 1.3430 - val_loss: 1.4933
# Epoch 23/50
# 7/7 - 2s - loss: 1.3351 - val_loss: 1.4744
# Epoch 24/50
# 7/7 - 2s - loss: 1.3190 - val_loss: 1.4980
# Epoch 25/50
# 7/7 - 2s - loss: 1.3230 - val_loss: 1.5622
# Epoch 26/50
# 7/7 - 2s - loss: 1.3335 - val_loss: 1.5444
# Epoch 27/50
# 7/7 - 2s - loss: 1.3078 - val_loss: 1.5151
# Epoch 28/50
# 7/7 - 2s - loss: 1.2961 - val_loss: 1.5609
# Epoch 29/50
# 7/7 - 2s - loss: 1.2965 - val_loss: 1.4750
# Epoch 30/50
# 7/7 - 2s - loss: 1.2870 - val_loss: 1.5663
# Epoch 31/50
# 7/7 - 2s - loss: 1.2769 - val_loss: 1.5310
# Epoch 32/50
# 7/7 - 2s - loss: 1.2691 - val_loss: 1.5704
# Epoch 33/50
# 7/7 - 2s - loss: 1.2594 - val_loss: 1.5675
# Epoch 34/50
# 7/7 - 2s - loss: 1.2614 - val_loss: 1.5987
# Epoch 35/50
# 7/7 - 2s - loss: 1.2329 - val_loss: 1.5793
# Epoch 36/50
# 7/7 - 2s - loss: 1.2552 - val_loss: 1.5570
# Epoch 37/50
# 7/7 - 2s - loss: 1.2276 - val_loss: 1.7171
# Epoch 38/50
# 7/7 - 2s - loss: 1.2054 - val_loss: 1.6217
# Epoch 39/50
# 7/7 - 2s - loss: 1.1867 - val_loss: 1.6980
# Epoch 40/50
# 7/7 - 2s - loss: 1.1660 - val_loss: 1.7402
# Epoch 41/50
# 7/7 - 2s - loss: 1.1475 - val_loss: 1.7068
# Epoch 42/50
# 7/7 - 3s - loss: 1.1606 - val_loss: 1.7640
# Epoch 43/50
# 7/7 - 2s - loss: 1.1197 - val_loss: 1.8354
# Epoch 44/50
# 7/7 - 2s - loss: 1.0819 - val_loss: 1.7757
# Epoch 45/50
# 7/7 - 2s - loss: 1.1039 - val_loss: 1.8042
# Epoch 46/50
# 7/7 - 2s - loss: 1.1265 - val_loss: 1.6491
# Epoch 47/50
# 7/7 - 2s - loss: 1.0993 - val_loss: 1.9525
# Epoch 48/50
# 7/7 - 2s - loss: 1.0512 - val_loss: 1.7652
# Epoch 49/50
# 7/7 - 2s - loss: 1.0202 - val_loss: 1.8174
# Epoch 50/50
# 7/7 - 2s - loss: 1.0327 - val_loss: 1.8099
# Model P0.2...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Epoch 1/50
# 7/7 - 30s - loss: 3.2186 - val_loss: 2.7967
# Epoch 2/50
# 7/7 - 2s - loss: 2.5931 - val_loss: 2.4885
# Epoch 3/50
# 7/7 - 2s - loss: 2.3767 - val_loss: 2.3944
# Epoch 4/50
# 7/7 - 2s - loss: 2.3292 - val_loss: 2.4007
# Epoch 5/50
# 7/7 - 2s - loss: 2.3239 - val_loss: 2.4142
# Epoch 6/50
# 7/7 - 2s - loss: 2.2993 - val_loss: 2.3853
# Epoch 7/50
# 7/7 - 2s - loss: 2.2766 - val_loss: 2.3425
# Epoch 8/50
# 7/7 - 2s - loss: 2.2632 - val_loss: 2.3677
# Epoch 9/50
# 7/7 - 3s - loss: 2.2558 - val_loss: 2.3635
# Epoch 10/50
# 7/7 - 2s - loss: 2.2720 - val_loss: 2.3525
# Epoch 11/50
# 7/7 - 2s - loss: 2.2508 - val_loss: 2.3616
# Epoch 12/50
# 7/7 - 2s - loss: 2.2450 - val_loss: 2.3594
# Epoch 13/50
# 7/7 - 2s - loss: 2.2275 - val_loss: 2.3543
# Epoch 14/50
# 7/7 - 2s - loss: 2.2246 - val_loss: 2.3670
# Epoch 15/50
# 7/7 - 2s - loss: 2.2307 - val_loss: 2.3772
# Epoch 16/50
# 7/7 - 2s - loss: 2.2292 - val_loss: 2.3566
# Epoch 17/50
# 7/7 - 2s - loss: 2.2134 - val_loss: 2.3543
# Epoch 18/50
# 7/7 - 2s - loss: 2.2021 - val_loss: 2.3562
# Epoch 19/50
# 7/7 - 2s - loss: 2.1885 - val_loss: 2.3835
# Epoch 20/50
# 7/7 - 2s - loss: 2.1915 - val_loss: 2.4132
# Epoch 21/50
# 7/7 - 2s - loss: 2.1839 - val_loss: 2.3610
# Epoch 22/50
# 7/7 - 2s - loss: 2.1817 - val_loss: 2.3599
# Epoch 23/50
# 7/7 - 2s - loss: 2.1999 - val_loss: 2.3636
# Epoch 24/50
# 7/7 - 2s - loss: 2.1799 - val_loss: 2.4051
# Epoch 25/50
# 7/7 - 2s - loss: 2.1598 - val_loss: 2.3703
# Epoch 26/50
# 7/7 - 2s - loss: 2.1451 - val_loss: 2.3651
# Epoch 27/50
# 7/7 - 2s - loss: 2.1420 - val_loss: 2.3984
# Epoch 28/50
# 7/7 - 2s - loss: 2.1182 - val_loss: 2.4264
# Epoch 29/50
# 7/7 - 2s - loss: 2.1035 - val_loss: 2.3752
# Epoch 30/50
# 7/7 - 2s - loss: 2.1035 - val_loss: 2.4294
# Epoch 31/50
# 7/7 - 2s - loss: 2.0689 - val_loss: 2.4958
# Epoch 32/50
# 7/7 - 2s - loss: 2.0592 - val_loss: 2.4396
# Epoch 33/50
# 7/7 - 2s - loss: 2.0291 - val_loss: 2.4988
# Epoch 34/50
# 7/7 - 2s - loss: 2.0437 - val_loss: 2.4607
# Epoch 35/50
# 7/7 - 2s - loss: 2.0464 - val_loss: 2.4818
# Epoch 36/50
# 7/7 - 2s - loss: 2.0257 - val_loss: 2.6558
# Epoch 37/50
# 7/7 - 2s - loss: 2.0430 - val_loss: 2.6394
# Epoch 38/50
# 7/7 - 2s - loss: 2.0389 - val_loss: 2.5204
# Epoch 39/50
# 7/7 - 3s - loss: 1.9808 - val_loss: 2.4552
# Epoch 40/50
# 7/7 - 2s - loss: 1.9382 - val_loss: 2.5051
# Epoch 41/50
# 7/7 - 2s - loss: 1.9623 - val_loss: 2.6304
# Epoch 42/50
# 7/7 - 2s - loss: 1.9384 - val_loss: 2.6907
# Epoch 43/50
# 7/7 - 2s - loss: 1.9273 - val_loss: 2.5788
# Epoch 44/50
# 7/7 - 2s - loss: 1.8348 - val_loss: 2.5445
# Epoch 45/50
# 7/7 - 2s - loss: 1.8018 - val_loss: 2.6324
# Epoch 46/50
# 7/7 - 2s - loss: 1.8005 - val_loss: 2.5164
# Epoch 47/50
# 7/7 - 2s - loss: 1.7859 - val_loss: 2.6801
# Epoch 48/50
# 7/7 - 2s - loss: 1.7259 - val_loss: 2.5708
# Epoch 49/50
# 7/7 - 2s - loss: 1.6996 - val_loss: 2.6332
# Epoch 50/50
# 7/7 - 2s - loss: 1.6631 - val_loss: 2.7423
# Model P0.3...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Epoch 1/50
# 7/7 - 33s - loss: 4.8389 - val_loss: 4.0845
# Epoch 2/50
# 7/7 - 2s - loss: 3.7078 - val_loss: 3.2672
# Epoch 3/50
# 7/7 - 2s - loss: 3.0591 - val_loss: 2.9420
# Epoch 4/50
# 7/7 - 2s - loss: 2.8386 - val_loss: 2.8648
# Epoch 5/50
# 7/7 - 2s - loss: 2.8019 - val_loss: 2.8803
# Epoch 6/50
# 7/7 - 2s - loss: 2.7813 - val_loss: 2.8156
# Epoch 7/50
# 7/7 - 2s - loss: 2.7370 - val_loss: 2.7878
# Epoch 8/50
# 7/7 - 2s - loss: 2.7133 - val_loss: 2.7492
# Epoch 9/50
# 7/7 - 2s - loss: 2.6890 - val_loss: 2.8195
# Epoch 10/50
# 7/7 - 2s - loss: 2.7334 - val_loss: 2.7800
# Epoch 11/50
# 7/7 - 2s - loss: 2.6925 - val_loss: 2.7598
# Epoch 12/50
# 7/7 - 2s - loss: 2.7113 - val_loss: 2.8276
# Epoch 13/50
# 7/7 - 2s - loss: 2.6948 - val_loss: 2.7656
# Epoch 14/50
# 7/7 - 2s - loss: 2.6685 - val_loss: 2.7526
# Epoch 15/50
# 7/7 - 2s - loss: 2.6728 - val_loss: 2.7435
# Epoch 16/50
# 7/7 - 2s - loss: 2.6594 - val_loss: 2.7416
# Epoch 17/50
# 7/7 - 2s - loss: 2.6519 - val_loss: 2.7658
# Epoch 18/50
# 7/7 - 2s - loss: 2.6626 - val_loss: 2.7584
# Epoch 19/50
# 7/7 - 2s - loss: 2.6504 - val_loss: 2.7630
# Epoch 20/50
# 7/7 - 2s - loss: 2.6537 - val_loss: 2.8078
# Epoch 21/50
# 7/7 - 2s - loss: 2.6535 - val_loss: 2.7486
# Epoch 22/50
# 7/7 - 2s - loss: 2.6212 - val_loss: 2.7568
# Epoch 23/50
# 7/7 - 2s - loss: 2.6138 - val_loss: 2.7651
# Epoch 24/50
# 7/7 - 2s - loss: 2.6120 - val_loss: 2.7734
# Epoch 25/50
# 7/7 - 2s - loss: 2.6649 - val_loss: 2.7821
# Epoch 26/50
# 7/7 - 2s - loss: 2.6166 - val_loss: 2.8214
# Epoch 27/50
# 7/7 - 2s - loss: 2.6281 - val_loss: 2.7624
# Epoch 28/50
# 7/7 - 2s - loss: 2.6051 - val_loss: 2.7746
# Epoch 29/50
# 7/7 - 2s - loss: 2.5832 - val_loss: 2.7565
# Epoch 30/50
# 7/7 - 2s - loss: 2.5756 - val_loss: 2.7661
# Epoch 31/50
# 7/7 - 2s - loss: 2.5727 - val_loss: 2.7631
# Epoch 32/50
# 7/7 - 2s - loss: 2.5679 - val_loss: 2.8279
# Epoch 33/50
# 7/7 - 2s - loss: 2.6046 - val_loss: 2.8045
# Epoch 34/50
# 7/7 - 2s - loss: 2.5909 - val_loss: 2.7754
# Epoch 35/50
# 7/7 - 2s - loss: 2.5716 - val_loss: 2.8234
# Epoch 36/50
# 7/7 - 2s - loss: 2.6290 - val_loss: 2.8410
# Epoch 37/50
# 7/7 - 2s - loss: 2.6093 - val_loss: 2.7929
# Epoch 38/50
# 7/7 - 2s - loss: 2.5435 - val_loss: 2.7912
# Epoch 39/50
# 7/7 - 2s - loss: 2.5295 - val_loss: 2.8022
# Epoch 40/50
# 7/7 - 2s - loss: 2.5155 - val_loss: 2.8172
# Epoch 41/50
# 7/7 - 2s - loss: 2.4973 - val_loss: 2.8018
# Epoch 42/50
# 7/7 - 2s - loss: 2.4674 - val_loss: 2.8412
# Epoch 43/50
# 7/7 - 2s - loss: 2.4530 - val_loss: 2.8129
# Epoch 44/50
# 7/7 - 2s - loss: 2.4401 - val_loss: 2.8372
# Epoch 45/50
# 7/7 - 2s - loss: 2.4488 - val_loss: 2.9088
# Epoch 46/50
# 7/7 - 2s - loss: 2.4233 - val_loss: 3.0528
# Epoch 47/50
# 7/7 - 2s - loss: 2.4162 - val_loss: 2.8405
# Epoch 48/50
# 7/7 - 2s - loss: 2.3836 - val_loss: 2.8469
# Epoch 49/50
# 7/7 - 2s - loss: 2.3496 - val_loss: 2.8955
# Epoch 50/50
# 7/7 - 2s - loss: 2.3273 - val_loss: 2.9076
# Model P0.4...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Epoch 1/50
# 7/7 - 32s - loss: 6.2693 - val_loss: 5.1034
# Epoch 2/50
# 7/7 - 2s - loss: 4.4699 - val_loss: 3.7203
# Epoch 3/50
# 7/7 - 2s - loss: 3.3701 - val_loss: 3.1427
# Epoch 4/50
# 7/7 - 2s - loss: 3.0175 - val_loss: 2.9245
# Epoch 5/50
# 7/7 - 2s - loss: 2.8951 - val_loss: 2.9427
# Epoch 6/50
# 7/7 - 2s - loss: 2.8611 - val_loss: 2.8625
# Epoch 7/50
# 7/7 - 2s - loss: 2.8358 - val_loss: 2.8740
# Epoch 8/50
# 7/7 - 2s - loss: 2.8090 - val_loss: 2.8514
# Epoch 9/50
# 7/7 - 2s - loss: 2.8016 - val_loss: 2.8598
# Epoch 10/50
# 7/7 - 2s - loss: 2.7916 - val_loss: 2.9832
# Epoch 11/50
# 7/7 - 2s - loss: 2.8214 - val_loss: 2.8446
# Epoch 12/50
# 7/7 - 2s - loss: 2.7935 - val_loss: 2.8534
# Epoch 13/50
# 7/7 - 2s - loss: 2.7811 - val_loss: 2.8468
# Epoch 14/50
# 7/7 - 2s - loss: 2.7742 - val_loss: 2.8345
# Epoch 15/50
# 7/7 - 2s - loss: 2.7556 - val_loss: 2.8805
# Epoch 16/50
# 7/7 - 2s - loss: 2.7602 - val_loss: 2.9925
# Epoch 17/50
# 7/7 - 2s - loss: 2.7795 - val_loss: 2.8633
# Epoch 18/50
# 7/7 - 2s - loss: 2.7670 - val_loss: 2.8585
# Epoch 19/50
# 7/7 - 2s - loss: 2.7470 - val_loss: 2.8655
# Epoch 20/50
# 7/7 - 2s - loss: 2.7241 - val_loss: 2.9043
# Epoch 21/50
# 7/7 - 2s - loss: 2.7407 - val_loss: 2.8512
# Epoch 22/50
# 7/7 - 2s - loss: 2.7239 - val_loss: 2.9214
# Epoch 23/50
# 7/7 - 2s - loss: 2.7601 - val_loss: 2.8464
# Epoch 24/50
# 7/7 - 2s - loss: 2.7735 - val_loss: 2.9471
# Epoch 25/50
# 7/7 - 2s - loss: 2.8003 - val_loss: 2.9290
# Epoch 26/50
# 7/7 - 2s - loss: 2.7780 - val_loss: 2.9134
# Epoch 27/50
# 7/7 - 2s - loss: 2.7382 - val_loss: 2.8721
# Epoch 28/50
# 7/7 - 2s - loss: 2.7129 - val_loss: 2.8886
# Epoch 29/50
# 7/7 - 2s - loss: 2.7188 - val_loss: 2.9083
# Epoch 30/50
# 7/7 - 2s - loss: 2.6794 - val_loss: 2.8980
# Epoch 31/50
# 7/7 - 2s - loss: 2.6939 - val_loss: 2.8656
# Epoch 32/50
# 7/7 - 2s - loss: 2.6492 - val_loss: 2.8703
# Epoch 33/50
# 7/7 - 2s - loss: 2.6304 - val_loss: 2.9005
# Epoch 34/50
# 7/7 - 2s - loss: 2.6321 - val_loss: 2.9139
# Epoch 35/50
# 7/7 - 2s - loss: 2.6779 - val_loss: 2.8703
# Epoch 36/50
# 7/7 - 2s - loss: 2.6504 - val_loss: 2.9332
# Epoch 37/50
# 7/7 - 3s - loss: 2.6583 - val_loss: 2.9514
# Epoch 38/50
# 7/7 - 2s - loss: 2.6359 - val_loss: 3.0355
# Epoch 39/50
# 7/7 - 2s - loss: 2.6372 - val_loss: 2.9035
# Epoch 40/50
# 7/7 - 2s - loss: 2.6233 - val_loss: 2.9846
# Epoch 41/50
# 7/7 - 2s - loss: 2.6089 - val_loss: 2.9058
# Epoch 42/50
# 7/7 - 2s - loss: 2.5978 - val_loss: 2.9754
# Epoch 43/50
# 7/7 - 2s - loss: 2.5577 - val_loss: 2.9019
# Epoch 44/50
# 7/7 - 2s - loss: 2.5490 - val_loss: 2.9620
# Epoch 45/50
# 7/7 - 2s - loss: 2.4963 - val_loss: 2.9641
# Epoch 46/50
# 7/7 - 2s - loss: 2.4834 - val_loss: 2.9826
# Epoch 47/50
# 7/7 - 2s - loss: 2.4825 - val_loss: 2.9856
# Epoch 48/50
# 7/7 - 2s - loss: 2.4323 - val_loss: 2.9598
# Epoch 49/50
# 7/7 - 2s - loss: 2.4016 - val_loss: 2.9980
# Epoch 50/50
# 7/7 - 2s - loss: 2.4066 - val_loss: 3.2198
# Model P0.5...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Epoch 1/50
# 7/7 - 33s - loss: 8.4370 - val_loss: 7.2604
# Epoch 2/50
# 7/7 - 2s - loss: 6.5151 - val_loss: 5.3967
# Epoch 3/50
# 7/7 - 2s - loss: 4.7276 - val_loss: 3.9401
# Epoch 4/50
# 7/7 - 2s - loss: 3.5525 - val_loss: 3.3391
# Epoch 5/50
# 7/7 - 2s - loss: 3.0093 - val_loss: 2.9322
# Epoch 6/50
# 7/7 - 2s - loss: 2.8793 - val_loss: 2.9573
# Epoch 7/50
# 7/7 - 3s - loss: 2.8153 - val_loss: 2.7698
# Epoch 8/50
# 7/7 - 2s - loss: 2.7326 - val_loss: 2.7445
# Epoch 9/50
# 7/7 - 2s - loss: 2.7050 - val_loss: 2.7285
# Epoch 10/50
# 7/7 - 2s - loss: 2.7068 - val_loss: 2.7238
# Epoch 11/50
# 7/7 - 2s - loss: 2.6706 - val_loss: 2.7426
# Epoch 12/50
# 7/7 - 2s - loss: 2.7245 - val_loss: 2.9525
# Epoch 13/50
# 7/7 - 2s - loss: 2.6954 - val_loss: 2.7061
# Epoch 14/50
# 7/7 - 2s - loss: 2.6704 - val_loss: 2.7432
# Epoch 15/50
# 7/7 - 2s - loss: 2.6469 - val_loss: 2.7037
# Epoch 16/50
# 7/7 - 2s - loss: 2.6462 - val_loss: 2.7435
# Epoch 17/50
# 7/7 - 2s - loss: 2.6245 - val_loss: 2.7049
# Epoch 18/50
# 7/7 - 2s - loss: 2.6221 - val_loss: 2.7317
# Epoch 19/50
# 7/7 - 2s - loss: 2.6353 - val_loss: 2.8141
# Epoch 20/50
# 7/7 - 2s - loss: 2.6454 - val_loss: 2.7040
# Epoch 21/50
# 7/7 - 2s - loss: 2.6263 - val_loss: 2.7282
# Epoch 22/50
# 7/7 - 2s - loss: 2.6181 - val_loss: 2.7682
# Epoch 23/50
# 7/7 - 2s - loss: 2.6303 - val_loss: 2.7823
# Epoch 24/50
# 7/7 - 2s - loss: 2.6653 - val_loss: 2.7167
# Epoch 25/50
# 7/7 - 2s - loss: 2.6097 - val_loss: 2.7544
# Epoch 26/50
# 7/7 - 2s - loss: 2.5995 - val_loss: 2.7120
# Epoch 27/50
# 7/7 - 2s - loss: 2.6016 - val_loss: 2.7213
# Epoch 28/50
# 7/7 - 2s - loss: 2.5818 - val_loss: 2.7390
# Epoch 29/50
# 7/7 - 2s - loss: 2.5688 - val_loss: 2.7148
# Epoch 30/50
# 7/7 - 2s - loss: 2.5565 - val_loss: 2.7168
# Epoch 31/50
# 7/7 - 2s - loss: 2.5666 - val_loss: 2.7040
# Epoch 32/50
# 7/7 - 2s - loss: 2.5702 - val_loss: 2.7293
# Epoch 33/50
# 7/7 - 2s - loss: 2.5459 - val_loss: 2.7077
# Epoch 34/50
# 7/7 - 2s - loss: 2.5511 - val_loss: 2.7634
# Epoch 35/50
# 7/7 - 2s - loss: 2.5527 - val_loss: 2.7176
# Epoch 36/50
# 7/7 - 2s - loss: 2.5667 - val_loss: 2.9042
# Epoch 37/50
# 7/7 - 2s - loss: 2.5739 - val_loss: 2.7194
# Epoch 38/50
# 7/7 - 2s - loss: 2.5551 - val_loss: 2.7340
# Epoch 39/50
# 7/7 - 2s - loss: 2.5326 - val_loss: 2.7350
# Epoch 40/50
# 7/7 - 2s - loss: 2.5320 - val_loss: 2.7925
# Epoch 41/50
# 7/7 - 2s - loss: 2.5393 - val_loss: 2.7389
# Epoch 42/50
# 7/7 - 2s - loss: 2.5051 - val_loss: 2.7320
# Epoch 43/50
# 7/7 - 3s - loss: 2.5129 - val_loss: 2.7687
# Epoch 44/50
# 7/7 - 2s - loss: 2.5154 - val_loss: 2.8783
# Epoch 45/50
# 7/7 - 2s - loss: 2.5571 - val_loss: 2.7307
# Epoch 46/50
# 7/7 - 2s - loss: 2.4900 - val_loss: 2.7333
# Epoch 47/50
# 7/7 - 2s - loss: 2.4596 - val_loss: 2.7350
# Epoch 48/50
# 7/7 - 2s - loss: 2.4512 - val_loss: 2.7747
# Epoch 49/50
# 7/7 - 2s - loss: 2.4493 - val_loss: 2.7505
# Epoch 50/50
# 7/7 - 2s - loss: 2.4271 - val_loss: 2.7987
# Model P0.6...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Epoch 1/50
# 7/7 - 32s - loss: 9.3463 - val_loss: 7.3509
# Epoch 2/50
# 7/7 - 2s - loss: 6.2620 - val_loss: 4.6915
# Epoch 3/50
# 7/7 - 2s - loss: 3.9194 - val_loss: 3.1587
# Epoch 4/50
# 7/7 - 2s - loss: 2.8528 - val_loss: 2.6354
# Epoch 5/50
# 7/7 - 2s - loss: 2.5052 - val_loss: 2.5030
# Epoch 6/50
# 7/7 - 2s - loss: 2.4141 - val_loss: 2.4072
# Epoch 7/50
# 7/7 - 2s - loss: 2.3916 - val_loss: 2.4315
# Epoch 8/50
# 7/7 - 2s - loss: 2.3747 - val_loss: 2.3930
# Epoch 9/50
# 7/7 - 2s - loss: 2.3665 - val_loss: 2.3911
# Epoch 10/50
# 7/7 - 2s - loss: 2.3684 - val_loss: 2.4309
# Epoch 11/50
# 7/7 - 2s - loss: 2.3871 - val_loss: 2.4059
# Epoch 12/50
# 7/7 - 2s - loss: 2.3331 - val_loss: 2.4367
# Epoch 13/50
# 7/7 - 2s - loss: 2.3257 - val_loss: 2.4232
# Epoch 14/50
# 7/7 - 2s - loss: 2.3115 - val_loss: 2.4048
# Epoch 15/50
# 7/7 - 2s - loss: 2.3069 - val_loss: 2.4016
# Epoch 16/50
# 7/7 - 2s - loss: 2.3045 - val_loss: 2.6194
# Epoch 17/50
# 7/7 - 2s - loss: 2.3407 - val_loss: 2.4090
# Epoch 18/50
# 7/7 - 2s - loss: 2.3460 - val_loss: 2.4932
# Epoch 19/50
# 7/7 - 2s - loss: 2.2932 - val_loss: 2.3904
# Epoch 20/50
# 7/7 - 2s - loss: 2.2926 - val_loss: 2.4220
# Epoch 21/50
# 7/7 - 2s - loss: 2.2967 - val_loss: 2.3915
# Epoch 22/50
# 7/7 - 2s - loss: 2.2800 - val_loss: 2.4098
# Epoch 23/50
# 7/7 - 2s - loss: 2.2783 - val_loss: 2.4724
# Epoch 24/50
# 7/7 - 2s - loss: 2.2862 - val_loss: 2.3902
# Epoch 25/50
# 7/7 - 2s - loss: 2.2628 - val_loss: 2.4185
# Epoch 26/50
# 7/7 - 2s - loss: 2.2659 - val_loss: 2.5395
# Epoch 27/50
# 7/7 - 2s - loss: 2.2991 - val_loss: 2.4177
# Epoch 28/50
# 7/7 - 2s - loss: 2.2919 - val_loss: 2.5379
# Epoch 29/50
# 7/7 - 2s - loss: 2.2513 - val_loss: 2.4101
# Epoch 30/50
# 7/7 - 2s - loss: 2.2526 - val_loss: 2.4453
# Epoch 31/50
# 7/7 - 2s - loss: 2.2566 - val_loss: 2.4384
# Epoch 32/50
# 7/7 - 2s - loss: 2.2466 - val_loss: 2.4188
# Epoch 33/50
# 7/7 - 2s - loss: 2.2325 - val_loss: 2.4212
# Epoch 34/50
# 7/7 - 2s - loss: 2.2353 - val_loss: 2.4447
# Epoch 35/50
# 7/7 - 2s - loss: 2.2698 - val_loss: 2.4226
# Epoch 36/50
# 7/7 - 2s - loss: 2.2301 - val_loss: 2.4343
# Epoch 37/50
# 7/7 - 2s - loss: 2.2132 - val_loss: 2.5383
# Epoch 38/50
# 7/7 - 2s - loss: 2.2122 - val_loss: 2.4127
# Epoch 39/50
# 7/7 - 2s - loss: 2.1850 - val_loss: 2.4318
# Epoch 40/50
# 7/7 - 2s - loss: 2.1826 - val_loss: 2.4225
# Epoch 41/50
# 7/7 - 2s - loss: 2.2004 - val_loss: 2.4107
# Epoch 42/50
# 7/7 - 2s - loss: 2.2060 - val_loss: 2.4701
# Epoch 43/50
# 7/7 - 2s - loss: 2.1655 - val_loss: 2.4264
# Epoch 44/50
# 7/7 - 2s - loss: 2.1580 - val_loss: 2.4296
# Epoch 45/50
# 7/7 - 2s - loss: 2.1568 - val_loss: 2.4233
# Epoch 46/50
# 7/7 - 2s - loss: 2.1463 - val_loss: 2.4401
# Epoch 47/50
# 7/7 - 2s - loss: 2.1297 - val_loss: 2.4430
# Epoch 48/50
# 7/7 - 2s - loss: 2.2014 - val_loss: 2.4478
# Epoch 49/50
# 7/7 - 3s - loss: 2.1686 - val_loss: 2.4508
# Epoch 50/50
# 7/7 - 2s - loss: 2.1475 - val_loss: 2.5634
# Model P0.7...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Epoch 1/50
# 7/7 - 34s - loss: 10.7236 - val_loss: 8.0912
# Epoch 2/50
# 7/7 - 3s - loss: 6.4780 - val_loss: 4.4308
# Epoch 3/50
# 7/7 - 2s - loss: 3.6061 - val_loss: 2.8324
# Epoch 4/50
# 7/7 - 2s - loss: 2.4111 - val_loss: 2.2352
# Epoch 5/50
# 7/7 - 2s - loss: 2.1402 - val_loss: 2.0730
# Epoch 6/50
# 7/7 - 2s - loss: 2.0409 - val_loss: 2.0191
# Epoch 7/50
# 7/7 - 2s - loss: 1.9804 - val_loss: 2.1428
# Epoch 8/50
# 7/7 - 2s - loss: 1.9669 - val_loss: 1.9659
# Epoch 9/50
# 7/7 - 2s - loss: 1.9407 - val_loss: 2.0701
# Epoch 10/50
# 7/7 - 2s - loss: 1.9885 - val_loss: 2.0896
# Epoch 11/50
# 7/7 - 2s - loss: 1.9336 - val_loss: 1.9864
# Epoch 12/50
# 7/7 - 2s - loss: 1.8999 - val_loss: 1.9460
# Epoch 13/50
# 7/7 - 2s - loss: 1.9331 - val_loss: 1.9427
# Epoch 14/50
# 7/7 - 2s - loss: 1.9125 - val_loss: 2.0023
# Epoch 15/50
# 7/7 - 2s - loss: 1.9153 - val_loss: 2.0194
# Epoch 16/50
# 7/7 - 2s - loss: 1.8839 - val_loss: 1.9744
# Epoch 17/50
# 7/7 - 2s - loss: 1.8802 - val_loss: 1.9927
# Epoch 18/50
# 7/7 - 2s - loss: 1.8682 - val_loss: 1.9322
# Epoch 19/50
# 7/7 - 2s - loss: 1.8594 - val_loss: 2.0365
# Epoch 20/50
# 7/7 - 2s - loss: 1.8780 - val_loss: 1.9389
# Epoch 21/50
# 7/7 - 2s - loss: 1.8515 - val_loss: 1.9760
# Epoch 22/50
# 7/7 - 2s - loss: 1.8496 - val_loss: 1.9439
# Epoch 23/50
# 7/7 - 2s - loss: 1.8547 - val_loss: 1.9481
# Epoch 24/50
# 7/7 - 2s - loss: 1.8744 - val_loss: 1.9498
# Epoch 25/50
# 7/7 - 2s - loss: 1.8674 - val_loss: 1.9474
# Epoch 26/50
# 7/7 - 2s - loss: 1.8761 - val_loss: 2.0652
# Epoch 27/50
# 7/7 - 2s - loss: 1.8721 - val_loss: 1.9607
# Epoch 28/50
# 7/7 - 2s - loss: 1.8528 - val_loss: 2.0775
# Epoch 29/50
# 7/7 - 2s - loss: 1.8478 - val_loss: 1.9488
# Epoch 30/50
# 7/7 - 2s - loss: 1.8442 - val_loss: 1.9700
# Epoch 31/50
# 7/7 - 2s - loss: 1.8198 - val_loss: 1.9530
# Epoch 32/50
# 7/7 - 2s - loss: 1.8572 - val_loss: 1.9690
# Epoch 33/50
# 7/7 - 2s - loss: 1.8547 - val_loss: 2.0065
# Epoch 34/50
# 7/7 - 2s - loss: 1.8222 - val_loss: 1.9475
# Epoch 35/50
# 7/7 - 2s - loss: 1.8149 - val_loss: 1.9588
# Epoch 36/50
# 7/7 - 2s - loss: 1.8063 - val_loss: 2.0535
# Epoch 37/50
# 7/7 - 2s - loss: 1.8139 - val_loss: 1.9314
# Epoch 38/50
# 7/7 - 2s - loss: 1.8022 - val_loss: 1.9525
# Epoch 39/50
# 7/7 - 2s - loss: 1.8055 - val_loss: 1.9473
# Epoch 40/50
# 7/7 - 2s - loss: 1.8077 - val_loss: 1.9909
# Epoch 41/50
# 7/7 - 2s - loss: 1.8550 - val_loss: 2.1565
# Epoch 42/50
# 7/7 - 2s - loss: 1.8729 - val_loss: 1.9793
# Epoch 43/50
# 7/7 - 2s - loss: 1.8443 - val_loss: 2.1357
# Epoch 44/50
# 7/7 - 2s - loss: 1.8545 - val_loss: 1.9764
# Epoch 45/50
# 7/7 - 2s - loss: 1.8139 - val_loss: 1.9941
# Epoch 46/50
# 7/7 - 2s - loss: 1.7778 - val_loss: 1.9827
# Epoch 47/50
# 7/7 - 2s - loss: 1.7667 - val_loss: 1.9475
# Epoch 48/50
# 7/7 - 2s - loss: 1.7740 - val_loss: 1.9590
# Epoch 49/50
# 7/7 - 2s - loss: 1.7641 - val_loss: 1.9542
# Epoch 50/50
# 7/7 - 3s - loss: 1.7548 - val_loss: 1.9652
# Model P0.8...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Epoch 1/50
# 7/7 - 34s - loss: 11.9290 - val_loss: 8.8745
# Epoch 2/50
# 7/7 - 2s - loss: 7.1816 - val_loss: 4.8241
# Epoch 3/50
# 7/7 - 2s - loss: 3.7334 - val_loss: 2.6650
# Epoch 4/50
# 7/7 - 2s - loss: 2.1378 - val_loss: 1.9727
# Epoch 5/50
# 7/7 - 2s - loss: 1.6859 - val_loss: 1.5496
# Epoch 6/50
# 7/7 - 2s - loss: 1.5211 - val_loss: 1.5384
# Epoch 7/50
# 7/7 - 2s - loss: 1.4819 - val_loss: 1.4269
# Epoch 8/50
# 7/7 - 2s - loss: 1.4341 - val_loss: 1.5518
# Epoch 9/50
# 7/7 - 2s - loss: 1.4500 - val_loss: 1.5093
# Epoch 10/50
# 7/7 - 2s - loss: 1.4124 - val_loss: 1.4319
# Epoch 11/50
# 7/7 - 2s - loss: 1.3895 - val_loss: 1.4962
# Epoch 12/50
# 7/7 - 2s - loss: 1.4009 - val_loss: 1.3997
# Epoch 13/50
# 7/7 - 2s - loss: 1.3594 - val_loss: 1.4349
# Epoch 14/50
# 7/7 - 2s - loss: 1.3586 - val_loss: 1.4350
# Epoch 15/50
# 7/7 - 2s - loss: 1.3568 - val_loss: 1.4490
# Epoch 16/50
# 7/7 - 2s - loss: 1.3716 - val_loss: 1.4022
# Epoch 17/50
# 7/7 - 3s - loss: 1.4119 - val_loss: 1.7088
# Epoch 18/50
# 7/7 - 2s - loss: 1.4645 - val_loss: 1.4162
# Epoch 19/50
# 7/7 - 2s - loss: 1.3892 - val_loss: 1.3901
# Epoch 20/50
# 7/7 - 2s - loss: 1.3724 - val_loss: 1.5112
# Epoch 21/50
# 7/7 - 2s - loss: 1.3584 - val_loss: 1.3941
# Epoch 22/50
# 7/7 - 2s - loss: 1.3416 - val_loss: 1.4554
# Epoch 23/50
# 7/7 - 2s - loss: 1.3470 - val_loss: 1.4098
# Epoch 24/50
# 7/7 - 2s - loss: 1.3424 - val_loss: 1.3874
# Epoch 25/50
# 7/7 - 2s - loss: 1.3228 - val_loss: 1.4448
# Epoch 26/50
# 7/7 - 2s - loss: 1.3310 - val_loss: 1.4417
# Epoch 27/50
# 7/7 - 2s - loss: 1.3089 - val_loss: 1.3783
# Epoch 28/50
# 7/7 - 2s - loss: 1.3111 - val_loss: 1.4022
# Epoch 29/50
# 7/7 - 2s - loss: 1.3204 - val_loss: 1.4541
# Epoch 30/50
# 7/7 - 2s - loss: 1.3102 - val_loss: 1.3920
# Epoch 31/50
# 7/7 - 2s - loss: 1.3430 - val_loss: 1.3957
# Epoch 32/50
# 7/7 - 2s - loss: 1.3095 - val_loss: 1.3890
# Epoch 33/50
# 7/7 - 2s - loss: 1.2894 - val_loss: 1.4654
# Epoch 34/50
# 7/7 - 2s - loss: 1.3026 - val_loss: 1.4074
# Epoch 35/50
# 7/7 - 2s - loss: 1.2918 - val_loss: 1.3870
# Epoch 36/50
# 7/7 - 2s - loss: 1.3232 - val_loss: 1.5075
# Epoch 37/50
# 7/7 - 2s - loss: 1.3034 - val_loss: 1.3897
# Epoch 38/50
# 7/7 - 2s - loss: 1.2835 - val_loss: 1.4212
# Epoch 39/50
# 7/7 - 2s - loss: 1.2894 - val_loss: 1.4666
# Epoch 40/50
# 7/7 - 2s - loss: 1.2837 - val_loss: 1.3825
# Epoch 41/50
# 7/7 - 2s - loss: 1.2695 - val_loss: 1.4147
# Epoch 42/50
# 7/7 - 2s - loss: 1.2793 - val_loss: 1.4839
# Epoch 43/50
# 7/7 - 2s - loss: 1.3224 - val_loss: 1.4465
# Epoch 44/50
# 7/7 - 2s - loss: 1.3384 - val_loss: 1.5325
# Epoch 45/50
# 7/7 - 2s - loss: 1.3108 - val_loss: 1.3903
# Epoch 46/50
# 7/7 - 2s - loss: 1.2669 - val_loss: 1.4052
# Epoch 47/50
# 7/7 - 2s - loss: 1.2560 - val_loss: 1.4128
# Epoch 48/50
# 7/7 - 2s - loss: 1.2620 - val_loss: 1.3831
# Epoch 49/50
# 7/7 - 3s - loss: 1.2533 - val_loss: 1.3814
# Epoch 50/50
# 7/7 - 2s - loss: 1.2732 - val_loss: 1.3944
# Model P0.9...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Epoch 1/50
# 7/7 - 34s - loss: 13.7421 - val_loss: 10.3860
# Epoch 2/50
# 7/7 - 2s - loss: 8.3246 - val_loss: 5.5272
# Epoch 3/50
# 7/7 - 2s - loss: 4.1087 - val_loss: 2.5464
# Epoch 4/50
# 7/7 - 2s - loss: 1.8597 - val_loss: 1.3294
# Epoch 5/50
# 7/7 - 2s - loss: 1.0856 - val_loss: 0.9739
# Epoch 6/50
# 7/7 - 2s - loss: 0.9197 - val_loss: 1.1636
# Epoch 7/50
# 7/7 - 2s - loss: 0.9706 - val_loss: 0.8976
# Epoch 8/50
# 7/7 - 2s - loss: 0.8692 - val_loss: 0.8581
# Epoch 9/50
# 7/7 - 2s - loss: 0.8457 - val_loss: 0.9388
# Epoch 10/50
# 7/7 - 2s - loss: 0.8508 - val_loss: 0.8156
# Epoch 11/50
# 7/7 - 2s - loss: 0.8027 - val_loss: 0.8490
# Epoch 12/50
# 7/7 - 2s - loss: 0.7924 - val_loss: 0.8132
# Epoch 13/50
# 7/7 - 2s - loss: 0.7783 - val_loss: 0.7980
# Epoch 14/50
# 7/7 - 2s - loss: 0.7806 - val_loss: 0.8260
# Epoch 15/50
# 7/7 - 2s - loss: 0.7635 - val_loss: 0.8132
# Epoch 16/50
# 7/7 - 2s - loss: 0.7570 - val_loss: 0.7962
# Epoch 17/50
# 7/7 - 2s - loss: 0.7493 - val_loss: 0.7910
# Epoch 18/50
# 7/7 - 2s - loss: 0.7429 - val_loss: 0.7945
# Epoch 19/50
# 7/7 - 2s - loss: 0.7578 - val_loss: 0.7859
# Epoch 20/50
# 7/7 - 2s - loss: 0.7669 - val_loss: 0.8686
# Epoch 21/50
# 7/7 - 2s - loss: 0.7714 - val_loss: 0.7774
# Epoch 22/50
# 7/7 - 2s - loss: 0.7518 - val_loss: 0.7773
# Epoch 23/50
# 7/7 - 2s - loss: 0.7484 - val_loss: 0.7819
# Epoch 24/50
# 7/7 - 2s - loss: 0.7407 - val_loss: 0.7736
# Epoch 25/50
# 7/7 - 2s - loss: 0.7297 - val_loss: 0.7938
# Epoch 26/50
# 7/7 - 2s - loss: 0.7300 - val_loss: 0.7719
# Epoch 27/50
# 7/7 - 2s - loss: 0.7226 - val_loss: 0.7700
# Epoch 28/50
# 7/7 - 2s - loss: 0.7384 - val_loss: 0.7904
# Epoch 29/50
# 7/7 - 2s - loss: 0.7338 - val_loss: 0.7960
# Epoch 30/50
# 7/7 - 2s - loss: 0.7272 - val_loss: 0.7900
# Epoch 31/50
# 7/7 - 2s - loss: 0.7248 - val_loss: 0.8201
# Epoch 32/50
# 7/7 - 2s - loss: 0.7412 - val_loss: 0.7875
# Epoch 33/50
# 7/7 - 2s - loss: 0.7260 - val_loss: 0.7656
# Epoch 34/50
# 7/7 - 2s - loss: 0.7398 - val_loss: 0.7711
# Epoch 35/50
# 7/7 - 2s - loss: 0.7434 - val_loss: 0.7982
# Epoch 36/50
# 7/7 - 2s - loss: 0.7417 - val_loss: 0.7940
# Epoch 37/50
# 7/7 - 2s - loss: 0.7264 - val_loss: 0.7929
# Epoch 38/50
# 7/7 - 2s - loss: 0.7294 - val_loss: 0.7945
# Epoch 39/50
# 7/7 - 2s - loss: 0.7110 - val_loss: 0.7811
# Epoch 40/50
# 7/7 - 2s - loss: 0.7080 - val_loss: 0.7652
# Epoch 41/50
# 7/7 - 2s - loss: 0.7000 - val_loss: 0.8370
# Epoch 42/50
# 7/7 - 2s - loss: 0.7418 - val_loss: 0.7639
# Epoch 43/50
# 7/7 - 2s - loss: 0.7044 - val_loss: 0.7656
# Epoch 44/50
# 7/7 - 2s - loss: 0.7141 - val_loss: 0.7789
# Epoch 45/50
# 7/7 - 2s - loss: 0.7017 - val_loss: 0.8030
# Epoch 46/50
# 7/7 - 2s - loss: 0.7234 - val_loss: 0.7916
# Epoch 47/50
# 7/7 - 2s - loss: 0.7192 - val_loss: 0.7672
# Epoch 48/50
# 7/7 - 2s - loss: 0.6979 - val_loss: 0.7621
# Epoch 49/50
# 7/7 - 2s - loss: 0.6956 - val_loss: 0.7622
# Epoch 50/50
# 7/7 - 2s - loss: 0.6862 - val_loss: 0.7622
# CPU times: user 31min 32s, sys: 2min 13s, total: 33min 46s
# Wall time: 23min 11s

# %%
# %tensorboard --logdir logs/fit --host jupyter-server --port 6006

# %% [markdown]
# ## **Make Clean Checkpoints**

# %%
# %%time

ckpt_folders = sorted(glob.glob(os.path.join(os.environ["CHECKPOINT_PATH"], os.environ["NOTEBOOKNAME"], "P*")))

num_rm_files = 0
rm_files_sz = 0 # bytes

for f in ckpt_folders:
    # 7 files must be located in ckpt_folders. (latest 3 ckpt, it's index and checkpoint file)
    assert len(os.listdir(f)) >= (1 + HPARAMS.max_to_keep * 2), f"Checkpoints in {f} is less then 3 (max_to_keep)."
    
    rm_files = [os.path.join(f, i) for i in sorted(os.listdir(f))[1:-2*HPARAMS.max_to_keep]] # [1:-6]
    num_rm_files += len(rm_files)
    rm_files_sz += sum([os.path.getsize(rm_file) for rm_file in rm_files])
    
    _ = [os.remove(rm_file) for rm_file in rm_files]
    
print(f"{num_rm_files} files removed.")
print(f"{rm_files_sz / 2**20:.2f}MB saved.")
# Out:
# 158 files removed.
# 1666.95MB saved.
# CPU times: user 0 ns, sys: 97 ms, total: 97 ms
# Wall time: 97 ms

# %% [markdown]
# # **Visualize**

# %% [markdown]
# ## **Plot Histories**

# %%
# def draw_histories(
#     histories: dict,
# ):
#     """Draw 9 histories in one plot."""
    
#     assert len(histories.keys()) == HPARAMS.num_quantile
    
#     plt.figure(figsize = (18, 14), facecolor = "white", dpi = 96)

#     for model_name, history in histories.items():
#         pos = int(model_name.split(".")[-1])
#         plt.subplot(3, 3, pos)
                
# #         plt.plot(history.epoch, history.history["aux_loss"], c = "r", label = "aux_loss")
#         plt.plot(history.epoch, history.history["real_loss"], c = "r", ls = "--", label = "real_loss")
# #         plt.plot(history.epoch, history.history["val_aux_loss"], c = "navy", label = "val_aux_loss")
#         plt.plot(history.epoch, history.history["val_real_loss"], c = "navy", ls = "--", label = "val_real_loss")
    
#         plt.legend(loc = "upper left")
#         plt.title(model_name, fontsize = 20)
#         plt.xlabel("Epoch")
#         plt.ylabel("Pinball Loss")
    
#         plt.grid(True)
        
#     plt.tight_layout()
#     plt.show()

# %%
# draw_histories(histories)

# %% [markdown]
# ## **Target Model Prediction**

# %%
def load_latest_models(
    ckpt_folders: list,
) -> list:
    """Load latest weights of target model from saved ckeckpoints."""   
    
    models = []
    val_losses = []
    
    for f in ckpt_folders:
        latest = tf.train.latest_checkpoint(f)
        print(f"Load latest checkpoints: {latest}...")
        
        model_name = latest.split(os.path.sep)[-2] # ckpt/[notebookname]/P0.1/...
        val_loss = np.float32(latest.split(os.path.sep)[-1].split("-")[2][:6])

        # Define a new AR-LSTM model and load checkpoints.
        model = Ensembled_AR_ConvLSTM1D(model_name = model_name)

        ckpt = tf.train.Checkpoint(model)
        ckpt.restore(latest).expect_partial()
        models.append(model)
        
        val_losses.append(val_loss)
        
    return models, val_losses


def draw_pred(
    inputs, 
    y_preds, 
    y_true, 
    save_fig = False,
):
    """Draw the predictions and labels."""
    
    plt.figure(figsize = (14, 4 * HPARAMS.num_quantile), facecolor = "white")
    
    for i, (y_pred, tau) in enumerate(zip(y_preds, np.arange(0.1, 1, 0.1))):
        plt.subplot(9, 1, i + 1)
        
        plt.plot(np.arange(len(inputs)), inputs, lw = 1.5, label = "Inputs")
        plt.plot(np.arange(len(inputs), len(inputs) + len(y_pred), 1), y_pred, marker = "o", lw = 1.5, label = "Predictions")
        plt.plot(np.arange(len(inputs), len(inputs) + len(y_true), 1), y_true, marker = "X", lw = 1.5, label = "Label")
    
        plt.title(f"Target Model T{tau:.1f}")
        plt.xlabel("Time [day]")
        plt.ylabel("Target")
        plt.ylim([-0.8, max(y_true) * 1.1])
        plt.legend()

        plt.xticks(
            np.arange(0, HPARAMS.w_inp + HPARAMS.w_tar + 1, HPARAMS.day), 
            [f"D+{i}" for i in np.arange(HPARAMS.inp + HPARAMS.tar + 1)])
        plt.grid(True)
        
    plt.tight_layout()
    
    if save_fig:
        plt.savefig(os.path.join("pngs", f"{os.environ['NOTEBOOKNAME']}.png"), dpi = 96)
        
    plt.show()

# %%
# Restore latest models from saved checkpoints.
ckpt_folders = sorted(glob.glob(os.path.join(os.environ["CHECKPOINT_PATH"], os.environ["NOTEBOOKNAME"], "P*")))
models, val_losses = load_latest_models(ckpt_folders)

print(f"Averaged Validation Loss: {np.mean(val_losses):.4f}")

# Now, unbatch the dataset to predict only one sequences (i.e. 7 days).
unbatched_vl_dataset = vl_dataset.unbatch().batch(1)

for t in unbatched_vl_dataset.take(1):
    x, r_y = t # inp, aux_tar, real_tar
    
    draw_pred(
        inputs = vl_tensor[:HPARAMS.w_inp, -1], # not x
        y_preds = [tf.reshape(model.predict(x), (-1, )).numpy() for model in models],
        y_true = tf.reshape(r_y, (-1, )))
# Out:
# Load latest checkpoints: ckpt/try168/P0.1/cp-007-1.4364.ckpt...
# Load latest checkpoints: ckpt/try168/P0.2/cp-007-2.3425.ckpt...
# Load latest checkpoints: ckpt/try168/P0.3/cp-016-2.7416.ckpt...
# Load latest checkpoints: ckpt/try168/P0.4/cp-014-2.8345.ckpt...
# Load latest checkpoints: ckpt/try168/P0.5/cp-015-2.7037.ckpt...
# Load latest checkpoints: ckpt/try168/P0.6/cp-024-2.3902.ckpt...
# Load latest checkpoints: ckpt/try168/P0.7/cp-037-1.9314.ckpt...
# Load latest checkpoints: ckpt/try168/P0.8/cp-027-1.3783.ckpt...
# Load latest checkpoints: ckpt/try168/P0.9/cp-048-0.7621.ckpt...
# Averaged Validation Loss: 2.0579
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f496c7eee18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4834afd488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4835a82158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f487e68df28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4888164620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# # **Make Submissions**

# %%
# %%time
# Restore latest models from saved checkpoints.
ckpt_folders = sorted(glob.glob(os.path.join(os.environ["CHECKPOINT_PATH"], os.environ["NOTEBOOKNAME"], "P*")))
models, _ = load_latest_models(ckpt_folders)

# Predict the test datasets.
# We need to drop auxiliary outputs and squeeze dimensions (i.e. [batch, 96, 1] => [batch, 96]).
preds = [np.array(tf.reshape(model.predict(ts_dataset)[-1], (-1, ))) for model in models]

# %%
submission = pd.read_csv(os.path.join(os.environ["LOCAL_DATA_PATH"], "sample_submission.csv"), index_col = "id")
submission.head()

# %%
for column, pred in zip(submission.columns, preds):
    foo = np.reshape(pred, (-1,))
    foo = np.where(foo < HPARAMS.epsilon, 0, foo) # clip by value
    
    submission[column] = foo

# %%
submission.head()

# %%
submission.to_csv(os.path.join(os.environ["SUBMISSION_PATH"], f"{os.environ['NOTEBOOKNAME']}_submission.csv"))
